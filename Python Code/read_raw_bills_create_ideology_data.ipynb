# %%
import os
import json
import pandas as pd
import pickle
import numpy as np
import time
from legiscan import LegiScan
from legiscan import LegiScanError
from datetime import datetime
import regex as re 

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

with open('./assets/imp/API_keys', 'r') as file:
    config = json.load(file)

# Extract the API key
legi = config['legiscan']
legis = LegiScan(legi)

#for state year, we store our sampled left and right bill ids from textalignments.ipynb. Will use this in read json
with open('./Data/left_dict.pkl', 'rb') as pickle_file:
    left_dict = pickle.load(pickle_file)

with open('./Data/left_dict.pkl.', 'rb') as pickle_file:
    right_dict = pickle.load(pickle_file)

key_left = [key for key in left_dict.keys()]
key_right = [key for key in right_dict.keys()]

# %%
def read_json_and_count(file_path):
    ''' Read the JSON file line by line and if bill text exists then append state and year to list.
     Then we group by state and list. The outpout is used in visualization of state and year wise number of document available '''
    # List to store all bill information with categories
    all_bills = []
    start = time.time()

    with open(file_path, 'r', encoding='utf-8') as file:
        line_count = 0  # Initialize line counter
        for line in file:
            try:
                bill = json.loads(line.strip())
                state = bill.get('state')
                date_created = bill.get('date_created')
                year = datetime.strptime(date_created, "%Y-%m-%d %H:%M:%S").year if date_created else 'NA'
                has_first = bill.get('bill_document_first') is not None
                has_last = bill.get('bill_document_last') is not None
                
                # Determine category of document availability
                if has_first or has_last:
                    years = year
                elif not has_first and not has_last:
                    years = 'na'
  # Set year as 'NA' if both parts are missing

                # Add bill information to the list
                all_bills.append({'state': state, 'year': years})

                line_count += 1
                if line_count % 500 == 0:  # Print progress every 500 lines
                    print(f"Processed {line_count} lines.")
                    end = time.time()
                    time_taken = (end - start) / 60
                    print(f'Time taken to process 500 lines: {time_taken} minutes')
                    start = time.time()
            except json.JSONDecodeError as e:
                print(f"Error decoding JSON: {e}")

    # Convert list of bills into DataFrame
    all_bills_df = pd.DataFrame(all_bills)

    # Group by 'state', 'year', and 'document_status' and count occurrences
    detailed_counts = all_bills_df.groupby(['state', 'year']).size().reset_index(name='count')

    return detailed_counts

# %%
###get state and yearwise counts 
counts = read_json_and_sample(file_path)
counts = counts.groupby(['state','year']).count()
# counts.to_csv('./Data/counts.csv')
# Out:
# Processed 500 lines.
# Time taken to process 500 lines: 0.012935888767242432 minutes
# Processed 1000 lines.
# Time taken to process 500 lines: 0.0010542710622151693 minutes
# Processed 1500 lines.
# Time taken to process 500 lines: 0.0008895754814147949 minutes
# Processed 2000 lines.
# Time taken to process 500 lines: 0.0011269132296244304 minutes
# Processed 2500 lines.
# Time taken to process 500 lines: 0.0009267131487528483 minutes
# Processed 3000 lines.
# Time taken to process 500 lines: 0.0008203625679016113 minutes
# Processed 3500 lines.
# Time taken to process 500 lines: 0.0014007647832234701 minutes
# Processed 4000 lines.
# Time taken to process 500 lines: 0.0007506251335144043 minutes
# Processed 4500 lines.
# Time taken to process 500 lines: 0.0009383002916971843 minutes
# Processed 5000 lines.
# Time taken to process 500 lines: 0.0007283767064412435 minutes
# Processed 5500 lines.
# Time taken to process 500 lines: 0.0006361762682596842 minutes
# Processed 6000 lines.
# Time taken to process 500 lines: 0.0008433818817138672 minutes
# Processed 6500 lines.
# Time taken to process 500 lines: 0.000725245475769043 minutes
# Processed 7000 lines.
# Time taken to process 500 lines: 0.0009067257245381674 minutes
# Processed 7500 lines.
# Time taken to process 500 lines: 0.0006537675857543945 minutes
# Processed 8000 lines.
# Time taken to process 500 lines: 0.0006726741790771485 minutes
# Processed 8500 lines.
# Time taken to process 500 lines: 0.0011296709378560384 minutes
# Processed 9000 lines.
# Time taken to process 500 lines: 0.0005833109219868978 minutes
# Processed 9500 lines.
# Time taken to process 500 lines: 0.000608678658803304 minutes
# Processed 10000 lines.
# Time taken to process 500 lines: 0.0006119966506958008 minutes
# Processed 10500 lines.
# Time taken to process 500 lines: 0.0006280700365702311 minutes
# Processed 11000 lines.
# Time taken to process 500 lines: 0.0010751446088155111 minutes
# Processed 11500 lines.
# Time taken to process 500 lines: 0.000767680009206136 minutes
# Processed 12000 lines.
# Time taken to process 500 lines: 0.0009525577227274577 minutes
# Processed 12500 lines.
# Time taken to process 500 lines: 0.0006335655848185222 minutes
# Processed 13000 lines.
# Time taken to process 500 lines: 0.0005255540211995443 minutes
# Processed 13500 lines.
# Time taken to process 500 lines: 0.0005812803904215495 minutes
# Processed 14000 lines.
# Time taken to process 500 lines: 0.0005503972371419271 minutes
# Processed 14500 lines.
# Time taken to process 500 lines: 0.0005944013595581054 minutes
# Processed 15000 lines.
# Time taken to process 500 lines: 0.001031466325124105 minutes
# Processed 15500 lines.
# Time taken to process 500 lines: 0.000889738400777181 minutes
# Processed 16000 lines.
# Time taken to process 500 lines: 0.002199856440226237 minutes
# Processed 16500 lines.
# Time taken to process 500 lines: 0.0010353644688924153 minutes
# Processed 17000 lines.
# Time taken to process 500 lines: 0.0010277390480041503 minutes
# Processed 17500 lines.
# Time taken to process 500 lines: 0.0013007918993632 minutes
# Processed 18000 lines.
# Time taken to process 500 lines: 0.002077500025431315 minutes
# Processed 18500 lines.
# Time taken to process 500 lines: 0.000749969482421875 minutes
# Processed 19000 lines.
# Time taken to process 500 lines: 0.0008447885513305664 minutes
# Processed 19500 lines.
# Time taken to process 500 lines: 0.0015470703442891439 minutes
# Processed 20000 lines.
# Time taken to process 500 lines: 0.0012557506561279297 minutes
# Processed 20500 lines.
# Time taken to process 500 lines: 0.0020982901255289714 minutes
# Processed 21000 lines.
# Time taken to process 500 lines: 0.0013802289962768556 minutes
# Processed 21500 lines.
# Time taken to process 500 lines: 0.0011803984642028808 minutes
# Processed 22000 lines.
# Time taken to process 500 lines: 0.0008168299992879232 minutes
# Processed 22500 lines.
# Time taken to process 500 lines: 0.0008034984270731608 minutes
# Processed 23000 lines.
# Time taken to process 500 lines: 0.0009459773699442546 minutes
# Processed 23500 lines.
# Time taken to process 500 lines: 0.0031739274660746255 minutes
# Processed 24000 lines.
# Time taken to process 500 lines: 0.002083126703898112 minutes
# Processed 24500 lines.
# Time taken to process 500 lines: 0.0017160932223002116 minutes
# Processed 25000 lines.
# Time taken to process 500 lines: 0.0008647839228312174 minutes
# Processed 25500 lines.
# Time taken to process 500 lines: 0.0012075384457906088 minutes
# Processed 26000 lines.
# Time taken to process 500 lines: 0.0007343848546346028 minutes
# Processed 26500 lines.
# Time taken to process 500 lines: 0.0013466000556945801 minutes
# Processed 27000 lines.
# Time taken to process 500 lines: 0.0007462223370869954 minutes
# Processed 27500 lines.
# Time taken to process 500 lines: 0.0010014692942301431 minutes
# Processed 28000 lines.
# Time taken to process 500 lines: 0.0007565140724182129 minutes
# Processed 28500 lines.
# Time taken to process 500 lines: 0.0009560942649841309 minutes
# Processed 29000 lines.
# Time taken to process 500 lines: 0.001384898026784261 minutes
# Processed 29500 lines.
# Time taken to process 500 lines: 0.0007266600926717123 minutes
# Processed 30000 lines.
# Time taken to process 500 lines: 0.0009975632031758626 minutes
# Processed 30500 lines.
# Time taken to process 500 lines: 0.0014181256294250489 minutes
# Processed 31000 lines.
# Time taken to process 500 lines: 0.0012233972549438477 minutes
# Processed 31500 lines.
# Time taken to process 500 lines: 0.0025383154551188152 minutes
# Processed 32000 lines.
# Time taken to process 500 lines: 0.0010020335515340169 minutes
# Processed 32500 lines.
# Time taken to process 500 lines: 0.0017931024233500163 minutes
# Processed 33000 lines.
# Time taken to process 500 lines: 0.0013257741928100586 minutes
# Processed 33500 lines.
# Time taken to process 500 lines: 0.0011393427848815918 minutes
# Processed 34000 lines.
# Time taken to process 500 lines: 0.0007435997327168782 minutes
# Processed 34500 lines.
# Time taken to process 500 lines: 0.0008837103843688965 minutes
# Processed 35000 lines.
# Time taken to process 500 lines: 0.0018326044082641602 minutes
# Processed 35500 lines.
# Time taken to process 500 lines: 0.0012791991233825684 minutes
# Processed 36000 lines.
# Time taken to process 500 lines: 0.0011597394943237305 minutes
# Processed 36500 lines.
# Time taken to process 500 lines: 0.0020132064819335938 minutes
# Processed 37000 lines.
# Time taken to process 500 lines: 0.0009012103080749511 minutes
# Processed 37500 lines.
# Time taken to process 500 lines: 0.0008410930633544922 minutes
# Processed 38000 lines.
# Time taken to process 500 lines: 0.0010087132453918458 minutes
# Processed 38500 lines.
# Time taken to process 500 lines: 0.0013454437255859375 minutes
# Processed 39000 lines.
# Time taken to process 500 lines: 0.0008924126625061036 minutes
# Processed 39500 lines.
# Time taken to process 500 lines: 0.0008167386054992676 minutes
# Processed 40000 lines.
# Time taken to process 500 lines: 0.0014550288518269856 minutes
# Processed 40500 lines.
# Time taken to process 500 lines: 0.0020266095797220867 minutes
# Processed 41000 lines.
# Time taken to process 500 lines: 0.0013322035471598308 minutes
# Processed 41500 lines.
# Time taken to process 500 lines: 0.0007025798161824545 minutes
# Processed 42000 lines.
# Time taken to process 500 lines: 0.0007196625073750813 minutes
# Processed 42500 lines.
# Time taken to process 500 lines: 0.0011627197265625 minutes
# Processed 43000 lines.
# Time taken to process 500 lines: 0.0014036099116007488 minutes
# Processed 43500 lines.
# Time taken to process 500 lines: 0.0009448607762654622 minutes
# Processed 44000 lines.
# Time taken to process 500 lines: 0.0012443900108337403 minutes
# Processed 44500 lines.
# Time taken to process 500 lines: 0.001998857657114665 minutes
# Processed 45000 lines.
# Time taken to process 500 lines: 0.0011084159215291342 minutes
# Processed 45500 lines.
# Time taken to process 500 lines: 0.0009996414184570313 minutes
# Processed 46000 lines.
# Time taken to process 500 lines: 0.001227740446726481 minutes
# Processed 46500 lines.
# Time taken to process 500 lines: 0.0009448448816935221 minutes
# Processed 47000 lines.
# Time taken to process 500 lines: 0.0008628050486246745 minutes
# Processed 47500 lines.
# Time taken to process 500 lines: 0.0008554657300313314 minutes
# Processed 48000 lines.
# Time taken to process 500 lines: 0.0015190362930297852 minutes
# Processed 48500 lines.
# Time taken to process 500 lines: 0.0006965676943461101 minutes
# Processed 49000 lines.
# Time taken to process 500 lines: 0.0006589571634928386 minutes
# Processed 49500 lines.
# Time taken to process 500 lines: 0.0010467847188313803 minutes
# Processed 50000 lines.
# Time taken to process 500 lines: 0.0009310285250345866 minutes
# Processed 50500 lines.
# Time taken to process 500 lines: 0.001414330800374349 minutes
# Processed 51000 lines.
# Time taken to process 500 lines: 0.0007528066635131836 minutes
# Processed 51500 lines.
# Time taken to process 500 lines: 0.0008074164390563965 minutes
# Processed 52000 lines.
# Time taken to process 500 lines: 0.0010301431020100912 minutes
# Processed 52500 lines.
# Time taken to process 500 lines: 0.0019476652145385743 minutes
# Processed 53000 lines.
# Time taken to process 500 lines: 0.000820620854695638 minutes
# Processed 53500 lines.
# Time taken to process 500 lines: 0.0010108033816019694 minutes
# Processed 54000 lines.
# Time taken to process 500 lines: 0.000717767079671224 minutes
# Processed 54500 lines.
# Time taken to process 500 lines: 0.0008634328842163086 minutes
# Processed 55000 lines.
# Time taken to process 500 lines: 0.00031265020370483396 minutes
# Processed 55500 lines.
# Time taken to process 500 lines: 0.0007689714431762696 minutes
# Processed 56000 lines.
# Time taken to process 500 lines: 0.0017091910044352214 minutes
# Processed 56500 lines.
# Time taken to process 500 lines: 0.001623392105102539 minutes
# Processed 57000 lines.
# Time taken to process 500 lines: 0.001793511708577474 minutes
# Processed 57500 lines.
# Time taken to process 500 lines: 0.002287336190541585 minutes
# Processed 58000 lines.
# Time taken to process 500 lines: 0.0019230604171752929 minutes
# Processed 58500 lines.
# Time taken to process 500 lines: 0.0015053311983744303 minutes
# Processed 59000 lines.
# Time taken to process 500 lines: 0.0011354525883992513 minutes
# Processed 59500 lines.
# Time taken to process 500 lines: 0.002325900395711263 minutes
# Processed 60000 lines.
# Time taken to process 500 lines: 0.0008181373278299968 minutes
# Processed 60500 lines.
# Time taken to process 500 lines: 0.001695724328358968 minutes
# Processed 61000 lines.
# Time taken to process 500 lines: 0.0013865947723388672 minutes
# Processed 61500 lines.
# Time taken to process 500 lines: 0.001047837734222412 minutes
# Processed 62000 lines.
# Time taken to process 500 lines: 0.0011276960372924804 minutes
# Processed 62500 lines.
# Time taken to process 500 lines: 0.0013852318127950032 minutes
# Processed 63000 lines.
# Time taken to process 500 lines: 0.0017266790072123209 minutes
# Processed 63500 lines.
# Time taken to process 500 lines: 0.0018306175867716472 minutes
# Processed 64000 lines.
# Time taken to process 500 lines: 0.0018926739692687988 minutes
# Processed 64500 lines.
# Time taken to process 500 lines: 0.000981438159942627 minutes
# Processed 65000 lines.
# Time taken to process 500 lines: 0.0007706403732299805 minutes
# Processed 65500 lines.
# Time taken to process 500 lines: 0.0006842851638793945 minutes
# Processed 66000 lines.
# Time taken to process 500 lines: 0.0007167220115661621 minutes
# Processed 66500 lines.
# Time taken to process 500 lines: 0.0011122385660807292 minutes
# Processed 67000 lines.
# Time taken to process 500 lines: 0.0006186405817667644 minutes
# Processed 67500 lines.
# Time taken to process 500 lines: 0.0003426273663838704 minutes
# Processed 68000 lines.
# Time taken to process 500 lines: 0.00033454100290934247 minutes
# Processed 68500 lines.
# Time taken to process 500 lines: 0.00030002196629842125 minutes
# Processed 69000 lines.
# Time taken to process 500 lines: 0.00030588308970133464 minutes
# Processed 69500 lines.
# Time taken to process 500 lines: 0.00047567288080851234 minutes
# Processed 70000 lines.
# Time taken to process 500 lines: 0.001134816805521647 minutes
# Processed 70500 lines.
# Time taken to process 500 lines: 0.0011480490366617838 minutes
# Processed 71000 lines.
# Time taken to process 500 lines: 0.0006587028503417969 minutes
# Processed 71500 lines.
# Time taken to process 500 lines: 0.0006656130154927572 minutes
# Processed 72000 lines.
# Time taken to process 500 lines: 0.0014429807662963868 minutes
# Processed 72500 lines.
# Time taken to process 500 lines: 0.00173494815826416 minutes
# Processed 73000 lines.
# Time taken to process 500 lines: 0.0009292244911193847 minutes
# Processed 73500 lines.
# Time taken to process 500 lines: 0.0008653759956359863 minutes
# Processed 74000 lines.
# Time taken to process 500 lines: 0.001084446907043457 minutes
# Processed 74500 lines.
# Time taken to process 500 lines: 0.0019390424092610677 minutes
# Processed 75000 lines.
# Time taken to process 500 lines: 0.004458971818288167 minutes
# Processed 75500 lines.
# Time taken to process 500 lines: 0.00477298100789388 minutes
# Processed 76000 lines.
# Time taken to process 500 lines: 0.003031428654988607 minutes
# Processed 76500 lines.
# Time taken to process 500 lines: 0.0024833917617797852 minutes
# Processed 77000 lines.
# Time taken to process 500 lines: 0.003918596108754476 minutes
# Processed 77500 lines.
# Time taken to process 500 lines: 0.007085176308949789 minutes
# Processed 78000 lines.
# Time taken to process 500 lines: 0.005351138114929199 minutes
# Processed 78500 lines.
# Time taken to process 500 lines: 0.006620637575785319 minutes
# Processed 79000 lines.
# Time taken to process 500 lines: 0.004236773649851481 minutes
# Processed 79500 lines.
# Time taken to process 500 lines: 0.0011142174402872722 minutes
# Processed 80000 lines.
# Time taken to process 500 lines: 0.001039266586303711 minutes
# Processed 80500 lines.
# Time taken to process 500 lines: 0.0007877031962076823 minutes
# Processed 81000 lines.
# Time taken to process 500 lines: 0.0008737444877624512 minutes
# Processed 81500 lines.
# Time taken to process 500 lines: 0.0006586074829101563 minutes
# Processed 82000 lines.
# Time taken to process 500 lines: 0.0007967511812845866 minutes
# Processed 82500 lines.
# Time taken to process 500 lines: 0.0016962051391601562 minutes
# Processed 83000 lines.
# Time taken to process 500 lines: 0.001312724749247233 minutes
# Processed 83500 lines.
# Time taken to process 500 lines: 0.0011541048685709636 minutes
# Processed 84000 lines.
# Time taken to process 500 lines: 0.0007617553075154622 minutes
# Processed 84500 lines.
# Time taken to process 500 lines: 0.0008971929550170898 minutes
# Processed 85000 lines.
# Time taken to process 500 lines: 0.0009975512822469077 minutes
# Processed 85500 lines.
# Time taken to process 500 lines: 0.0010396242141723633 minutes
# Processed 86000 lines.
# Time taken to process 500 lines: 0.0014134605725606283 minutes
# Processed 86500 lines.
# Time taken to process 500 lines: 0.001465582847595215 minutes
# Processed 87000 lines.
# Time taken to process 500 lines: 0.0009672284126281738 minutes
# Processed 87500 lines.
# Time taken to process 500 lines: 0.0009070873260498047 minutes
# Processed 88000 lines.
# Time taken to process 500 lines: 0.0009335160255432128 minutes
# Processed 88500 lines.
# Time taken to process 500 lines: 0.0008148670196533204 minutes
# Processed 89000 lines.
# Time taken to process 500 lines: 0.000817418098449707 minutes
# Processed 89500 lines.
# Time taken to process 500 lines: 0.000692137082417806 minutes
# Processed 90000 lines.
# Time taken to process 500 lines: 0.0010467290878295899 minutes
# Processed 90500 lines.
# Time taken to process 500 lines: 0.0007329463958740234 minutes
# Processed 91000 lines.
# Time taken to process 500 lines: 0.0007469574610392253 minutes
# Processed 91500 lines.
# Time taken to process 500 lines: 0.0008216738700866699 minutes
# Processed 92000 lines.
# Time taken to process 500 lines: 0.001709600289662679 minutes
# Processed 92500 lines.
# Time taken to process 500 lines: 0.000824439525604248 minutes
# Processed 93000 lines.
# Time taken to process 500 lines: 0.0008949915568033854 minutes
# Processed 93500 lines.
# Time taken to process 500 lines: 0.0010216474533081056 minutes
# Processed 94000 lines.
# Time taken to process 500 lines: 0.0009741663932800293 minutes
# Processed 94500 lines.
# Time taken to process 500 lines: 0.0009743968645731608 minutes
# Processed 95000 lines.
# Time taken to process 500 lines: 0.0012016812960306802 minutes
# Processed 95500 lines.
# Time taken to process 500 lines: 0.000907297929128011 minutes
# Processed 96000 lines.
# Time taken to process 500 lines: 0.0010109543800354004 minutes
# Processed 96500 lines.
# Time taken to process 500 lines: 0.0008236289024353028 minutes
# Processed 97000 lines.
# Time taken to process 500 lines: 0.0007951815923055013 minutes
# Processed 97500 lines.
# Time taken to process 500 lines: 0.0008805274963378906 minutes
# Processed 98000 lines.
# Time taken to process 500 lines: 0.0008696397145589193 minutes
# Processed 98500 lines.
# Time taken to process 500 lines: 0.0007391691207885743 minutes
# Processed 99000 lines.
# Time taken to process 500 lines: 0.0008434494336446126 minutes
# Processed 99500 lines.
# Time taken to process 500 lines: 0.0009945392608642577 minutes
# Processed 100000 lines.
# Time taken to process 500 lines: 0.0009165048599243164 minutes
# Processed 100500 lines.
# Time taken to process 500 lines: 0.0013716737429300943 minutes
# Processed 101000 lines.
# Time taken to process 500 lines: 0.0009585777918497721 minutes
# Processed 101500 lines.
# Time taken to process 500 lines: 0.0009533246358235677 minutes
# Processed 102000 lines.
# Time taken to process 500 lines: 0.0008659680684407552 minutes
# Processed 102500 lines.
# Time taken to process 500 lines: 0.0009929776191711427 minutes
# Processed 103000 lines.
# Time taken to process 500 lines: 0.0009049057960510253 minutes
# Processed 103500 lines.
# Time taken to process 500 lines: 0.0009456396102905274 minutes
# Processed 104000 lines.
# Time taken to process 500 lines: 0.001011228561401367 minutes
# Processed 104500 lines.
# Time taken to process 500 lines: 0.0009668350219726562 minutes
# Processed 105000 lines.
# Time taken to process 500 lines: 0.0008704861005147299 minutes
# Processed 105500 lines.
# Time taken to process 500 lines: 0.0011778434117635092 minutes
# Processed 106000 lines.
# Time taken to process 500 lines: 0.001201164722442627 minutes
# Processed 106500 lines.
# Time taken to process 500 lines: 0.0010266621907552083 minutes
# Processed 107000 lines.
# Time taken to process 500 lines: 0.001147313912709554 minutes
# Processed 107500 lines.
# Time taken to process 500 lines: 0.0008778254191080729 minutes
# Processed 108000 lines.
# Time taken to process 500 lines: 0.0012781302134195964 minutes
# Processed 108500 lines.
# Time taken to process 500 lines: 0.000870350996653239 minutes
# Processed 109000 lines.
# Time taken to process 500 lines: 0.0009184916814168294 minutes
# Processed 109500 lines.
# Time taken to process 500 lines: 0.0008919000625610352 minutes
# Processed 110000 lines.
# Time taken to process 500 lines: 0.0009783148765563966 minutes
# Processed 110500 lines.
# Time taken to process 500 lines: 0.0009197751681009928 minutes
# Processed 111000 lines.
# Time taken to process 500 lines: 0.0010850270589192708 minutes
# Processed 111500 lines.
# Time taken to process 500 lines: 0.0007391730944315592 minutes
# Processed 112000 lines.
# Time taken to process 500 lines: 0.0008228381474812825 minutes
# Processed 112500 lines.
# Time taken to process 500 lines: 0.0008798360824584961 minutes
# Processed 113000 lines.
# Time taken to process 500 lines: 0.0009113510449727376 minutes
# Processed 113500 lines.
# Time taken to process 500 lines: 0.0010491132736206055 minutes
# Processed 114000 lines.
# Time taken to process 500 lines: 0.0010360121726989747 minutes
# Processed 114500 lines.
# Time taken to process 500 lines: 0.0007871150970458985 minutes
# Processed 115000 lines.
# Time taken to process 500 lines: 0.0008747736612955729 minutes
# Processed 115500 lines.
# Time taken to process 500 lines: 0.000919946034749349 minutes
# Processed 116000 lines.
# Time taken to process 500 lines: 0.0009678761164347331 minutes
# Processed 116500 lines.
# Time taken to process 500 lines: 0.0010660847028096518 minutes
# Processed 117000 lines.
# Time taken to process 500 lines: 0.0009669582049051921 minutes
# Processed 117500 lines.
# Time taken to process 500 lines: 0.0009484052658081055 minutes
# Processed 118000 lines.
# Time taken to process 500 lines: 0.0011567393938700357 minutes
# Processed 118500 lines.
# Time taken to process 500 lines: 0.0009197831153869629 minutes
# Processed 119000 lines.
# Time taken to process 500 lines: 0.0009820898373921712 minutes
# Processed 119500 lines.
# Time taken to process 500 lines: 0.0008412639300028484 minutes
# Processed 120000 lines.
# Time taken to process 500 lines: 0.0008690516153971354 minutes
# Processed 120500 lines.
# Time taken to process 500 lines: 0.0009954571723937988 minutes
# Processed 121000 lines.
# Time taken to process 500 lines: 0.0008041779200236003 minutes
# Processed 121500 lines.
# Time taken to process 500 lines: 0.0008905450503031413 minutes
# Processed 122000 lines.
# Time taken to process 500 lines: 0.0008042454719543457 minutes
# Processed 122500 lines.
# Time taken to process 500 lines: 0.0008210539817810059 minutes
# Processed 123000 lines.
# Time taken to process 500 lines: 0.0009557008743286133 minutes
# Processed 123500 lines.
# Time taken to process 500 lines: 0.0007104357083638509 minutes
# Processed 124000 lines.
# Time taken to process 500 lines: 0.0008936524391174316 minutes
# Processed 124500 lines.
# Time taken to process 500 lines: 0.0008119821548461914 minutes
# Processed 125000 lines.
# Time taken to process 500 lines: 0.0007920702298482259 minutes
# Processed 125500 lines.
# Time taken to process 500 lines: 0.0007266799608866373 minutes
# Processed 126000 lines.
# Time taken to process 500 lines: 0.0007614572842915853 minutes
# Processed 126500 lines.
# Time taken to process 500 lines: 0.0009595910708109538 minutes
# Processed 127000 lines.
# Time taken to process 500 lines: 0.0007890542348225911 minutes
# Processed 127500 lines.
# Time taken to process 500 lines: 0.0009122610092163086 minutes
# Processed 128000 lines.
# Time taken to process 500 lines: 0.0007850527763366699 minutes
# Processed 128500 lines.
# Time taken to process 500 lines: 0.0008549610773722331 minutes
# Processed 129000 lines.
# Time taken to process 500 lines: 0.0008585254351298014 minutes
# Processed 129500 lines.
# Time taken to process 500 lines: 0.0007632970809936523 minutes
# Processed 130000 lines.
# Time taken to process 500 lines: 0.0007316788037618001 minutes
# Processed 130500 lines.
# Time taken to process 500 lines: 0.0007178942362467448 minutes
# Processed 131000 lines.
# Time taken to process 500 lines: 0.000854337215423584 minutes
# Processed 131500 lines.
# Time taken to process 500 lines: 0.0009087800979614257 minutes
# Processed 132000 lines.
# Time taken to process 500 lines: 0.0007546424865722656 minutes
# Processed 132500 lines.
# Time taken to process 500 lines: 0.0007185975710550945 minutes
# Processed 133000 lines.
# Time taken to process 500 lines: 0.0007999857266743978 minutes
# Processed 133500 lines.
# Time taken to process 500 lines: 0.0008416136105855305 minutes
# Processed 134000 lines.
# Time taken to process 500 lines: 0.000739590326944987 minutes
# Processed 134500 lines.
# Time taken to process 500 lines: 0.0007945179939270019 minutes
# Processed 135000 lines.
# Time taken to process 500 lines: 0.0007677634557088216 minutes
# Processed 135500 lines.
# Time taken to process 500 lines: 0.0007843852043151855 minutes
# Processed 136000 lines.
# Time taken to process 500 lines: 0.0007355690002441406 minutes
# Processed 136500 lines.
# Time taken to process 500 lines: 0.0009026646614074707 minutes
# Processed 137000 lines.
# Time taken to process 500 lines: 0.0008135437965393066 minutes
# Processed 137500 lines.
# Time taken to process 500 lines: 0.0008225758870442708 minutes
# Processed 138000 lines.
# Time taken to process 500 lines: 0.0008705377578735352 minutes
# Processed 138500 lines.
# Time taken to process 500 lines: 0.0007538517316182454 minutes
# Processed 139000 lines.
# Time taken to process 500 lines: 0.000883797804514567 minutes
# Processed 139500 lines.
# Time taken to process 500 lines: 0.0008411248524983724 minutes
# Processed 140000 lines.
# Time taken to process 500 lines: 0.0008275190989176433 minutes
# Processed 140500 lines.
# Time taken to process 500 lines: 0.0008754571278889974 minutes
# Processed 141000 lines.
# Time taken to process 500 lines: 0.0008343180020650228 minutes
# Processed 141500 lines.
# Time taken to process 500 lines: 0.0008420149485270182 minutes
# Processed 142000 lines.
# Time taken to process 500 lines: 0.0008297006289164226 minutes
# Processed 142500 lines.
# Time taken to process 500 lines: 0.000775293509165446 minutes
# Processed 143000 lines.
# Time taken to process 500 lines: 0.0008010228474934895 minutes
# Processed 143500 lines.
# Time taken to process 500 lines: 0.0007889469464619955 minutes
# Processed 144000 lines.
# Time taken to process 500 lines: 0.0008316755294799805 minutes
# Processed 144500 lines.
# Time taken to process 500 lines: 0.0008223970731099446 minutes
# Processed 145000 lines.
# Time taken to process 500 lines: 0.0009092013041178385 minutes
# Processed 145500 lines.
# Time taken to process 500 lines: 0.0008739312489827474 minutes
# Processed 146000 lines.
# Time taken to process 500 lines: 0.0010323762893676759 minutes
# Processed 146500 lines.
# Time taken to process 500 lines: 0.0010372400283813477 minutes
# Processed 147000 lines.
# Time taken to process 500 lines: 0.0011032780011494955 minutes
# Processed 147500 lines.
# Time taken to process 500 lines: 0.0009085575739542644 minutes
# Processed 148000 lines.
# Time taken to process 500 lines: 0.0010531306266784667 minutes
# Processed 148500 lines.
# Time taken to process 500 lines: 0.000979785124460856 minutes
# Processed 149000 lines.
# Time taken to process 500 lines: 0.0008172790209452311 minutes
# Processed 149500 lines.
# Time taken to process 500 lines: 0.0009023745854695638 minutes
# Processed 150000 lines.
# Time taken to process 500 lines: 0.0009820342063903808 minutes
# Processed 150500 lines.
# Time taken to process 500 lines: 0.0008577148119608562 minutes
# Processed 151000 lines.
# Time taken to process 500 lines: 0.000950479507446289 minutes
# Processed 151500 lines.
# Time taken to process 500 lines: 0.000754853089650472 minutes
# Processed 152000 lines.
# Time taken to process 500 lines: 0.0012410084406534831 minutes
# Processed 152500 lines.
# Time taken to process 500 lines: 0.0008335590362548828 minutes
# Processed 153000 lines.
# Time taken to process 500 lines: 0.002885425090789795 minutes
# Processed 153500 lines.
# Time taken to process 500 lines: 0.0008745471636454265 minutes
# Processed 154000 lines.
# Time taken to process 500 lines: 0.001021262009938558 minutes
# Processed 154500 lines.
# Time taken to process 500 lines: 0.0008929888407389323 minutes
# Processed 155000 lines.
# Time taken to process 500 lines: 0.0007334033648173015 minutes
# Processed 155500 lines.
# Time taken to process 500 lines: 0.0007296125094095866 minutes
# Processed 156000 lines.
# Time taken to process 500 lines: 0.0007705648740132649 minutes
# Processed 156500 lines.
# Time taken to process 500 lines: 0.0005884607632954916 minutes
# Processed 157000 lines.
# Time taken to process 500 lines: 0.0006999731063842774 minutes
# Processed 157500 lines.
# Time taken to process 500 lines: 0.0007752537727355957 minutes
# Processed 158000 lines.
# Time taken to process 500 lines: 0.0007355729738871257 minutes
# Processed 158500 lines.
# Time taken to process 500 lines: 0.0006834944089253743 minutes
# Processed 159000 lines.
# Time taken to process 500 lines: 0.0007504900296529134 minutes
# Processed 159500 lines.
# Time taken to process 500 lines: 0.0007129708925882975 minutes
# Processed 160000 lines.
# Time taken to process 500 lines: 0.0007652401924133301 minutes
# Processed 160500 lines.
# Time taken to process 500 lines: 0.0008235414822896322 minutes
# Processed 161000 lines.
# Time taken to process 500 lines: 0.0008569876352945964 minutes
# Processed 161500 lines.
# Time taken to process 500 lines: 0.0008418083190917969 minutes
# Processed 162000 lines.
# Time taken to process 500 lines: 0.0007068753242492676 minutes
# Processed 162500 lines.
# Time taken to process 500 lines: 0.0007587552070617675 minutes
# Processed 163000 lines.
# Time taken to process 500 lines: 0.0011779467264811199 minutes
# Processed 163500 lines.
# Time taken to process 500 lines: 0.0007269581158955892 minutes
# Processed 164000 lines.
# Time taken to process 500 lines: 0.001156016190846761 minutes
# Processed 164500 lines.
# Time taken to process 500 lines: 0.0007390141487121582 minutes
# Processed 165000 lines.
# Time taken to process 500 lines: 0.0007284442583719889 minutes
# Processed 165500 lines.
# Time taken to process 500 lines: 0.0007711847623189291 minutes
# Processed 166000 lines.
# Time taken to process 500 lines: 0.0007736643155415852 minutes
# Processed 166500 lines.
# Time taken to process 500 lines: 0.0007949988047281901 minutes
# Processed 167000 lines.
# Time taken to process 500 lines: 0.0008821566899617513 minutes
# Processed 167500 lines.
# Time taken to process 500 lines: 0.0011530518531799316 minutes
# Processed 168000 lines.
# Time taken to process 500 lines: 0.0008384386698404948 minutes
# Processed 168500 lines.
# Time taken to process 500 lines: 0.0007886608441670735 minutes
# Processed 169000 lines.
# Time taken to process 500 lines: 0.0008075634638468424 minutes
# Processed 169500 lines.
# Time taken to process 500 lines: 0.0009690046310424805 minutes
# Processed 170000 lines.
# Time taken to process 500 lines: 0.0007676839828491211 minutes
# Processed 170500 lines.
# Time taken to process 500 lines: 0.0007949789365132649 minutes
# Processed 171000 lines.
# Time taken to process 500 lines: 0.0008075793584187825 minutes
# Processed 171500 lines.
# Time taken to process 500 lines: 0.0012345631917317708 minutes
# Processed 172000 lines.
# Time taken to process 500 lines: 0.0007252693176269531 minutes
# Processed 172500 lines.
# Time taken to process 500 lines: 0.0008034229278564454 minutes
# Processed 173000 lines.
# Time taken to process 500 lines: 0.0010290741920471191 minutes
# Processed 173500 lines.
# Time taken to process 500 lines: 0.0009534557660420736 minutes
# Processed 174000 lines.
# Time taken to process 500 lines: 0.0013129432996114095 minutes
# Processed 174500 lines.
# Time taken to process 500 lines: 0.0008333086967468262 minutes
# Processed 175000 lines.
# Time taken to process 500 lines: 0.0006708741188049316 minutes
# Processed 175500 lines.
# Time taken to process 500 lines: 0.0008223454157511393 minutes
# Processed 176000 lines.
# Time taken to process 500 lines: 0.0008093396822611491 minutes
# Processed 176500 lines.
# Time taken to process 500 lines: 0.0012284199396769206 minutes
# Processed 177000 lines.
# Time taken to process 500 lines: 0.0027243534723917643 minutes
# Processed 177500 lines.
# Time taken to process 500 lines: 0.0022270600001017254 minutes
# Processed 178000 lines.
# Time taken to process 500 lines: 0.0025690754254659018 minutes
# Processed 178500 lines.
# Time taken to process 500 lines: 0.0017840862274169922 minutes
# Processed 179000 lines.
# Time taken to process 500 lines: 0.001676928997039795 minutes
# Processed 179500 lines.
# Time taken to process 500 lines: 0.0019424319267272948 minutes
# Processed 180000 lines.
# Time taken to process 500 lines: 0.0015904744466145833 minutes
# Processed 180500 lines.
# Time taken to process 500 lines: 0.0010741710662841796 minutes
# Processed 181000 lines.
# Time taken to process 500 lines: 0.0012808799743652343 minutes
# Processed 181500 lines.
# Time taken to process 500 lines: 0.00125046173731486 minutes
# Processed 182000 lines.
# Time taken to process 500 lines: 0.0014182647069295247 minutes
# Processed 182500 lines.
# Time taken to process 500 lines: 0.002343893051147461 minutes
# Processed 183000 lines.
# Time taken to process 500 lines: 0.0014588713645935058 minutes
# Processed 183500 lines.
# Time taken to process 500 lines: 0.0010502219200134277 minutes
# Processed 184000 lines.
# Time taken to process 500 lines: 0.0012813925743103028 minutes
# Processed 184500 lines.
# Time taken to process 500 lines: 0.0006980220476786296 minutes
# Processed 185000 lines.
# Time taken to process 500 lines: 0.0011393268903096517 minutes
# Processed 185500 lines.
# Time taken to process 500 lines: 0.0007839322090148926 minutes
# Processed 186000 lines.
# Time taken to process 500 lines: 0.0009018937746683756 minutes
# Processed 186500 lines.
# Time taken to process 500 lines: 0.0010791420936584473 minutes
# Processed 187000 lines.
# Time taken to process 500 lines: 0.000985399881998698 minutes
# Processed 187500 lines.
# Time taken to process 500 lines: 0.000834349791208903 minutes
# Processed 188000 lines.
# Time taken to process 500 lines: 0.0015824397404988607 minutes
# Processed 188500 lines.
# Time taken to process 500 lines: 0.0010898192723592123 minutes
# Processed 189000 lines.
# Time taken to process 500 lines: 0.0015340963999430338 minutes
# Processed 189500 lines.
# Time taken to process 500 lines: 0.0014217972755432128 minutes
# Processed 190000 lines.
# Time taken to process 500 lines: 0.001186199982961019 minutes
# Processed 190500 lines.
# Time taken to process 500 lines: 0.0010361472765604656 minutes
# Processed 191000 lines.
# Time taken to process 500 lines: 0.0012066125869750976 minutes
# Processed 191500 lines.
# Time taken to process 500 lines: 0.001289530595143636 minutes
# Processed 192000 lines.
# Time taken to process 500 lines: 0.0013701796531677246 minutes
# Processed 192500 lines.
# Time taken to process 500 lines: 0.0014502207438151042 minutes
# Processed 193000 lines.
# Time taken to process 500 lines: 0.0012108246485392252 minutes
# Processed 193500 lines.
# Time taken to process 500 lines: 0.001364437739054362 minutes
# Processed 194000 lines.
# Time taken to process 500 lines: 0.0010695695877075196 minutes
# Processed 194500 lines.
# Time taken to process 500 lines: 0.0007729093233744303 minutes
# Processed 195000 lines.
# Time taken to process 500 lines: 0.0008178989092508952 minutes
# Processed 195500 lines.
# Time taken to process 500 lines: 0.0007500052452087402 minutes
# Processed 196000 lines.
# Time taken to process 500 lines: 0.0008501052856445312 minutes
# Processed 196500 lines.
# Time taken to process 500 lines: 0.0011129379272460938 minutes
# Processed 197000 lines.
# Time taken to process 500 lines: 0.000887298583984375 minutes
# Processed 197500 lines.
# Time taken to process 500 lines: 0.0014478087425231934 minutes
# Processed 198000 lines.
# Time taken to process 500 lines: 0.0012644449869791666 minutes
# Processed 198500 lines.
# Time taken to process 500 lines: 0.0007778763771057129 minutes
# Processed 199000 lines.
# Time taken to process 500 lines: 0.000937036673227946 minutes
# Processed 199500 lines.
# Time taken to process 500 lines: 0.0010078072547912598 minutes
# Processed 200000 lines.
# Time taken to process 500 lines: 0.000892039140065511 minutes
# Processed 200500 lines.
# Time taken to process 500 lines: 0.0016089240709940592 minutes
# Processed 201000 lines.
# Time taken to process 500 lines: 0.0008906165758768718 minutes
# Processed 201500 lines.
# Time taken to process 500 lines: 0.001071802775065104 minutes
# Processed 202000 lines.
# Time taken to process 500 lines: 0.0015614787737528483 minutes
# Processed 202500 lines.
# Time taken to process 500 lines: 0.000926804542541504 minutes
# Processed 203000 lines.
# Time taken to process 500 lines: 0.001027083396911621 minutes
# Processed 203500 lines.
# Time taken to process 500 lines: 0.0011192957560221355 minutes
# Processed 204000 lines.
# Time taken to process 500 lines: 0.0034145077069600424 minutes
# Processed 204500 lines.
# Time taken to process 500 lines: 0.003566579023996989 minutes
# Processed 205000 lines.
# Time taken to process 500 lines: 0.0027357180913289386 minutes
# Processed 205500 lines.
# Time taken to process 500 lines: 0.0037740270296732583 minutes
# Processed 206000 lines.
# Time taken to process 500 lines: 0.004898238182067871 minutes
# Processed 206500 lines.
# Time taken to process 500 lines: 0.005233387152353923 minutes
# Processed 207000 lines.
# Time taken to process 500 lines: 0.0017433881759643555 minutes
# Processed 207500 lines.
# Time taken to process 500 lines: 0.005353879928588867 minutes
# Processed 208000 lines.
# Time taken to process 500 lines: 0.00778961181640625 minutes
# Processed 208500 lines.
# Time taken to process 500 lines: 0.005446179707845052 minutes
# Processed 209000 lines.
# Time taken to process 500 lines: 0.006591506799062093 minutes
# Processed 209500 lines.
# Time taken to process 500 lines: 0.0019766926765441895 minutes
# Processed 210000 lines.
# Time taken to process 500 lines: 0.001159497102101644 minutes
# Processed 210500 lines.
# Time taken to process 500 lines: 0.0012807528177897136 minutes
# Processed 211000 lines.
# Time taken to process 500 lines: 0.0017369588216145833 minutes
# Processed 211500 lines.
# Time taken to process 500 lines: 0.0006843527158101399 minutes
# Processed 212000 lines.
# Time taken to process 500 lines: 0.0012927889823913575 minutes
# Processed 212500 lines.
# Time taken to process 500 lines: 0.0008586565653483073 minutes
# Processed 213000 lines.
# Time taken to process 500 lines: 0.00155407985051473 minutes
# Processed 213500 lines.
# Time taken to process 500 lines: 0.001882350444793701 minutes
# Processed 214000 lines.
# Time taken to process 500 lines: 0.0012702465057373047 minutes
# Processed 214500 lines.
# Time taken to process 500 lines: 0.0018972317377726237 minutes
# Processed 215000 lines.
# Time taken to process 500 lines: 0.0015947858492533365 minutes
# Processed 215500 lines.
# Time taken to process 500 lines: 0.0008765260378519694 minutes
# Processed 216000 lines.
# Time taken to process 500 lines: 0.0007496476173400879 minutes
# Processed 216500 lines.
# Time taken to process 500 lines: 0.0012533108393351236 minutes
# Processed 217000 lines.
# Time taken to process 500 lines: 0.0009892821311950684 minutes
# Processed 217500 lines.
# Time taken to process 500 lines: 0.0009792248407999675 minutes
# Processed 218000 lines.
# Time taken to process 500 lines: 0.00092087189356486 minutes
# Processed 218500 lines.
# Time taken to process 500 lines: 0.0007323066393534343 minutes
# Processed 219000 lines.
# Time taken to process 500 lines: 0.00039167404174804686 minutes
# Processed 219500 lines.
# Time taken to process 500 lines: 0.0005166808764139811 minutes
# Processed 220000 lines.
# Time taken to process 500 lines: 0.0005980928738911947 minutes
# Processed 220500 lines.
# Time taken to process 500 lines: 0.00037972132364908856 minutes
# Processed 221000 lines.
# Time taken to process 500 lines: 0.0006082375844319661 minutes
# Processed 221500 lines.
# Time taken to process 500 lines: 0.0002920349438985189 minutes
# Processed 222000 lines.
# Time taken to process 500 lines: 0.00018334786097208658 minutes
# Processed 222500 lines.
# Time taken to process 500 lines: 0.00018331607182820638 minutes
# Processed 223000 lines.
# Time taken to process 500 lines: 0.00016659895579020182 minutes
# Processed 223500 lines.
# Time taken to process 500 lines: 0.00018171072006225585 minutes
# Processed 224000 lines.
# Time taken to process 500 lines: 0.00018341938654581707 minutes
# Processed 224500 lines.
# Time taken to process 500 lines: 0.00015475749969482422 minutes
# Processed 225000 lines.
# Time taken to process 500 lines: 0.0002500732739766439 minutes
# Processed 225500 lines.
# Time taken to process 500 lines: 0.0002669890721638997 minutes
# Processed 226000 lines.
# Time taken to process 500 lines: 0.0008486708005269369 minutes
# Processed 226500 lines.
# Time taken to process 500 lines: 0.0013648033142089843 minutes
# Processed 227000 lines.
# Time taken to process 500 lines: 0.000646527608235677 minutes
# Processed 227500 lines.
# Time taken to process 500 lines: 0.000831751028696696 minutes
# Processed 228000 lines.
# Time taken to process 500 lines: 0.003155656655629476 minutes
# Processed 228500 lines.
# Time taken to process 500 lines: 0.0008572459220886231 minutes
# Processed 229000 lines.
# Time taken to process 500 lines: 0.0008308927218119304 minutes
# Processed 229500 lines.
# Time taken to process 500 lines: 0.0016773422559102377 minutes
# Processed 230000 lines.
# Time taken to process 500 lines: 0.0015653133392333984 minutes
# Processed 230500 lines.
# Time taken to process 500 lines: 0.0029064178466796874 minutes
# Processed 231000 lines.
# Time taken to process 500 lines: 0.0014296452204386394 minutes
# Processed 231500 lines.
# Time taken to process 500 lines: 0.0010753154754638671 minutes
# Processed 232000 lines.
# Time taken to process 500 lines: 0.0022661606470743816 minutes
# Processed 232500 lines.
# Time taken to process 500 lines: 0.001156628131866455 minutes
# Processed 233000 lines.
# Time taken to process 500 lines: 0.0014780799547831217 minutes
# Processed 233500 lines.
# Time taken to process 500 lines: 0.003167728583017985 minutes
# Processed 234000 lines.
# Time taken to process 500 lines: 0.00248874028523763 minutes
# Processed 234500 lines.
# Time taken to process 500 lines: 0.0020714759826660155 minutes
# Processed 235000 lines.
# Time taken to process 500 lines: 0.0013358235359191895 minutes
# Processed 235500 lines.
# Time taken to process 500 lines: 0.0014975508054097494 minutes
# Processed 236000 lines.
# Time taken to process 500 lines: 0.0017053524653116861 minutes
# Processed 236500 lines.
# Time taken to process 500 lines: 0.0017443656921386718 minutes
# Processed 237000 lines.
# Time taken to process 500 lines: 0.0017433643341064453 minutes
# Processed 237500 lines.
# Time taken to process 500 lines: 0.001607807477315267 minutes
# Processed 238000 lines.
# Time taken to process 500 lines: 0.0028656601905822756 minutes
# Processed 238500 lines.
# Time taken to process 500 lines: 0.002953811486562093 minutes
# Processed 239000 lines.
# Time taken to process 500 lines: 0.0015644192695617675 minutes
# Processed 239500 lines.
# Time taken to process 500 lines: 0.002001345157623291 minutes
# Processed 240000 lines.
# Time taken to process 500 lines: 0.0018033186594645183 minutes
# Processed 240500 lines.
# Time taken to process 500 lines: 0.0013086001078287761 minutes
# Processed 241000 lines.
# Time taken to process 500 lines: 0.0006167173385620117 minutes
# Processed 241500 lines.
# Time taken to process 500 lines: 0.00027676026026407876 minutes
# Processed 242000 lines.
# Time taken to process 500 lines: 0.00021965503692626952 minutes
# Processed 242500 lines.
# Time taken to process 500 lines: 0.0018142183621724446 minutes
# Processed 243000 lines.
# Time taken to process 500 lines: 0.0016905546188354492 minutes
# Processed 243500 lines.
# Time taken to process 500 lines: 0.0025435646375020346 minutes
# Processed 244000 lines.
# Time taken to process 500 lines: 0.0019231836001078288 minutes
# Processed 244500 lines.
# Time taken to process 500 lines: 0.0011476755142211914 minutes
# Processed 245000 lines.
# Time taken to process 500 lines: 0.0002691984176635742 minutes
# Processed 245500 lines.
# Time taken to process 500 lines: 0.000311283270517985 minutes
# Processed 246000 lines.
# Time taken to process 500 lines: 0.0010967254638671875 minutes
# Processed 246500 lines.
# Time taken to process 500 lines: 0.001790150006612142 minutes
# Processed 247000 lines.
# Time taken to process 500 lines: 0.001954344908396403 minutes
# Processed 247500 lines.
# Time taken to process 500 lines: 0.001305365562438965 minutes
# Processed 248000 lines.
# Time taken to process 500 lines: 0.0017617026964823405 minutes
# Processed 248500 lines.
# Time taken to process 500 lines: 0.0018530567487080893 minutes
# Processed 249000 lines.
# Time taken to process 500 lines: 0.001532729466756185 minutes
# Processed 249500 lines.
# Time taken to process 500 lines: 0.00092620054880778 minutes
# Processed 250000 lines.
# Time taken to process 500 lines: 0.0010529160499572754 minutes
# Processed 250500 lines.
# Time taken to process 500 lines: 0.001695076624552409 minutes
# Processed 251000 lines.
# Time taken to process 500 lines: 0.0018784562746683756 minutes
# Processed 251500 lines.
# Time taken to process 500 lines: 0.00214385986328125 minutes
# Processed 252000 lines.
# Time taken to process 500 lines: 0.001256553332010905 minutes
# Processed 252500 lines.
# Time taken to process 500 lines: 0.0012680808703104654 minutes
# Processed 253000 lines.
# Time taken to process 500 lines: 0.0009650786717732748 minutes
# Processed 253500 lines.
# Time taken to process 500 lines: 0.001997498671213786 minutes
# Processed 254000 lines.
# Time taken to process 500 lines: 0.0013562758763631185 minutes
# Processed 254500 lines.
# Time taken to process 500 lines: 0.0016606251398722331 minutes
# Processed 255000 lines.
# Time taken to process 500 lines: 0.0014867305755615235 minutes
# Processed 255500 lines.
# Time taken to process 500 lines: 0.001659115155537923 minutes
# Processed 256000 lines.
# Time taken to process 500 lines: 0.0018192092577616374 minutes
# Processed 256500 lines.
# Time taken to process 500 lines: 0.0007906715075174967 minutes
# Processed 257000 lines.
# Time taken to process 500 lines: 0.0008088350296020508 minutes
# Processed 257500 lines.
# Time taken to process 500 lines: 0.000829780101776123 minutes
# Processed 258000 lines.
# Time taken to process 500 lines: 0.0006672263145446778 minutes
# Processed 258500 lines.
# Time taken to process 500 lines: 0.0007379531860351562 minutes
# Processed 259000 lines.
# Time taken to process 500 lines: 0.0007692178090413412 minutes
# Processed 259500 lines.
# Time taken to process 500 lines: 0.0014288862546284994 minutes
# Processed 260000 lines.
# Time taken to process 500 lines: 0.001568897565205892 minutes
# Processed 260500 lines.
# Time taken to process 500 lines: 0.002066679795583089 minutes
# Processed 261000 lines.
# Time taken to process 500 lines: 0.0017968138058980306 minutes
# Processed 261500 lines.
# Time taken to process 500 lines: 0.0010282437006632486 minutes
# Processed 262000 lines.
# Time taken to process 500 lines: 0.0011925935745239259 minutes
# Processed 262500 lines.
# Time taken to process 500 lines: 0.0008170684178670247 minutes
# Processed 263000 lines.
# Time taken to process 500 lines: 0.0014366666475931803 minutes
# Processed 263500 lines.
# Time taken to process 500 lines: 0.0013802409172058105 minutes
# Processed 264000 lines.
# Time taken to process 500 lines: 0.0010814666748046875 minutes
# Processed 264500 lines.
# Time taken to process 500 lines: 0.002117009957631429 minutes
# Processed 265000 lines.
# Time taken to process 500 lines: 0.0011476874351501465 minutes
# Processed 265500 lines.
# Time taken to process 500 lines: 0.0013695200284322103 minutes
# Processed 266000 lines.
# Time taken to process 500 lines: 0.0015361269315083822 minutes
# Processed 266500 lines.
# Time taken to process 500 lines: 0.0014301697413126627 minutes
# Processed 267000 lines.
# Time taken to process 500 lines: 0.0009941458702087402 minutes
# Processed 267500 lines.
# Time taken to process 500 lines: 0.0013684868812561036 minutes
# Processed 268000 lines.
# Time taken to process 500 lines: 0.0011682709058125813 minutes
# Processed 268500 lines.
# Time taken to process 500 lines: 0.0011588215827941894 minutes
# Processed 269000 lines.
# Time taken to process 500 lines: 0.001371475060780843 minutes
# Processed 269500 lines.
# Time taken to process 500 lines: 0.0010047276814778646 minutes
# Processed 270000 lines.
# Time taken to process 500 lines: 0.001003575325012207 minutes
# Processed 270500 lines.
# Time taken to process 500 lines: 0.0012144724527994792 minutes
# Processed 271000 lines.
# Time taken to process 500 lines: 0.003839397430419922 minutes
# Processed 271500 lines.
# Time taken to process 500 lines: 0.001853013038635254 minutes
# Processed 272000 lines.
# Time taken to process 500 lines: 0.0018112659454345703 minutes
# Processed 272500 lines.
# Time taken to process 500 lines: 0.0020236611366271974 minutes
# Processed 273000 lines.
# Time taken to process 500 lines: 0.0018076419830322266 minutes
# Processed 273500 lines.
# Time taken to process 500 lines: 0.0015529314676920572 minutes
# Processed 274000 lines.
# Time taken to process 500 lines: 0.0013508399327596028 minutes
# Processed 274500 lines.
# Time taken to process 500 lines: 0.0012503226598103842 minutes
# Processed 275000 lines.
# Time taken to process 500 lines: 0.0017281810442606607 minutes
# Processed 275500 lines.
# Time taken to process 500 lines: 0.0012318094571431477 minutes
# Processed 276000 lines.
# Time taken to process 500 lines: 0.0011963089307149251 minutes
# Processed 276500 lines.
# Time taken to process 500 lines: 0.0009028434753417969 minutes
# Processed 277000 lines.
# Time taken to process 500 lines: 0.0011472463607788085 minutes
# Processed 277500 lines.
# Time taken to process 500 lines: 0.0013628204663594563 minutes
# Processed 278000 lines.
# ...
# Processed 480000 lines.
# Time taken to process 500 lines: 0.001546915372212728 minutes
# Processed 480500 lines.
# Time taken to process 500 lines: 0.0007594466209411621 minutes
# Processed 481000 lines.
# Time taken to process 500 lines: 0.0009875218073527017 minutes
# Processed 481500 lines.
# Time taken to process 500 lines: 0.00082549254099528 minutes
# Processed 482000 lines.
# Time taken to process 500 lines: 0.0014323671658833823 minutes
# Processed 482500 lines.
# Time taken to process 500 lines: 0.001014578342437744 minutes
# Processed 483000 lines.
# Time taken to process 500 lines: 0.0016432007153828938 minutes
# Processed 483500 lines.
# Time taken to process 500 lines: 0.0019704023996988933 minutes
# Processed 484000 lines.
# Time taken to process 500 lines: 0.0011278311411539713 minutes
# Processed 484500 lines.
# Time taken to process 500 lines: 0.0010849754015604654 minutes
# Processed 485000 lines.
# Time taken to process 500 lines: 0.0013558546702067058 minutes
# Processed 485500 lines.
# Time taken to process 500 lines: 0.0015617847442626954 minutes
# Processed 486000 lines.
# Time taken to process 500 lines: 0.0008688012758890788 minutes
# Processed 486500 lines.
# Time taken to process 500 lines: 0.0009561141331990559 minutes
# Processed 487000 lines.
# Time taken to process 500 lines: 0.0009737292925516765 minutes
# Processed 487500 lines.
# Time taken to process 500 lines: 0.0008090774218241374 minutes
# Processed 488000 lines.
# Time taken to process 500 lines: 0.0009947419166564941 minutes
# Processed 488500 lines.
# Time taken to process 500 lines: 0.0012618740399678548 minutes
# Processed 489000 lines.
# Time taken to process 500 lines: 0.0012833237648010253 minutes
# Processed 489500 lines.
# Time taken to process 500 lines: 0.0009220719337463378 minutes
# Processed 490000 lines.
# Time taken to process 500 lines: 0.0009897271792093912 minutes
# Processed 490500 lines.
# Time taken to process 500 lines: 0.0009671688079833984 minutes
# Processed 491000 lines.
# Time taken to process 500 lines: 0.0007794817288716634 minutes
# Processed 491500 lines.
# Time taken to process 500 lines: 0.001231086254119873 minutes
# Processed 492000 lines.
# Time taken to process 500 lines: 0.0007489403088887532 minutes
# Processed 492500 lines.
# Time taken to process 500 lines: 0.0009697675704956055 minutes
# Processed 493000 lines.
# Time taken to process 500 lines: 0.0008660793304443359 minutes
# Processed 493500 lines.
# Time taken to process 500 lines: 0.0008029739061991373 minutes
# Processed 494000 lines.
# Time taken to process 500 lines: 0.0006377577781677246 minutes
# Processed 494500 lines.
# Time taken to process 500 lines: 0.0007939696311950684 minutes
# Processed 495000 lines.
# Time taken to process 500 lines: 0.0007834593454996745 minutes
# Processed 495500 lines.
# Time taken to process 500 lines: 0.0007963935534159342 minutes
# Processed 496000 lines.
# Time taken to process 500 lines: 0.0006229718526204427 minutes
# Processed 496500 lines.
# Time taken to process 500 lines: 0.0008081833521525066 minutes
# Processed 497000 lines.
# Time taken to process 500 lines: 0.0008587519327799479 minutes
# Processed 497500 lines.
# Time taken to process 500 lines: 0.0006488323211669922 minutes
# Processed 498000 lines.
# Time taken to process 500 lines: 0.0025385618209838867 minutes
# Processed 498500 lines.
# Time taken to process 500 lines: 0.0015547474225362141 minutes
# Processed 499000 lines.
# Time taken to process 500 lines: 0.0009789784749348958 minutes
# Processed 499500 lines.
# Time taken to process 500 lines: 0.001310118039449056 minutes
# Processed 500000 lines.
# Time taken to process 500 lines: 0.001038209597269694 minutes
# Processed 500500 lines.
# Time taken to process 500 lines: 0.0008589863777160644 minutes
# Processed 501000 lines.
# Time taken to process 500 lines: 0.0010191480318705241 minutes
# Processed 501500 lines.
# Time taken to process 500 lines: 0.0010804375012715658 minutes
# Processed 502000 lines.
# Time taken to process 500 lines: 0.0018830219904581705 minutes
# Processed 502500 lines.
# Time taken to process 500 lines: 0.0025019009908040365 minutes
# Processed 503000 lines.
# Time taken to process 500 lines: 0.0026663462320963543 minutes
# Processed 503500 lines.
# Time taken to process 500 lines: 0.0023710052172342937 minutes
# Processed 504000 lines.
# Time taken to process 500 lines: 0.0026984930038452147 minutes
# Processed 504500 lines.
# Time taken to process 500 lines: 0.0026564717292785643 minutes
# Processed 505000 lines.
# Time taken to process 500 lines: 0.001943679650624593 minutes
# Processed 505500 lines.
# Time taken to process 500 lines: 0.0021879037221272787 minutes
# Processed 506000 lines.
# Time taken to process 500 lines: 0.0016725500424702962 minutes
# Processed 506500 lines.
# Time taken to process 500 lines: 0.0008408784866333008 minutes
# Processed 507000 lines.
# Time taken to process 500 lines: 0.0007445812225341797 minutes
# Processed 507500 lines.
# Time taken to process 500 lines: 0.0007979154586791992 minutes
# Processed 508000 lines.
# Time taken to process 500 lines: 0.0007262229919433594 minutes
# Processed 508500 lines.
# Time taken to process 500 lines: 0.0006474057833353678 minutes
# Processed 509000 lines.
# Time taken to process 500 lines: 0.0007180929183959961 minutes
# Processed 509500 lines.
# Time taken to process 500 lines: 0.0005638837814331054 minutes
# Processed 510000 lines.
# Time taken to process 500 lines: 0.0006246328353881836 minutes
# Processed 510500 lines.
# Time taken to process 500 lines: 0.0005422155062357585 minutes
# Processed 511000 lines.
# Time taken to process 500 lines: 0.0006695389747619629 minutes
# Processed 511500 lines.
# Time taken to process 500 lines: 0.0007031520207722981 minutes
# Processed 512000 lines.
# Time taken to process 500 lines: 0.0005564570426940918 minutes
# Processed 512500 lines.
# Time taken to process 500 lines: 0.0006858309110005697 minutes
# Processed 513000 lines.
# Time taken to process 500 lines: 0.0007218122482299805 minutes
# Processed 513500 lines.
# Time taken to process 500 lines: 0.0010922551155090332 minutes
# Processed 514000 lines.
# Time taken to process 500 lines: 0.001085821787516276 minutes
# Processed 514500 lines.
# Time taken to process 500 lines: 0.0011263688405354817 minutes
# Processed 515000 lines.
# Time taken to process 500 lines: 0.0012615402539571127 minutes
# Processed 515500 lines.
# Time taken to process 500 lines: 0.001058026154836019 minutes
# Processed 516000 lines.
# Time taken to process 500 lines: 0.0006022969881693522 minutes
# Processed 516500 lines.
# Time taken to process 500 lines: 0.0007096529006958008 minutes
# Processed 517000 lines.
# Time taken to process 500 lines: 0.00047537883122762047 minutes
# Processed 517500 lines.
# Time taken to process 500 lines: 0.0005888064702351888 minutes
# Processed 518000 lines.
# Time taken to process 500 lines: 0.0005741079648335774 minutes
# Processed 518500 lines.
# Time taken to process 500 lines: 0.001010278860727946 minutes
# Processed 519000 lines.
# Time taken to process 500 lines: 0.0006801327069600423 minutes
# Processed 519500 lines.
# Time taken to process 500 lines: 0.0005103349685668945 minutes
# Processed 520000 lines.
# Time taken to process 500 lines: 0.0004667480786641439 minutes
# Processed 520500 lines.
# Time taken to process 500 lines: 0.0005625486373901367 minutes
# Processed 521000 lines.
# Time taken to process 500 lines: 0.000559075673421224 minutes
# Processed 521500 lines.
# Time taken to process 500 lines: 0.0004999995231628418 minutes
# Processed 522000 lines.
# Time taken to process 500 lines: 0.0005565841992696126 minutes
# Processed 522500 lines.
# Time taken to process 500 lines: 0.0005002061525980632 minutes
# Processed 523000 lines.
# Time taken to process 500 lines: 0.00045342048009236653 minutes
# Processed 523500 lines.
# Time taken to process 500 lines: 0.00046671628952026366 minutes
# Processed 524000 lines.
# Time taken to process 500 lines: 0.0005123615264892578 minutes
# Processed 524500 lines.
# Time taken to process 500 lines: 0.000579531987508138 minutes
# Processed 525000 lines.
# Time taken to process 500 lines: 0.0004943092664082845 minutes
# Processed 525500 lines.
# Time taken to process 500 lines: 0.0008650978406270345 minutes
# Processed 526000 lines.
# Time taken to process 500 lines: 0.0009892741839090983 minutes
# Processed 526500 lines.
# Time taken to process 500 lines: 0.0011033336321512857 minutes
# Processed 527000 lines.
# Time taken to process 500 lines: 0.000587924321492513 minutes
# Processed 527500 lines.
# Time taken to process 500 lines: 0.0006858468055725098 minutes
# Processed 528000 lines.
# Time taken to process 500 lines: 0.0008158008257548014 minutes
# Processed 528500 lines.
# Time taken to process 500 lines: 0.0006194670995076497 minutes
# Processed 529000 lines.
# Time taken to process 500 lines: 0.000670472780863444 minutes
# Processed 529500 lines.
# Time taken to process 500 lines: 0.0007814725240071614 minutes
# Processed 530000 lines.
# Time taken to process 500 lines: 0.0010874470074971516 minutes
# Processed 530500 lines.
# Time taken to process 500 lines: 0.0007173458735148112 minutes
# Processed 531000 lines.
# Time taken to process 500 lines: 0.000639339288075765 minutes
# Processed 531500 lines.
# Time taken to process 500 lines: 0.0007173935572306315 minutes
# Processed 532000 lines.
# Time taken to process 500 lines: 0.0008606354395548503 minutes
# Processed 532500 lines.
# Time taken to process 500 lines: 0.0012091398239135742 minutes
# Processed 533000 lines.
# Time taken to process 500 lines: 0.0009508728981018066 minutes
# Processed 533500 lines.
# Time taken to process 500 lines: 0.0009234189987182617 minutes
# Processed 534000 lines.
# Time taken to process 500 lines: 0.0008489251136779785 minutes
# Processed 534500 lines.
# Time taken to process 500 lines: 0.000876617431640625 minutes
# Processed 535000 lines.
# Time taken to process 500 lines: 0.0011094252268473307 minutes
# Processed 535500 lines.
# Time taken to process 500 lines: 0.0009949763615926107 minutes
# Processed 536000 lines.
# Time taken to process 500 lines: 0.0010138869285583497 minutes
# Processed 536500 lines.
# Time taken to process 500 lines: 0.0008128722508748373 minutes
# Processed 537000 lines.
# Time taken to process 500 lines: 0.0011151790618896484 minutes
# Processed 537500 lines.
# Time taken to process 500 lines: 0.0011419097582499186 minutes
# Processed 538000 lines.
# Time taken to process 500 lines: 0.0017933448155721028 minutes
# Processed 538500 lines.
# Time taken to process 500 lines: 0.0012317736943562826 minutes
# Processed 539000 lines.
# Time taken to process 500 lines: 0.001426553726196289 minutes
# Processed 539500 lines.
# Time taken to process 500 lines: 0.00132828156153361 minutes
# Processed 540000 lines.
# Time taken to process 500 lines: 0.0012770295143127441 minutes
# Processed 540500 lines.
# Time taken to process 500 lines: 0.0013291041056315105 minutes
# Processed 541000 lines.
# Time taken to process 500 lines: 0.001017749309539795 minutes
# Processed 541500 lines.
# Time taken to process 500 lines: 0.0011401414871215821 minutes
# Processed 542000 lines.
# Time taken to process 500 lines: 0.0013177633285522462 minutes
# Processed 542500 lines.
# Time taken to process 500 lines: 0.0010187546412150064 minutes
# Processed 543000 lines.
# Time taken to process 500 lines: 0.0011487682660420737 minutes
# Processed 543500 lines.
# Time taken to process 500 lines: 0.0013147513071695963 minutes
# Processed 544000 lines.
# Time taken to process 500 lines: 0.0013121684392293294 minutes
# Processed 544500 lines.
# Time taken to process 500 lines: 0.0012224276860555014 minutes
# Processed 545000 lines.
# Time taken to process 500 lines: 0.0012287179629007976 minutes
# Processed 545500 lines.
# Time taken to process 500 lines: 0.0012034177780151367 minutes
# Processed 546000 lines.
# Time taken to process 500 lines: 0.0011793057123819987 minutes
# Processed 546500 lines.
# Time taken to process 500 lines: 0.0008369684219360352 minutes
# Processed 547000 lines.
# Time taken to process 500 lines: 0.0010744055112202962 minutes
# Processed 547500 lines.
# Time taken to process 500 lines: 0.0012583772341410318 minutes
# Processed 548000 lines.
# Time taken to process 500 lines: 0.0016069849332173666 minutes
# Processed 548500 lines.
# Time taken to process 500 lines: 0.0010877251625061035 minutes
# Processed 549000 lines.
# Time taken to process 500 lines: 0.0013641079266866049 minutes
# Processed 549500 lines.
# Time taken to process 500 lines: 0.0011539975802103677 minutes
# Processed 550000 lines.
# Time taken to process 500 lines: 0.0017217159271240234 minutes
# Processed 550500 lines.
# Time taken to process 500 lines: 0.0014854987462361653 minutes
# Processed 551000 lines.
# Time taken to process 500 lines: 0.0012743353843688964 minutes
# Processed 551500 lines.
# Time taken to process 500 lines: 0.0011057058970133464 minutes
# Processed 552000 lines.
# Time taken to process 500 lines: 0.00118563175201416 minutes
# Processed 552500 lines.
# Time taken to process 500 lines: 0.0010030229886372885 minutes
# Processed 553000 lines.
# Time taken to process 500 lines: 0.0012725234031677247 minutes
# Processed 553500 lines.
# Time taken to process 500 lines: 0.0010482509930928548 minutes
# Processed 554000 lines.
# Time taken to process 500 lines: 0.0010253310203552247 minutes
# Processed 554500 lines.
# Time taken to process 500 lines: 0.0010959506034851074 minutes
# Processed 555000 lines.
# Time taken to process 500 lines: 0.0009954373041788738 minutes
# Processed 555500 lines.
# Time taken to process 500 lines: 0.0009344100952148437 minutes
# Processed 556000 lines.
# Time taken to process 500 lines: 0.0010288000106811524 minutes
# Processed 556500 lines.
# Time taken to process 500 lines: 0.0012420852979024251 minutes
# Processed 557000 lines.
# Time taken to process 500 lines: 0.0012496113777160645 minutes
# Processed 557500 lines.
# Time taken to process 500 lines: 0.0008371432622273763 minutes
# Processed 558000 lines.
# Time taken to process 500 lines: 0.000705858071645101 minutes
# Processed 558500 lines.
# Time taken to process 500 lines: 0.0007455110549926758 minutes
# Processed 559000 lines.
# Time taken to process 500 lines: 0.0007502079010009765 minutes
# Processed 559500 lines.
# Time taken to process 500 lines: 0.0006861011187235514 minutes
# Processed 560000 lines.
# Time taken to process 500 lines: 0.0009833852450052897 minutes
# Processed 560500 lines.
# Time taken to process 500 lines: 0.000637356440226237 minutes
# Processed 561000 lines.
# Time taken to process 500 lines: 0.0007682879765828451 minutes
# Processed 561500 lines.
# Time taken to process 500 lines: 0.0007752736409505208 minutes
# Processed 562000 lines.
# Time taken to process 500 lines: 0.0011898159980773925 minutes
# Processed 562500 lines.
# Time taken to process 500 lines: 0.0006726384162902832 minutes
# Processed 563000 lines.
# Time taken to process 500 lines: 0.0009766062100728353 minutes
# Processed 563500 lines.
# Time taken to process 500 lines: 0.0007217208544413249 minutes
# Processed 564000 lines.
# Time taken to process 500 lines: 0.0007769346237182617 minutes
# Processed 564500 lines.
# Time taken to process 500 lines: 0.0011283795038859049 minutes
# Processed 565000 lines.
# Time taken to process 500 lines: 0.001758265495300293 minutes
# Processed 565500 lines.
# Time taken to process 500 lines: 0.001986273129781087 minutes
# Processed 566000 lines.
# Time taken to process 500 lines: 0.002638836701711019 minutes
# Processed 566500 lines.
# Time taken to process 500 lines: 0.0009334286053975424 minutes
# Processed 567000 lines.
# Time taken to process 500 lines: 0.0010573307673136393 minutes
# Processed 567500 lines.
# Time taken to process 500 lines: 0.0011490424474080404 minutes
# Processed 568000 lines.
# Time taken to process 500 lines: 0.0016615947087605795 minutes
# Processed 568500 lines.
# Time taken to process 500 lines: 0.0017559329668680828 minutes
# Processed 569000 lines.
# Time taken to process 500 lines: 0.001767281691233317 minutes
# Processed 569500 lines.
# Time taken to process 500 lines: 0.00144042174021403 minutes
# Processed 570000 lines.
# Time taken to process 500 lines: 0.001783589522043864 minutes
# Processed 570500 lines.
# Time taken to process 500 lines: 0.0015170971552530925 minutes
# Processed 571000 lines.
# Time taken to process 500 lines: 0.001851963996887207 minutes
# Processed 571500 lines.
# Time taken to process 500 lines: 0.0022226770718892417 minutes

# %%
def read_json_and_sample(file_path, key_left = key_left, key_right = key_right, left_dict = left_dict, right_dict = right_dict):
    ''' Read the JSON file line by line and if bill text exists and if bill id and state match from our unique bills found from
    sampling alignments data then append and convert to dataframe with all metadata.'''
    
    # Dictionary to store all bills, keyed by state
    matched_bills = []
    start = time.time()

    with open(file_path, 'r', encoding='utf-8') as file:
            line_count = 0  # Initialize line counter
            for line in file:
                try:
                    bill = json.loads(line.strip())
                    billnum = bill.get('bill_id').replace(' ', '')  # Remove whitespace

                    state = bill.get('state').lower()  # Convert state to lowercase

                    # Check if the bill_id is in key_left or key_right
                    if billnum in key_left:
                        print(billnum)
                        expected_state = left_dict.get(billnum).lower()  # Get corresponding state and convert to lowercase
                        if expected_state == state:  # Compare the states
                            matched_bills.append(bill)  # Append the bill

                    elif billnum in key_right:
                        expected_state = right_dict.get(billnum, '').lower()  # Get corresponding state and convert to lowercase
                        if expected_state == state:  # Compare the states
                            matched_bills.append(bill)  # Append the bill

                    line_count += 1
                    if line_count % 500 == 0:  # Print progress every 500 lines
                        print(f"Processed {line_count} lines.")
                        end = time.time()
                        time_taken = (end - start) / 60
                        print(f'Time taken to process 500 lines: {time_taken} minutes')
                        start = time.time()
                except json.JSONDecodeError as e:
                    print(f"Error decoding JSON: {e}")

    matched_bills_df = pd.DataFrame(matched_bills)
    return matched_bills_df

file_path = './Data/state_bills.json'

# %%
all_bills = read_json_and_sample('./Data/state_bills.json')
# Out:
# Processed 500 lines.
# Time taken to process 500 lines: 0.0010923107465108236 minutes
# Processed 1000 lines.
# Time taken to process 500 lines: 0.0007870276769002279 minutes
# Processed 1500 lines.
# Time taken to process 500 lines: 0.0007864753405253093 minutes
# Processed 2000 lines.
# Time taken to process 500 lines: 0.0008180141448974609 minutes
# Processed 2500 lines.
# Time taken to process 500 lines: 0.0007648944854736328 minutes
# Processed 3000 lines.
# Time taken to process 500 lines: 0.0007667740186055502 minutes
# Processed 3500 lines.
# Time taken to process 500 lines: 0.0009121974309285482 minutes
# Processed 4000 lines.
# Time taken to process 500 lines: 0.0007108211517333985 minutes
# Processed 4500 lines.
# Time taken to process 500 lines: 0.00075989564259847 minutes
# Processed 5000 lines.
# Time taken to process 500 lines: 0.0007753372192382812 minutes
# Processed 5500 lines.
# Time taken to process 500 lines: 0.0006702939669291178 minutes
# Processed 6000 lines.
# Time taken to process 500 lines: 0.0007707516352335612 minutes
# Processed 6500 lines.
# Time taken to process 500 lines: 0.0006921688715616862 minutes
# Processed 7000 lines.
# Time taken to process 500 lines: 0.0008228699366251628 minutes
# Processed 7500 lines.
# Time taken to process 500 lines: 0.000612942377726237 minutes
# Processed 8000 lines.
# Time taken to process 500 lines: 0.0007044672966003418 minutes
# Processed 8500 lines.
# Time taken to process 500 lines: 0.0008513768513997396 minutes
# Processed 9000 lines.
# Time taken to process 500 lines: 0.00067902406056722 minutes
# Processed 9500 lines.
# Time taken to process 500 lines: 0.0006133119265238444 minutes
# Processed 10000 lines.
# Time taken to process 500 lines: 0.0006630579630533854 minutes
# Processed 10500 lines.
# Time taken to process 500 lines: 0.0006444374720255534 minutes
# Processed 11000 lines.
# Time taken to process 500 lines: 0.000877221425374349 minutes
# Processed 11500 lines.
# Time taken to process 500 lines: 0.0007361888885498047 minutes
# Processed 12000 lines.
# Time taken to process 500 lines: 0.0007943789164225261 minutes
# Processed 12500 lines.
# Time taken to process 500 lines: 0.0007329066594441732 minutes
# Processed 13000 lines.
# Time taken to process 500 lines: 0.0006009896596272786 minutes
# Processed 13500 lines.
# Time taken to process 500 lines: 0.000797116756439209 minutes
# Processed 14000 lines.
# Time taken to process 500 lines: 0.000669403870900472 minutes
# Processed 14500 lines.
# Time taken to process 500 lines: 0.0006772677103678385 minutes
# Processed 15000 lines.
# Time taken to process 500 lines: 0.000866695245107015 minutes
# Processed 15500 lines.
# Time taken to process 500 lines: 0.0007240494092305501 minutes
# Processed 16000 lines.
# Time taken to process 500 lines: 0.001181169350941976 minutes
# Processed 16500 lines.
# Time taken to process 500 lines: 0.0009650429089864095 minutes
# Processed 17000 lines.
# Time taken to process 500 lines: 0.0009932518005371094 minutes
# Processed 17500 lines.
# Time taken to process 500 lines: 0.0007599512736002604 minutes
# Processed 18000 lines.
# Time taken to process 500 lines: 0.0009251912434895833 minutes
# Processed 18500 lines.
# Time taken to process 500 lines: 0.0007776021957397461 minutes
# Processed 19000 lines.
# Time taken to process 500 lines: 0.0007484992345174154 minutes
# Processed 19500 lines.
# Time taken to process 500 lines: 0.0010758519172668457 minutes
# Processed 20000 lines.
# Time taken to process 500 lines: 0.0011428554852803549 minutes
# Processed 20500 lines.
# Time taken to process 500 lines: 0.0015682935714721679 minutes
# Processed 21000 lines.
# Time taken to process 500 lines: 0.0012245893478393555 minutes
# Processed 21500 lines.
# Time taken to process 500 lines: 0.001206827163696289 minutes
# Processed 22000 lines.
# Time taken to process 500 lines: 0.0008512576421101888 minutes
# Processed 22500 lines.
# Time taken to process 500 lines: 0.0008705417315165202 minutes
# Processed 23000 lines.
# Time taken to process 500 lines: 0.0010373512903849283 minutes
# Processed 23500 lines.
# Time taken to process 500 lines: 0.00237733523050944 minutes
# Processed 24000 lines.
# Time taken to process 500 lines: 0.0017259558041890462 minutes
# Processed 24500 lines.
# Time taken to process 500 lines: 0.0016473491986592611 minutes
# Processed 25000 lines.
# Time taken to process 500 lines: 0.0010063489278157552 minutes
# Processed 25500 lines.
# Time taken to process 500 lines: 0.0011355161666870117 minutes
# Processed 26000 lines.
# Time taken to process 500 lines: 0.0008308609326680501 minutes
# Processed 26500 lines.
# Time taken to process 500 lines: 0.0012580990791320802 minutes
# Processed 27000 lines.
# Time taken to process 500 lines: 0.0009009758631388346 minutes
# Processed 27500 lines.
# Time taken to process 500 lines: 0.0009512702624003092 minutes
# Processed 28000 lines.
# Time taken to process 500 lines: 0.000828393300374349 minutes
# Processed 28500 lines.
# Time taken to process 500 lines: 0.0009654005368550619 minutes
# Processed 29000 lines.
# Time taken to process 500 lines: 0.0012109875679016113 minutes
# Processed 29500 lines.
# Time taken to process 500 lines: 0.0008405645688374838 minutes
# Processed 30000 lines.
# Time taken to process 500 lines: 0.0010305166244506836 minutes
# Processed 30500 lines.
# Time taken to process 500 lines: 0.0014086484909057618 minutes
# Processed 31000 lines.
# Time taken to process 500 lines: 0.001122450828552246 minutes
# Processed 31500 lines.
# Time taken to process 500 lines: 0.0017082413037618 minutes
# Processed 32000 lines.
# Time taken to process 500 lines: 0.0010735909144083658 minutes
# Processed 32500 lines.
# Time taken to process 500 lines: 0.0011952757835388184 minutes
# Processed 33000 lines.
# Time taken to process 500 lines: 0.001192776362101237 minutes
# Processed 33500 lines.
# Time taken to process 500 lines: 0.0010863105456034342 minutes
# Processed 34000 lines.
# Time taken to process 500 lines: 0.0008953213691711426 minutes
# Processed 34500 lines.
# Time taken to process 500 lines: 0.0010047157605489094 minutes
# Processed 35000 lines.
# Time taken to process 500 lines: 0.0014351169268290202 minutes
# Processed 35500 lines.
# Time taken to process 500 lines: 0.0010161519050598145 minutes
# Processed 36000 lines.
# Time taken to process 500 lines: 0.0012296795845031737 minutes
# Processed 36500 lines.
# Time taken to process 500 lines: 0.0015333692232767742 minutes
# Processed 37000 lines.
# Time taken to process 500 lines: 0.0011002024014790852 minutes
# Processed 37500 lines.
# Time taken to process 500 lines: 0.000977917512257894 minutes
# Processed 38000 lines.
# Time taken to process 500 lines: 0.0010297497113545735 minutes
# Processed 38500 lines.
# Time taken to process 500 lines: 0.001289645830790202 minutes
# Processed 39000 lines.
# Time taken to process 500 lines: 0.0009550929069519043 minutes
# Processed 39500 lines.
# Time taken to process 500 lines: 0.0008765975634256999 minutes
# Processed 40000 lines.
# Time taken to process 500 lines: 0.0013096094131469726 minutes
# Processed 40500 lines.
# Time taken to process 500 lines: 0.0013321121533711752 minutes
# Processed 41000 lines.
# Time taken to process 500 lines: 0.0011918822924296061 minutes
# Processed 41500 lines.
# Time taken to process 500 lines: 0.0009353280067443848 minutes
# Processed 42000 lines.
# Time taken to process 500 lines: 0.0008828083674112956 minutes
# Processed 42500 lines.
# Time taken to process 500 lines: 0.0011363267898559571 minutes
# Processed 43000 lines.
# Time taken to process 500 lines: 0.0012557427088419595 minutes
# Processed 43500 lines.
# Time taken to process 500 lines: 0.000867768128712972 minutes
# Processed 44000 lines.
# Time taken to process 500 lines: 0.0012986063957214355 minutes
# Processed 44500 lines.
# Time taken to process 500 lines: 0.003465898831685384 minutes
# Processed 45000 lines.
# Time taken to process 500 lines: 0.001257181167602539 minutes
# Processed 45500 lines.
# Time taken to process 500 lines: 0.0010146816571553548 minutes
# Processed 46000 lines.
# Time taken to process 500 lines: 0.0011122345924377442 minutes
# Processed 46500 lines.
# Time taken to process 500 lines: 0.0010823567708333334 minutes
# Processed 47000 lines.
# Time taken to process 500 lines: 0.0009879390398661295 minutes
# Processed 47500 lines.
# Time taken to process 500 lines: 0.000883038838704427 minutes
# Processed 48000 lines.
# Time taken to process 500 lines: 0.0011855800946553548 minutes
# Processed 48500 lines.
# Time taken to process 500 lines: 0.000649567445119222 minutes
# Processed 49000 lines.
# Time taken to process 500 lines: 0.0006514549255371094 minutes
# Processed 49500 lines.
# Time taken to process 500 lines: 0.0009398937225341796 minutes
# Processed 50000 lines.
# Time taken to process 500 lines: 0.0007875243822733561 minutes
# Processed 50500 lines.
# Time taken to process 500 lines: 0.0011462529500325521 minutes
# Processed 51000 lines.
# Time taken to process 500 lines: 0.0008065501848856608 minutes
# Processed 51500 lines.
# Time taken to process 500 lines: 0.0006929874420166015 minutes
# Processed 52000 lines.
# Time taken to process 500 lines: 0.0008267124493916829 minutes
# Processed 52500 lines.
# Time taken to process 500 lines: 0.0013195474942525227 minutes
# Processed 53000 lines.
# Time taken to process 500 lines: 0.000800927480061849 minutes
# Processed 53500 lines.
# Time taken to process 500 lines: 0.0008915901184082031 minutes
# Processed 54000 lines.
# Time taken to process 500 lines: 0.0007210175196329752 minutes
# Processed 54500 lines.
# Time taken to process 500 lines: 0.0008424560228983562 minutes
# Processed 55000 lines.
# Time taken to process 500 lines: 0.00036168893178304036 minutes
# Processed 55500 lines.
# Time taken to process 500 lines: 0.0007435480753580729 minutes
# Processed 56000 lines.
# Time taken to process 500 lines: 0.0010352849960327149 minutes
# Processed 56500 lines.
# Time taken to process 500 lines: 0.0008366862932840983 minutes
# Processed 57000 lines.
# Time taken to process 500 lines: 0.0013241370519002278 minutes
# Processed 57500 lines.
# Time taken to process 500 lines: 0.0015107949574788412 minutes
# Processed 58000 lines.
# Time taken to process 500 lines: 0.0013811588287353516 minutes
# Processed 58500 lines.
# Time taken to process 500 lines: 0.0014945904413859049 minutes
# Processed 59000 lines.
# Time taken to process 500 lines: 0.0010504484176635741 minutes
# Processed 59500 lines.
# Time taken to process 500 lines: 0.0013849814732869467 minutes
# Processed 60000 lines.
# Time taken to process 500 lines: 0.0009238998095194499 minutes
# Processed 60500 lines.
# Time taken to process 500 lines: 0.0012082854906717937 minutes
# Processed 61000 lines.
# Time taken to process 500 lines: 0.001223572095235189 minutes
# Processed 61500 lines.
# Time taken to process 500 lines: 0.0009109218915303548 minutes
# Processed 62000 lines.
# Time taken to process 500 lines: 0.0010338346163431802 minutes
# Processed 62500 lines.
# Time taken to process 500 lines: 0.0012944380442301432 minutes
# Processed 63000 lines.
# Time taken to process 500 lines: 0.0012436310450236003 minutes
# Processed 63500 lines.
# Time taken to process 500 lines: 0.0014843265215555826 minutes
# Processed 64000 lines.
# Time taken to process 500 lines: 0.0014366547266642252 minutes
# Processed 64500 lines.
# Time taken to process 500 lines: 0.001071619987487793 minutes
# Processed 65000 lines.
# Time taken to process 500 lines: 0.0008128603299458821 minutes
# Processed 65500 lines.
# Time taken to process 500 lines: 0.0007468024889628092 minutes
# Processed 66000 lines.
# Time taken to process 500 lines: 0.0007344524065653484 minutes
# Processed 66500 lines.
# Time taken to process 500 lines: 0.0009378393491109213 minutes
# Processed 67000 lines.
# Time taken to process 500 lines: 0.0007162610689798991 minutes
# Processed 67500 lines.
# Time taken to process 500 lines: 0.0004072109858194987 minutes
# Processed 68000 lines.
# Time taken to process 500 lines: 0.00038806994756062827 minutes
# Processed 68500 lines.
# Time taken to process 500 lines: 0.00031909545262654625 minutes
# Processed 69000 lines.
# Time taken to process 500 lines: 0.00034341812133789065 minutes
# Processed 69500 lines.
# Time taken to process 500 lines: 0.0005001425743103027 minutes
# Processed 70000 lines.
# Time taken to process 500 lines: 0.001051020622253418 minutes
# Processed 70500 lines.
# Time taken to process 500 lines: 0.0009366552035013835 minutes
# Processed 71000 lines.
# Time taken to process 500 lines: 0.0008159319559733073 minutes
# Processed 71500 lines.
# Time taken to process 500 lines: 0.0007507165273030598 minutes
# Processed 72000 lines.
# Time taken to process 500 lines: 0.0014618158340454102 minutes
# Processed 72500 lines.
# Time taken to process 500 lines: 0.0014996727307637532 minutes
# Processed 73000 lines.
# Time taken to process 500 lines: 0.0011641422907511393 minutes
# Processed 73500 lines.
# Time taken to process 500 lines: 0.000989226500193278 minutes
# Processed 74000 lines.
# Time taken to process 500 lines: 0.0012049396832784017 minutes
# Processed 74500 lines.
# Time taken to process 500 lines: 0.0016939242680867512 minutes
# Processed 75000 lines.
# Time taken to process 500 lines: 0.003167386849721273 minutes
# Processed 75500 lines.
# Time taken to process 500 lines: 0.003755795955657959 minutes
# Processed 76000 lines.
# Time taken to process 500 lines: 0.002479668458302816 minutes
# Processed 76500 lines.
# Time taken to process 500 lines: 0.002497597535451253 minutes
# Processed 77000 lines.
# Time taken to process 500 lines: 0.004163885116577148 minutes
# Processed 77500 lines.
# Time taken to process 500 lines: 0.004816889762878418 minutes
# Processed 78000 lines.
# Time taken to process 500 lines: 0.004035031795501709 minutes
# Processed 78500 lines.
# Time taken to process 500 lines: 0.00507121483484904 minutes
# Processed 79000 lines.
# Time taken to process 500 lines: 0.0034759044647216797 minutes
# Processed 79500 lines.
# Time taken to process 500 lines: 0.0011359691619873048 minutes
# Processed 80000 lines.
# Time taken to process 500 lines: 0.0011487166086832682 minutes
# Processed 80500 lines.
# Time taken to process 500 lines: 0.0009955128033955893 minutes
# Processed 81000 lines.
# Time taken to process 500 lines: 0.0011263449986775717 minutes
# Processed 81500 lines.
# Time taken to process 500 lines: 0.0008455832799275716 minutes
# Processed 82000 lines.
# Time taken to process 500 lines: 0.0009703914324442546 minutes
# Processed 82500 lines.
# Time taken to process 500 lines: 0.00154342254002889 minutes
# Processed 83000 lines.
# Time taken to process 500 lines: 0.0012833237648010253 minutes
# Processed 83500 lines.
# Time taken to process 500 lines: 0.0011307795842488606 minutes
# Processed 84000 lines.
# Time taken to process 500 lines: 0.000855402151743571 minutes
# Processed 84500 lines.
# Time taken to process 500 lines: 0.0009644508361816406 minutes
# Processed 85000 lines.
# Time taken to process 500 lines: 0.001104589303334554 minutes
# Processed 85500 lines.
# Time taken to process 500 lines: 0.0011960466702779133 minutes
# Processed 86000 lines.
# Time taken to process 500 lines: 0.0012184500694274903 minutes
# Processed 86500 lines.
# Time taken to process 500 lines: 0.0012355685234069825 minutes
# Processed 87000 lines.
# Time taken to process 500 lines: 0.0011185248692830404 minutes
# Processed 87500 lines.
# Time taken to process 500 lines: 0.0008656501770019532 minutes
# Processed 88000 lines.
# Time taken to process 500 lines: 0.0010828415552775065 minutes
# Processed 88500 lines.
# Time taken to process 500 lines: 0.0008946061134338379 minutes
# Processed 89000 lines.
# Time taken to process 500 lines: 0.0009334087371826172 minutes
# Processed 89500 lines.
# Time taken to process 500 lines: 0.00085144837697347 minutes
# Processed 90000 lines.
# Time taken to process 500 lines: 0.0010649522145589193 minutes
# Processed 90500 lines.
# Time taken to process 500 lines: 0.0009389678637186686 minutes
# Processed 91000 lines.
# Time taken to process 500 lines: 0.0009185870488484701 minutes
# Processed 91500 lines.
# Time taken to process 500 lines: 0.0010406851768493652 minutes
# Processed 92000 lines.
# Time taken to process 500 lines: 0.0013834198315938314 minutes
# Processed 92500 lines.
# Time taken to process 500 lines: 0.0010805010795593261 minutes
# Processed 93000 lines.
# Time taken to process 500 lines: 0.001035912831624349 minutes
# Processed 93500 lines.
# Time taken to process 500 lines: 0.000994265079498291 minutes
# Processed 94000 lines.
# Time taken to process 500 lines: 0.0011439164479573568 minutes
# Processed 94500 lines.
# Time taken to process 500 lines: 0.0010558247566223144 minutes
# Processed 95000 lines.
# Time taken to process 500 lines: 0.0010613322257995606 minutes
# Processed 95500 lines.
# Time taken to process 500 lines: 0.0010323484738667807 minutes
# Processed 96000 lines.
# Time taken to process 500 lines: 0.00109023650487264 minutes
# Processed 96500 lines.
# Time taken to process 500 lines: 0.0009666005770365397 minutes
# Processed 97000 lines.
# Time taken to process 500 lines: 0.0008685787518819174 minutes
# Processed 97500 lines.
# Time taken to process 500 lines: 0.0009682138760884602 minutes
# Processed 98000 lines.
# Time taken to process 500 lines: 0.0009589274724324544 minutes
# Processed 98500 lines.
# Time taken to process 500 lines: 0.0008780598640441894 minutes
# Processed 99000 lines.
# Time taken to process 500 lines: 0.000946648915608724 minutes
# Processed 99500 lines.
# Time taken to process 500 lines: 0.0010193745295206706 minutes
# Processed 100000 lines.
# Time taken to process 500 lines: 0.0010464072227478027 minutes
# Processed 100500 lines.
# Time taken to process 500 lines: 0.0010567784309387207 minutes
# Processed 101000 lines.
# Time taken to process 500 lines: 0.000986472765604655 minutes
# Processed 101500 lines.
# Time taken to process 500 lines: 0.0009842197100321452 minutes
# Processed 102000 lines.
# Time taken to process 500 lines: 0.00094603697458903 minutes
# Processed 102500 lines.
# Time taken to process 500 lines: 0.0009834647178649902 minutes
# Processed 103000 lines.
# Time taken to process 500 lines: 0.0009182810783386231 minutes
# Processed 103500 lines.
# Time taken to process 500 lines: 0.0009728272755940756 minutes
# Processed 104000 lines.
# Time taken to process 500 lines: 0.0011416792869567872 minutes
# Processed 104500 lines.
# Time taken to process 500 lines: 0.0010352015495300293 minutes
# Processed 105000 lines.
# Time taken to process 500 lines: 0.000978251298268636 minutes
# Processed 105500 lines.
# Time taken to process 500 lines: 0.0011707226435343425 minutes
# Processed 106000 lines.
# Time taken to process 500 lines: 0.0011344313621520995 minutes
# Processed 106500 lines.
# Time taken to process 500 lines: 0.0011357386906941731 minutes
# Processed 107000 lines.
# Time taken to process 500 lines: 0.0011655211448669434 minutes
# Processed 107500 lines.
# Time taken to process 500 lines: 0.0009281794230143229 minutes
# Processed 108000 lines.
# Time taken to process 500 lines: 0.0010894497235616049 minutes
# Processed 108500 lines.
# Time taken to process 500 lines: 0.0009833017985026041 minutes
# Processed 109000 lines.
# Time taken to process 500 lines: 0.0010204434394836426 minutes
# Processed 109500 lines.
# Time taken to process 500 lines: 0.0009437203407287598 minutes
# Processed 110000 lines.
# Time taken to process 500 lines: 0.0010580857594807943 minutes
# Processed 110500 lines.
# Time taken to process 500 lines: 0.0010112444559733072 minutes
# Processed 111000 lines.
# Time taken to process 500 lines: 0.0016102552413940429 minutes
# Processed 111500 lines.
# Time taken to process 500 lines: 0.002120494842529297 minutes
# Processed 112000 lines.
# Time taken to process 500 lines: 0.0011126796404520671 minutes
# Processed 112500 lines.
# Time taken to process 500 lines: 0.0011500914891560872 minutes
# Processed 113000 lines.
# Time taken to process 500 lines: 0.0009644548098246257 minutes
# Processed 113500 lines.
# Time taken to process 500 lines: 0.001077560583750407 minutes
# Processed 114000 lines.
# Time taken to process 500 lines: 0.0010637482007344564 minutes
# Processed 114500 lines.
# Time taken to process 500 lines: 0.0008703351020812988 minutes
# Processed 115000 lines.
# Time taken to process 500 lines: 0.0009608785311381022 minutes
# Processed 115500 lines.
# Time taken to process 500 lines: 0.0011701107025146485 minutes
# Processed 116000 lines.
# Time taken to process 500 lines: 0.0010128498077392578 minutes
# Processed 116500 lines.
# Time taken to process 500 lines: 0.0011241515477498373 minutes
# Processed 117000 lines.
# Time taken to process 500 lines: 0.0012865225474039713 minutes
# Processed 117500 lines.
# Time taken to process 500 lines: 0.0009509086608886719 minutes
# Processed 118000 lines.
# Time taken to process 500 lines: 0.0010391434033711752 minutes
# Processed 118500 lines.
# Time taken to process 500 lines: 0.0009974280993143717 minutes
# Processed 119000 lines.
# Time taken to process 500 lines: 0.0011153658231099447 minutes
# Processed 119500 lines.
# Time taken to process 500 lines: 0.0009408831596374512 minutes
# Processed 120000 lines.
# Time taken to process 500 lines: 0.001027965545654297 minutes
# Processed 120500 lines.
# Time taken to process 500 lines: 0.0012083172798156739 minutes
# Processed 121000 lines.
# Time taken to process 500 lines: 0.0009331107139587402 minutes
# Processed 121500 lines.
# Time taken to process 500 lines: 0.0010710358619689941 minutes
# Processed 122000 lines.
# Time taken to process 500 lines: 0.0008954048156738281 minutes
# Processed 122500 lines.
# Time taken to process 500 lines: 0.0009194374084472656 minutes
# Processed 123000 lines.
# Time taken to process 500 lines: 0.0009459376335144043 minutes
# Processed 123500 lines.
# Time taken to process 500 lines: 0.0008085290590922038 minutes
# Processed 124000 lines.
# Time taken to process 500 lines: 0.0010015010833740235 minutes
# Processed 124500 lines.
# Time taken to process 500 lines: 0.0008918642997741699 minutes
# Processed 125000 lines.
# Time taken to process 500 lines: 0.0008592963218688965 minutes
# Processed 125500 lines.
# Time taken to process 500 lines: 0.0008044123649597168 minutes
# Processed 126000 lines.
# Time taken to process 500 lines: 0.0008773048718770345 minutes
# Processed 126500 lines.
# Time taken to process 500 lines: 0.0009987314542134603 minutes
# Processed 127000 lines.
# Time taken to process 500 lines: 0.0008333802223205566 minutes
# Processed 127500 lines.
# Time taken to process 500 lines: 0.0008873661359151204 minutes
# Processed 128000 lines.
# Time taken to process 500 lines: 0.0009324749310811361 minutes
# Processed 128500 lines.
# Time taken to process 500 lines: 0.0010561267534891763 minutes
# Processed 129000 lines.
# Time taken to process 500 lines: 0.0009531180063883463 minutes
# Processed 129500 lines.
# Time taken to process 500 lines: 0.000829760233561198 minutes
# Processed 130000 lines.
# Time taken to process 500 lines: 0.0008599281311035157 minutes
# Processed 130500 lines.
# Time taken to process 500 lines: 0.0008559385935465495 minutes
# Processed 131000 lines.
# Time taken to process 500 lines: 0.0008777221043904623 minutes
# Processed 131500 lines.
# Time taken to process 500 lines: 0.0010263482729593913 minutes
# Processed 132000 lines.
# Time taken to process 500 lines: 0.0009059349695841472 minutes
# Processed 132500 lines.
# Time taken to process 500 lines: 0.000858759880065918 minutes
# Processed 133000 lines.
# Time taken to process 500 lines: 0.0009015242258707683 minutes
# Processed 133500 lines.
# Time taken to process 500 lines: 0.0009075562159220377 minutes
# Processed 134000 lines.
# Time taken to process 500 lines: 0.0008748690287272135 minutes
# Processed 134500 lines.
# Time taken to process 500 lines: 0.000946505864461263 minutes
# Processed 135000 lines.
# Time taken to process 500 lines: 0.0009027957916259765 minutes
# Processed 135500 lines.
# Time taken to process 500 lines: 0.0008907079696655274 minutes
# Processed 136000 lines.
# Time taken to process 500 lines: 0.0009869853655497232 minutes
# Processed 136500 lines.
# Time taken to process 500 lines: 0.001006766160329183 minutes
# Processed 137000 lines.
# Time taken to process 500 lines: 0.0009507457415262858 minutes
# Processed 137500 lines.
# Time taken to process 500 lines: 0.0010056734085083009 minutes
# Processed 138000 lines.
# Time taken to process 500 lines: 0.0010282317797342935 minutes
# Processed 138500 lines.
# Time taken to process 500 lines: 0.0008367220560709635 minutes
# Processed 139000 lines.
# Time taken to process 500 lines: 0.0008623878161112468 minutes
# Processed 139500 lines.
# Time taken to process 500 lines: 0.0009895960489908855 minutes
# Processed 140000 lines.
# Time taken to process 500 lines: 0.0009144663810729981 minutes
# Processed 140500 lines.
# Time taken to process 500 lines: 0.0010387102762858074 minutes
# Processed 141000 lines.
# Time taken to process 500 lines: 0.000999744733174642 minutes
# Processed 141500 lines.
# Time taken to process 500 lines: 0.0010299801826477051 minutes
# Processed 142000 lines.
# Time taken to process 500 lines: 0.000919342041015625 minutes
# Processed 142500 lines.
# Time taken to process 500 lines: 0.0008743882179260253 minutes
# Processed 143000 lines.
# Time taken to process 500 lines: 0.001003122329711914 minutes
# Processed 143500 lines.
# Time taken to process 500 lines: 0.0008670290311177572 minutes
# Processed 144000 lines.
# Time taken to process 500 lines: 0.0009952425956726075 minutes
# Processed 144500 lines.
# Time taken to process 500 lines: 0.0009016633033752441 minutes
# Processed 145000 lines.
# Time taken to process 500 lines: 0.0010257959365844727 minutes
# Processed 145500 lines.
# Time taken to process 500 lines: 0.0010565956433614095 minutes
# Processed 146000 lines.
# Time taken to process 500 lines: 0.0011479338010152182 minutes
# Processed 146500 lines.
# Time taken to process 500 lines: 0.0010999242464701335 minutes
# Processed 147000 lines.
# Time taken to process 500 lines: 0.0012691815694173176 minutes
# Processed 147500 lines.
# Time taken to process 500 lines: 0.0010354836781819661 minutes
# Processed 148000 lines.
# Time taken to process 500 lines: 0.0011160890261332193 minutes
# Processed 148500 lines.
# Time taken to process 500 lines: 0.0010363658269246419 minutes
# Processed 149000 lines.
# Time taken to process 500 lines: 0.0009508728981018066 minutes
# Processed 149500 lines.
# Time taken to process 500 lines: 0.0009841005007425944 minutes
# Processed 150000 lines.
# Time taken to process 500 lines: 0.001074079672495524 minutes
# Processed 150500 lines.
# Time taken to process 500 lines: 0.0009885748227437337 minutes
# Processed 151000 lines.
# Time taken to process 500 lines: 0.001064916451772054 minutes
# Processed 151500 lines.
# Time taken to process 500 lines: 0.0009232799212137859 minutes
# Processed 152000 lines.
# Time taken to process 500 lines: 0.0012224872907002768 minutes
# Processed 152500 lines.
# Time taken to process 500 lines: 0.0009369532267252604 minutes
# Processed 153000 lines.
# Time taken to process 500 lines: 0.0011461218198140462 minutes
# Processed 153500 lines.
# Time taken to process 500 lines: 0.0009187102317810058 minutes
# Processed 154000 lines.
# Time taken to process 500 lines: 0.0011338591575622559 minutes
# Processed 154500 lines.
# Time taken to process 500 lines: 0.0008164286613464355 minutes
# Processed 155000 lines.
# Time taken to process 500 lines: 0.0007538119951883952 minutes
# Processed 155500 lines.
# Time taken to process 500 lines: 0.0009095788002014161 minutes
# Processed 156000 lines.
# Time taken to process 500 lines: 0.0008111317952473958 minutes
# Processed 156500 lines.
# Time taken to process 500 lines: 0.0006789167722066244 minutes
# Processed 157000 lines.
# Time taken to process 500 lines: 0.0007993658383687337 minutes
# Processed 157500 lines.
# Time taken to process 500 lines: 0.0009159366289774577 minutes
# Processed 158000 lines.
# Time taken to process 500 lines: 0.0008416096369425456 minutes
# Processed 158500 lines.
# Time taken to process 500 lines: 0.0007667978604634603 minutes
# Processed 159000 lines.
# Time taken to process 500 lines: 0.0008658091227213542 minutes
# Processed 159500 lines.
# Time taken to process 500 lines: 0.000786435604095459 minutes
# Processed 160000 lines.
# Time taken to process 500 lines: 0.0008763670921325684 minutes
# Processed 160500 lines.
# Time taken to process 500 lines: 0.0008165438969930013 minutes
# Processed 161000 lines.
# Time taken to process 500 lines: 0.0007655620574951172 minutes
# Processed 161500 lines.
# Time taken to process 500 lines: 0.0009072820345560709 minutes
# Processed 162000 lines.
# Time taken to process 500 lines: 0.0028754472732543945 minutes
# Processed 162500 lines.
# Time taken to process 500 lines: 0.0009312113126118978 minutes
# Processed 163000 lines.
# Time taken to process 500 lines: 0.0009995539983113607 minutes
# Processed 163500 lines.
# Time taken to process 500 lines: 0.0008486827214558919 minutes
# Processed 164000 lines.
# Time taken to process 500 lines: 0.0010819514592488608 minutes
# Processed 164500 lines.
# Time taken to process 500 lines: 0.0008923014005025228 minutes
# Processed 165000 lines.
# Time taken to process 500 lines: 0.0008397777875264486 minutes
# Processed 165500 lines.
# Time taken to process 500 lines: 0.0008022467295328776 minutes
# Processed 166000 lines.
# Time taken to process 500 lines: 0.0007962783177693685 minutes
# Processed 166500 lines.
# Time taken to process 500 lines: 0.0008832136789957682 minutes
# Processed 167000 lines.
# Time taken to process 500 lines: 0.000960230827331543 minutes
# Processed 167500 lines.
# Time taken to process 500 lines: 0.0011449297269185384 minutes
# Processed 168000 lines.
# Time taken to process 500 lines: 0.0009283026059468588 minutes
# Processed 168500 lines.
# Time taken to process 500 lines: 0.0009273409843444825 minutes
# Processed 169000 lines.
# Time taken to process 500 lines: 0.0009924570719401042 minutes
# Processed 169500 lines.
# Time taken to process 500 lines: 0.0009600202242533366 minutes
# Processed 170000 lines.
# Time taken to process 500 lines: 0.0009215076764424642 minutes
# Processed 170500 lines.
# Time taken to process 500 lines: 0.0010253469149271647 minutes
# Processed 171000 lines.
# Time taken to process 500 lines: 0.0009528438250223796 minutes
# Processed 171500 lines.
# Time taken to process 500 lines: 0.0011262059211730956 minutes
# Processed 172000 lines.
# Time taken to process 500 lines: 0.0008647402127583821 minutes
# Processed 172500 lines.
# Time taken to process 500 lines: 0.0008715430895487468 minutes
# Processed 173000 lines.
# Time taken to process 500 lines: 0.0010354797045389811 minutes
# Processed 173500 lines.
# Time taken to process 500 lines: 0.0010572473208109538 minutes
# Processed 174000 lines.
# Time taken to process 500 lines: 0.001231845219930013 minutes
# Processed 174500 lines.
# Time taken to process 500 lines: 0.000853574275970459 minutes
# Processed 175000 lines.
# Time taken to process 500 lines: 0.0008189717928568523 minutes
# Processed 175500 lines.
# Time taken to process 500 lines: 0.000985689957936605 minutes
# Processed 176000 lines.
# Time taken to process 500 lines: 0.0008697032928466797 minutes
# Processed 176500 lines.
# Time taken to process 500 lines: 0.0012128353118896484 minutes
# Processed 177000 lines.
# Time taken to process 500 lines: 0.0021956245104471843 minutes
# Processed 177500 lines.
# Time taken to process 500 lines: 0.0018713235855102538 minutes
# Processed 178000 lines.
# Time taken to process 500 lines: 0.003750284512837728 minutes
# Processed 178500 lines.
# Time taken to process 500 lines: 0.0018147110939025878 minutes
# Processed 179000 lines.
# Time taken to process 500 lines: 0.0015280922253926596 minutes
# Processed 179500 lines.
# Time taken to process 500 lines: 0.0015227874120076498 minutes
# Processed 180000 lines.
# Time taken to process 500 lines: 0.001411906878153483 minutes
# Processed 180500 lines.
# Time taken to process 500 lines: 0.001193086306254069 minutes
# Processed 181000 lines.
# Time taken to process 500 lines: 0.0011413415273030599 minutes
# Processed 181500 lines.
# Time taken to process 500 lines: 0.0012881159782409668 minutes
# Processed 182000 lines.
# Time taken to process 500 lines: 0.0012185136477152506 minutes
# Processed 182500 lines.
# Time taken to process 500 lines: 0.0017549753189086913 minutes
# Processed 183000 lines.
# Time taken to process 500 lines: 0.0012749552726745606 minutes
# Processed 183500 lines.
# Time taken to process 500 lines: 0.0010323564211527506 minutes
# Processed 184000 lines.
# Time taken to process 500 lines: 0.000997340679168701 minutes
# Processed 184500 lines.
# Time taken to process 500 lines: 0.0009289185206095377 minutes
# Processed 185000 lines.
# Time taken to process 500 lines: 0.0011235475540161133 minutes
# Processed 185500 lines.
# Time taken to process 500 lines: 0.000885613759358724 minutes
# Processed 186000 lines.
# Time taken to process 500 lines: 0.0009412964185078939 minutes
# Processed 186500 lines.
# Time taken to process 500 lines: 0.0011259595553080241 minutes
# Processed 187000 lines.
# Time taken to process 500 lines: 0.001117404301961263 minutes
# Processed 187500 lines.
# Time taken to process 500 lines: 0.0009899338086446126 minutes
# Processed 188000 lines.
# Time taken to process 500 lines: 0.0012957135836283366 minutes
# Processed 188500 lines.
# Time taken to process 500 lines: 0.0012629191080729167 minutes
# Processed 189000 lines.
# Time taken to process 500 lines: 0.0015489578247070313 minutes
# Processed 189500 lines.
# Time taken to process 500 lines: 0.0013351957003275552 minutes
# Processed 190000 lines.
# Time taken to process 500 lines: 0.0014366904894510906 minutes
# Processed 190500 lines.
# Time taken to process 500 lines: 0.0012166062990824381 minutes
# Processed 191000 lines.
# Time taken to process 500 lines: 0.0011454105377197265 minutes
# Processed 191500 lines.
# Time taken to process 500 lines: 0.0012697418530782064 minutes
# Processed 192000 lines.
# Time taken to process 500 lines: 0.001343834400177002 minutes
# Processed 192500 lines.
# Time taken to process 500 lines: 0.0014201084772745769 minutes
# Processed 193000 lines.
# Time taken to process 500 lines: 0.0012514233589172364 minutes
# Processed 193500 lines.
# Time taken to process 500 lines: 0.0012686411539713542 minutes
# Processed 194000 lines.
# Time taken to process 500 lines: 0.0011990507443745931 minutes
# Processed 194500 lines.
# Time taken to process 500 lines: 0.0009772857030232748 minutes
# Processed 195000 lines.
# Time taken to process 500 lines: 0.0009401321411132812 minutes
# Processed 195500 lines.
# Time taken to process 500 lines: 0.000911239782969157 minutes
# Processed 196000 lines.
# Time taken to process 500 lines: 0.0009353359540303549 minutes
# Processed 196500 lines.
# Time taken to process 500 lines: 0.0010357181231180827 minutes
# Processed 197000 lines.
# Time taken to process 500 lines: 0.0010287086168924966 minutes
# Processed 197500 lines.
# Time taken to process 500 lines: 0.0013912439346313477 minutes
# Processed 198000 lines.
# Time taken to process 500 lines: 0.0012931346893310547 minutes
# Processed 198500 lines.
# Time taken to process 500 lines: 0.0009176174799601237 minutes
# Processed 199000 lines.
# Time taken to process 500 lines: 0.0008350133895874024 minutes
# Processed 199500 lines.
# Time taken to process 500 lines: 0.0009415109952290852 minutes
# Processed 200000 lines.
# Time taken to process 500 lines: 0.0009596784909566244 minutes
# Processed 200500 lines.
# Time taken to process 500 lines: 0.0011757691701253256 minutes
# Processed 201000 lines.
# Time taken to process 500 lines: 0.000923311710357666 minutes
# Processed 201500 lines.
# Time taken to process 500 lines: 0.0010328133900960287 minutes
# Processed 202000 lines.
# Time taken to process 500 lines: 0.0012050469716389973 minutes
# Processed 202500 lines.
# Time taken to process 500 lines: 0.0010134061177571616 minutes
# Processed 203000 lines.
# Time taken to process 500 lines: 0.0010675787925720215 minutes
# Processed 203500 lines.
# Time taken to process 500 lines: 0.0012646913528442383 minutes
# Processed 204000 lines.
# Time taken to process 500 lines: 0.003141685326894124 minutes
# Processed 204500 lines.
# Time taken to process 500 lines: 0.0028851509094238283 minutes
# Processed 205000 lines.
# Time taken to process 500 lines: 0.0027912020683288573 minutes
# Processed 205500 lines.
# Time taken to process 500 lines: 0.0032338380813598635 minutes
# Processed 206000 lines.
# Time taken to process 500 lines: 0.003633411725362142 minutes
# Processed 206500 lines.
# Time taken to process 500 lines: 0.0028039693832397463 minutes
# Processed 207000 lines.
# Time taken to process 500 lines: 0.001710045337677002 minutes
# Processed 207500 lines.
# Time taken to process 500 lines: 0.004303344090779622 minutes
# Processed 208000 lines.
# Time taken to process 500 lines: 0.005025553703308106 minutes
# Processed 208500 lines.
# Time taken to process 500 lines: 0.004417204856872558 minutes
# Processed 209000 lines.
# Time taken to process 500 lines: 0.005075204372406006 minutes
# Processed 209500 lines.
# Time taken to process 500 lines: 0.0019089063008626303 minutes
# Processed 210000 lines.
# Time taken to process 500 lines: 0.0013824939727783204 minutes
# Processed 210500 lines.
# Time taken to process 500 lines: 0.0013743877410888673 minutes
# Processed 211000 lines.
# Time taken to process 500 lines: 0.0016035040219624837 minutes
# Processed 211500 lines.
# Time taken to process 500 lines: 0.0008767048517862955 minutes
# Processed 212000 lines.
# Time taken to process 500 lines: 0.0013721664746602377 minutes
# Processed 212500 lines.
# Time taken to process 500 lines: 0.0010196129480997721 minutes
# Processed 213000 lines.
# Time taken to process 500 lines: 0.0016896684964497885 minutes
# Processed 213500 lines.
# Time taken to process 500 lines: 0.0017696261405944825 minutes
# Processed 214000 lines.
# Time taken to process 500 lines: 0.0013877113660176596 minutes
# Processed 214500 lines.
# Time taken to process 500 lines: 0.0019422332445780436 minutes
# Processed 215000 lines.
# Time taken to process 500 lines: 0.0015691200892130534 minutes
# Processed 215500 lines.
# Time taken to process 500 lines: 0.000993359088897705 minutes
# Processed 216000 lines.
# Time taken to process 500 lines: 0.0008476972579956055 minutes
# Processed 216500 lines.
# Time taken to process 500 lines: 0.0012342611948649089 minutes
# Processed 217000 lines.
# Time taken to process 500 lines: 0.0011909047762552897 minutes
# Processed 217500 lines.
# Time taken to process 500 lines: 0.001016549269358317 minutes
# Processed 218000 lines.
# Time taken to process 500 lines: 0.0010519862174987794 minutes
# Processed 218500 lines.
# Time taken to process 500 lines: 0.0009116609891255697 minutes
# Processed 219000 lines.
# Time taken to process 500 lines: 0.0005910038948059082 minutes
# Processed 219500 lines.
# Time taken to process 500 lines: 0.0005923032760620118 minutes
# Processed 220000 lines.
# Time taken to process 500 lines: 0.0007153471310933431 minutes
# Processed 220500 lines.
# Time taken to process 500 lines: 0.0005167245864868164 minutes
# Processed 221000 lines.
# Time taken to process 500 lines: 0.0010476112365722656 minutes
# Processed 221500 lines.
# Time taken to process 500 lines: 0.00045109192530314127 minutes
# Processed 222000 lines.
# Time taken to process 500 lines: 0.0003508726755777995 minutes
# Processed 222500 lines.
# Time taken to process 500 lines: 0.0003124833106994629 minutes
# Processed 223000 lines.
# Time taken to process 500 lines: 0.0002910057703653971 minutes
# Processed 223500 lines.
# Time taken to process 500 lines: 0.0002727111180623372 minutes
# Processed 224000 lines.
# Time taken to process 500 lines: 0.0002522428830464681 minutes
# Processed 224500 lines.
# Time taken to process 500 lines: 0.0004000107447306315 minutes
# Processed 225000 lines.
# Time taken to process 500 lines: 0.0004999756813049317 minutes
# Processed 225500 lines.
# Time taken to process 500 lines: 0.0005000988642374674 minutes
# Processed 226000 lines.
# Time taken to process 500 lines: 0.0009460846583048502 minutes
# Processed 226500 lines.
# Time taken to process 500 lines: 0.0013458887736002604 minutes
# Processed 227000 lines.
# Time taken to process 500 lines: 0.0006385684013366699 minutes
# Processed 227500 lines.
# Time taken to process 500 lines: 0.0008139371871948242 minutes
# Processed 228000 lines.
# Time taken to process 500 lines: 0.0011463403701782227 minutes
# Processed 228500 lines.
# Time taken to process 500 lines: 0.002283593018849691 minutes
# Processed 229000 lines.
# Time taken to process 500 lines: 0.0008999903996785482 minutes
# Processed 229500 lines.
# Time taken to process 500 lines: 0.0018398960431416829 minutes
# Processed 230000 lines.
# Time taken to process 500 lines: 0.0015124201774597168 minutes
# Processed 230500 lines.
# Time taken to process 500 lines: 0.002725513776143392 minutes
# Processed 231000 lines.
# Time taken to process 500 lines: 0.0014610608418782552 minutes
# Processed 231500 lines.
# Time taken to process 500 lines: 0.0012028098106384277 minutes
# Processed 232000 lines.
# Time taken to process 500 lines: 0.0024164994557698567 minutes
# Processed 232500 lines.
# Time taken to process 500 lines: 0.0013702750205993653 minutes
# Processed 233000 lines.
# Time taken to process 500 lines: 0.00166624387105306 minutes
# Processed 233500 lines.
# Time taken to process 500 lines: 0.0028538902600606284 minutes
# Processed 234000 lines.
# Time taken to process 500 lines: 0.004141946633656819 minutes
# Processed 234500 lines.
# Time taken to process 500 lines: 0.0019324938456217447 minutes
# Processed 235000 lines.
# Time taken to process 500 lines: 0.0014592647552490235 minutes
# Processed 235500 lines.
# Time taken to process 500 lines: 0.0015038450558980305 minutes
# Processed 236000 lines.
# Time taken to process 500 lines: 0.0016919811566670736 minutes
# Processed 236500 lines.
# Time taken to process 500 lines: 0.0018087108929951987 minutes
# Processed 237000 lines.
# Time taken to process 500 lines: 0.0017373800277709962 minutes
# Processed 237500 lines.
# Time taken to process 500 lines: 0.0015154997507731119 minutes
# Processed 238000 lines.
# Time taken to process 500 lines: 0.0026647210121154784 minutes
# Processed 238500 lines.
# Time taken to process 500 lines: 0.0028372844060262042 minutes
# Processed 239000 lines.
# Time taken to process 500 lines: 0.0017191688219706216 minutes
# Processed 239500 lines.
# Time taken to process 500 lines: 0.0020508050918579103 minutes
# Processed 240000 lines.
# Time taken to process 500 lines: 0.0016290744145711262 minutes
# Processed 240500 lines.
# Time taken to process 500 lines: 0.0013985633850097656 minutes
# Processed 241000 lines.
# Time taken to process 500 lines: 0.0007091482480367024 minutes
# Processed 241500 lines.
# Time taken to process 500 lines: 0.0003438154856363932 minutes
# Processed 242000 lines.
# Time taken to process 500 lines: 0.0003186662991841634 minutes
# Processed 242500 lines.
# Time taken to process 500 lines: 0.0018986940383911132 minutes
# Processed 243000 lines.
# Time taken to process 500 lines: 0.0018726269404093425 minutes
# Processed 243500 lines.
# Time taken to process 500 lines: 0.002171480655670166 minutes
# Processed 244000 lines.
# Time taken to process 500 lines: 0.0017547726631164551 minutes
# Processed 244500 lines.
# Time taken to process 500 lines: 0.0012061874071757 minutes
# Processed 245000 lines.
# Time taken to process 500 lines: 0.0003695805867513021 minutes
# Processed 245500 lines.
# Time taken to process 500 lines: 0.0003669102986653646 minutes
# Processed 246000 lines.
# Time taken to process 500 lines: 0.0012294173240661622 minutes
# Processed 246500 lines.
# Time taken to process 500 lines: 0.001641229788462321 minutes
# Processed 247000 lines.
# Time taken to process 500 lines: 0.0022008101145426433 minutes
# Processed 247500 lines.
# Time taken to process 500 lines: 0.0014350175857543944 minutes
# Processed 248000 lines.
# Time taken to process 500 lines: 0.0020229498545328776 minutes
# Processed 248500 lines.
# Time taken to process 500 lines: 0.001881277561187744 minutes
# Processed 249000 lines.
# Time taken to process 500 lines: 0.0014670769373575847 minutes
# Processed 249500 lines.
# Time taken to process 500 lines: 0.0011516412099202473 minutes
# Processed 250000 lines.
# Time taken to process 500 lines: 0.0013428449630737305 minutes
# Processed 250500 lines.
# Time taken to process 500 lines: 0.0018412629763285319 minutes
# Processed 251000 lines.
# Time taken to process 500 lines: 0.001996922492980957 minutes
# Processed 251500 lines.
# Time taken to process 500 lines: 0.0022346059481302897 minutes
# Processed 252000 lines.
# Time taken to process 500 lines: 0.0014774044354756673 minutes
# Processed 252500 lines.
# Time taken to process 500 lines: 0.001738111178080241 minutes
# Processed 253000 lines.
# Time taken to process 500 lines: 0.0011261860529581706 minutes
# Processed 253500 lines.
# Time taken to process 500 lines: 0.0018712361653645834 minutes
# Processed 254000 lines.
# Time taken to process 500 lines: 0.0014955997467041016 minutes
# Processed 254500 lines.
# Time taken to process 500 lines: 0.0016467809677124024 minutes
# Processed 255000 lines.
# Time taken to process 500 lines: 0.0015308260917663574 minutes
# Processed 255500 lines.
# Time taken to process 500 lines: 0.0014539361000061035 minutes
# Processed 256000 lines.
# Time taken to process 500 lines: 0.0018058021863301594 minutes
# Processed 256500 lines.
# Time taken to process 500 lines: 0.0009491761525472005 minutes
# Processed 257000 lines.
# Time taken to process 500 lines: 0.0009077072143554687 minutes
# Processed 257500 lines.
# Time taken to process 500 lines: 0.0008866985638936361 minutes
# Processed 258000 lines.
# Time taken to process 500 lines: 0.0007385691006978353 minutes
# Processed 258500 lines.
# Time taken to process 500 lines: 0.0007683555285135905 minutes
# Processed 259000 lines.
# Time taken to process 500 lines: 0.0009265700976053874 minutes
# Processed 259500 lines.
# Time taken to process 500 lines: 0.0017206350962320964 minutes
# Processed 260000 lines.
# Time taken to process 500 lines: 0.0017113208770751954 minutes
# Processed 260500 lines.
# Time taken to process 500 lines: 0.002209742863972982 minutes
# Processed 261000 lines.
# Time taken to process 500 lines: 0.001557000478108724 minutes
# Processed 261500 lines.
# Time taken to process 500 lines: 0.001123658816019694 minutes
# Processed 262000 lines.
# Time taken to process 500 lines: 0.0012636343638102213 minutes
# Processed 262500 lines.
# Time taken to process 500 lines: 0.0010191639264424642 minutes
# Processed 263000 lines.
# Time taken to process 500 lines: 0.0014256556828816731 minutes
# Processed 263500 lines.
# Time taken to process 500 lines: 0.0013836503028869628 minutes
# Processed 264000 lines.
# Time taken to process 500 lines: 0.0014317790667215983 minutes
# Processed 264500 lines.
# Time taken to process 500 lines: 0.0021773378054300943 minutes
# Processed 265000 lines.
# Time taken to process 500 lines: 0.0011139988899230957 minutes
# Processed 265500 lines.
# Time taken to process 500 lines: 0.002498515446980794 minutes
# Processed 266000 lines.
# Time taken to process 500 lines: 0.0016615867614746093 minutes
# Processed 266500 lines.
# Time taken to process 500 lines: 0.0016398429870605469 minutes
# Processed 267000 lines.
# Time taken to process 500 lines: 0.0012283007303873698 minutes
# Processed 267500 lines.
# Time taken to process 500 lines: 0.0016000866889953613 minutes
# Processed 268000 lines.
# Time taken to process 500 lines: 0.0014310399691263834 minutes
# Processed 268500 lines.
# Time taken to process 500 lines: 0.0012026945749918619 minutes
# Processed 269000 lines.
# Time taken to process 500 lines: 0.001503582795461019 minutes
# Processed 269500 lines.
# Time taken to process 500 lines: 0.0012095053990681967 minutes
# Processed 270000 lines.
# Time taken to process 500 lines: 0.0012086709340413412 minutes
# Processed 270500 lines.
# Time taken to process 500 lines: 0.0015288631121317545 minutes
# Processed 271000 lines.
# Time taken to process 500 lines: 0.0033397714296976725 minutes
# Processed 271500 lines.
# Time taken to process 500 lines: 0.001564192771911621 minutes
# Processed 272000 lines.
# Time taken to process 500 lines: 0.0015381534894307455 minutes
# Processed 272500 lines.
# Time taken to process 500 lines: 0.0022598385810852053 minutes
# Processed 273000 lines.
# Time taken to process 500 lines: 0.0018833041191101073 minutes
# Processed 273500 lines.
# Time taken to process 500 lines: 0.0018192052841186524 minutes
# Processed 274000 lines.
# Time taken to process 500 lines: 0.0014195005098978678 minutes
# Processed 274500 lines.
# Time taken to process 500 lines: 0.0015093286832173665 minutes
# Processed 275000 lines.
# Time taken to process 500 lines: 0.0017194747924804688 minutes
# Processed 275500 lines.
# Time taken to process 500 lines: 0.0013412833213806152 minutes
# Processed 276000 lines.
# Time taken to process 500 lines: 0.0011020461718241374 minutes
# Processed 276500 lines.
# Time taken to process 500 lines: 0.0010227203369140626 minutes
# Processed 277000 lines.
# Time taken to process 500 lines: 0.0012013872464497885 minutes
# Processed 277500 lines.
# Time taken to process 500 lines: 0.0013056635856628419 minutes
# Processed 278000 lines.
# ...
# Processed 480000 lines.
# Time taken to process 500 lines: 0.0017350872357686361 minutes
# Processed 480500 lines.
# Time taken to process 500 lines: 0.0009118278821309407 minutes
# Processed 481000 lines.
# Time taken to process 500 lines: 0.0012130419413248698 minutes
# Processed 481500 lines.
# Time taken to process 500 lines: 0.0009897708892822265 minutes
# Processed 482000 lines.
# Time taken to process 500 lines: 0.001743443806966146 minutes
# Processed 482500 lines.
# Time taken to process 500 lines: 0.0011894623438517252 minutes
# Processed 483000 lines.
# Time taken to process 500 lines: 0.0018293579419453939 minutes
# Processed 483500 lines.
# Time taken to process 500 lines: 0.002256341775258382 minutes
# Processed 484000 lines.
# Time taken to process 500 lines: 0.0012578090031941731 minutes
# Processed 484500 lines.
# Time taken to process 500 lines: 0.0012482881546020507 minutes
# Processed 485000 lines.
# Time taken to process 500 lines: 0.0016616304715474446 minutes
# Processed 485500 lines.
# Time taken to process 500 lines: 0.001575136184692383 minutes
# Processed 486000 lines.
# Time taken to process 500 lines: 0.0011043826738993327 minutes
# Processed 486500 lines.
# Time taken to process 500 lines: 0.0012119571367899577 minutes
# Processed 487000 lines.
# Time taken to process 500 lines: 0.0012384335199991862 minutes
# Processed 487500 lines.
# Time taken to process 500 lines: 0.0009395400683085124 minutes
# Processed 488000 lines.
# Time taken to process 500 lines: 0.0011649727821350098 minutes
# Processed 488500 lines.
# Time taken to process 500 lines: 0.0016008933385213216 minutes
# Processed 489000 lines.
# Time taken to process 500 lines: 0.0014577746391296388 minutes
# Processed 489500 lines.
# Time taken to process 500 lines: 0.0012037873268127442 minutes
# Processed 490000 lines.
# Time taken to process 500 lines: 0.0012131770451863607 minutes
# Processed 490500 lines.
# Time taken to process 500 lines: 0.0011852264404296875 minutes
# Processed 491000 lines.
# Time taken to process 500 lines: 0.0009359002113342285 minutes
# Processed 491500 lines.
# Time taken to process 500 lines: 0.0013944029808044434 minutes
# Processed 492000 lines.
# Time taken to process 500 lines: 0.0008997877438863118 minutes
# Processed 492500 lines.
# Time taken to process 500 lines: 0.0011064847310384115 minutes
# Processed 493000 lines.
# Time taken to process 500 lines: 0.0010540246963500976 minutes
# Processed 493500 lines.
# Time taken to process 500 lines: 0.001099689801534017 minutes
# Processed 494000 lines.
# Time taken to process 500 lines: 0.0007747371991475423 minutes
# Processed 494500 lines.
# Time taken to process 500 lines: 0.0008661588033040365 minutes
# Processed 495000 lines.
# Time taken to process 500 lines: 0.0008318463961283366 minutes
# Processed 495500 lines.
# Time taken to process 500 lines: 0.0008649746576944987 minutes
# Processed 496000 lines.
# Time taken to process 500 lines: 0.0008694410324096679 minutes
# Processed 496500 lines.
# Time taken to process 500 lines: 0.0008198499679565429 minutes
# Processed 497000 lines.
# Time taken to process 500 lines: 0.0010559519131978353 minutes
# Processed 497500 lines.
# Time taken to process 500 lines: 0.0007644176483154296 minutes
# Processed 498000 lines.
# Time taken to process 500 lines: 0.0013395428657531738 minutes
# Processed 498500 lines.
# Time taken to process 500 lines: 0.0013287782669067383 minutes
# Processed 499000 lines.
# Time taken to process 500 lines: 0.001111892859141032 minutes
# Processed 499500 lines.
# Time taken to process 500 lines: 0.001275165875752767 minutes
# Processed 500000 lines.
# Time taken to process 500 lines: 0.0012470324834187826 minutes
# Processed 500500 lines.
# Time taken to process 500 lines: 0.0010425090789794923 minutes
# Processed 501000 lines.
# Time taken to process 500 lines: 0.0012548089027404786 minutes
# Processed 501500 lines.
# Time taken to process 500 lines: 0.0013111670811971029 minutes
# Processed 502000 lines.
# Time taken to process 500 lines: 0.0022679567337036133 minutes
# Processed 502500 lines.
# Time taken to process 500 lines: 0.0026473522186279295 minutes
# Processed 503000 lines.
# Time taken to process 500 lines: 0.0031677643458048505 minutes
# Processed 503500 lines.
# Time taken to process 500 lines: 0.002251152197519938 minutes
# Processed 504000 lines.
# Time taken to process 500 lines: 0.0027350902557373045 minutes
# Processed 504500 lines.
# Time taken to process 500 lines: 0.002828021844228109 minutes
# Processed 505000 lines.
# Time taken to process 500 lines: 0.002234335740407308 minutes
# Processed 505500 lines.
# Time taken to process 500 lines: 0.002511922518412272 minutes
# Processed 506000 lines.
# Time taken to process 500 lines: 0.0033034006754557293 minutes
# Processed 506500 lines.
# Time taken to process 500 lines: 0.00120316743850708 minutes
# Processed 507000 lines.
# Time taken to process 500 lines: 0.001108849048614502 minutes
# Processed 507500 lines.
# Time taken to process 500 lines: 0.0009522358576456706 minutes
# Processed 508000 lines.
# Time taken to process 500 lines: 0.0007887760798136394 minutes
# Processed 508500 lines.
# Time taken to process 500 lines: 0.0008288820584615072 minutes
# Processed 509000 lines.
# Time taken to process 500 lines: 0.0008617599805196126 minutes
# Processed 509500 lines.
# Time taken to process 500 lines: 0.0008231600125630697 minutes
# Processed 510000 lines.
# Time taken to process 500 lines: 0.0008014520009358724 minutes
# Processed 510500 lines.
# Time taken to process 500 lines: 0.0006281812985738118 minutes
# Processed 511000 lines.
# Time taken to process 500 lines: 0.00076294740041097 minutes
# Processed 511500 lines.
# Time taken to process 500 lines: 0.0008804440498352051 minutes
# Processed 512000 lines.
# Time taken to process 500 lines: 0.0007048726081848144 minutes
# Processed 512500 lines.
# Time taken to process 500 lines: 0.0008862098058064779 minutes
# Processed 513000 lines.
# Time taken to process 500 lines: 0.0010054628054300943 minutes
# Processed 513500 lines.
# Time taken to process 500 lines: 0.0013117432594299317 minutes
# Processed 514000 lines.
# Time taken to process 500 lines: 0.0012996951738993327 minutes
# Processed 514500 lines.
# Time taken to process 500 lines: 0.0013824939727783204 minutes
# Processed 515000 lines.
# Time taken to process 500 lines: 0.0012822826703389487 minutes
# Processed 515500 lines.
# Time taken to process 500 lines: 0.0011729756991068522 minutes
# Processed 516000 lines.
# Time taken to process 500 lines: 0.0007462541262308757 minutes
# Processed 516500 lines.
# Time taken to process 500 lines: 0.001141838232676188 minutes
# Processed 517000 lines.
# Time taken to process 500 lines: 0.0006522655487060547 minutes
# Processed 517500 lines.
# Time taken to process 500 lines: 0.0007812062899271647 minutes
# Processed 518000 lines.
# Time taken to process 500 lines: 0.0006676157315572103 minutes
# Processed 518500 lines.
# Time taken to process 500 lines: 0.00112000306447347 minutes
# Processed 519000 lines.
# Time taken to process 500 lines: 0.0007173856099446615 minutes
# Processed 519500 lines.
# Time taken to process 500 lines: 0.0006687045097351074 minutes
# Processed 520000 lines.
# Time taken to process 500 lines: 0.0006083448727925619 minutes
# Processed 520500 lines.
# Time taken to process 500 lines: 0.0006322383880615235 minutes
# Processed 521000 lines.
# Time taken to process 500 lines: 0.0006179253260294597 minutes
# Processed 521500 lines.
# Time taken to process 500 lines: 0.0005776683489481608 minutes
# Processed 522000 lines.
# Time taken to process 500 lines: 0.0005695819854736328 minutes
# Processed 522500 lines.
# Time taken to process 500 lines: 0.0005996068318684896 minutes
# Processed 523000 lines.
# Time taken to process 500 lines: 0.000537864367167155 minutes
# Processed 523500 lines.
# Time taken to process 500 lines: 0.0005479176839192708 minutes
# Processed 524000 lines.
# Time taken to process 500 lines: 0.0005756696065266927 minutes
# Processed 524500 lines.
# Time taken to process 500 lines: 0.0007202307383219401 minutes
# Processed 525000 lines.
# Time taken to process 500 lines: 0.0007210334142049153 minutes
# Processed 525500 lines.
# Time taken to process 500 lines: 0.0010428627332051594 minutes
# Processed 526000 lines.
# Time taken to process 500 lines: 0.0011456886927286784 minutes
# Processed 526500 lines.
# Time taken to process 500 lines: 0.0012350281079610188 minutes
# Processed 527000 lines.
# Time taken to process 500 lines: 0.0007838606834411621 minutes
# Processed 527500 lines.
# Time taken to process 500 lines: 0.0008257667223612468 minutes
# Processed 528000 lines.
# Time taken to process 500 lines: 0.0008942246437072754 minutes
# Processed 528500 lines.
# Time taken to process 500 lines: 0.0007620453834533691 minutes
# Processed 529000 lines.
# Time taken to process 500 lines: 0.0008453965187072754 minutes
# Processed 529500 lines.
# Time taken to process 500 lines: 0.0008950948715209961 minutes
# Processed 530000 lines.
# Time taken to process 500 lines: 0.0011892318725585938 minutes
# Processed 530500 lines.
# Time taken to process 500 lines: 0.0008804996808369955 minutes
# Processed 531000 lines.
# Time taken to process 500 lines: 0.0008275707562764486 minutes
# Processed 531500 lines.
# Time taken to process 500 lines: 0.0008830825487772623 minutes
# Processed 532000 lines.
# Time taken to process 500 lines: 0.0010285695393880208 minutes
# Processed 532500 lines.
# Time taken to process 500 lines: 0.001239649454752604 minutes
# Processed 533000 lines.
# Time taken to process 500 lines: 0.0010546286900838216 minutes
# Processed 533500 lines.
# Time taken to process 500 lines: 0.0011166572570800782 minutes
# Processed 534000 lines.
# Time taken to process 500 lines: 0.000883173942565918 minutes
# Processed 534500 lines.
# Time taken to process 500 lines: 0.0011242151260375977 minutes
# Processed 535000 lines.
# Time taken to process 500 lines: 0.0012511610984802246 minutes
# Processed 535500 lines.
# Time taken to process 500 lines: 0.0010423541069030761 minutes
# Processed 536000 lines.
# Time taken to process 500 lines: 0.0011281490325927735 minutes
# Processed 536500 lines.
# Time taken to process 500 lines: 0.0009837587674458822 minutes
# Processed 537000 lines.
# Time taken to process 500 lines: 0.0013538082440694174 minutes
# Processed 537500 lines.
# Time taken to process 500 lines: 0.0012431780497233072 minutes
# Processed 538000 lines.
# Time taken to process 500 lines: 0.0016549309094746909 minutes
# Processed 538500 lines.
# Time taken to process 500 lines: 0.0013712763786315918 minutes
# Processed 539000 lines.
# Time taken to process 500 lines: 0.0013024449348449708 minutes
# Processed 539500 lines.
# Time taken to process 500 lines: 0.001441514492034912 minutes
# Processed 540000 lines.
# Time taken to process 500 lines: 0.0014753341674804688 minutes
# Processed 540500 lines.
# Time taken to process 500 lines: 0.0014839053153991699 minutes
# Processed 541000 lines.
# Time taken to process 500 lines: 0.0011359492937723795 minutes
# Processed 541500 lines.
# Time taken to process 500 lines: 0.0014615853627522786 minutes
# Processed 542000 lines.
# Time taken to process 500 lines: 0.0016580661137898763 minutes
# Processed 542500 lines.
# Time taken to process 500 lines: 0.0012723445892333985 minutes
# Processed 543000 lines.
# Time taken to process 500 lines: 0.0013193964958190918 minutes
# Processed 543500 lines.
# Time taken to process 500 lines: 0.0013487617174784343 minutes
# Processed 544000 lines.
# Time taken to process 500 lines: 0.0016219178835550944 minutes
# Processed 544500 lines.
# Time taken to process 500 lines: 0.0015125552813212077 minutes
# Processed 545000 lines.
# Time taken to process 500 lines: 0.0030665119489034017 minutes
# Processed 545500 lines.
# Time taken to process 500 lines: 0.001535348097483317 minutes
# Processed 546000 lines.
# Time taken to process 500 lines: 0.0014284690221150716 minutes
# Processed 546500 lines.
# Time taken to process 500 lines: 0.001080004374186198 minutes
# Processed 547000 lines.
# Time taken to process 500 lines: 0.0013274749120076497 minutes
# Processed 547500 lines.
# Time taken to process 500 lines: 0.0015594124794006347 minutes
# Processed 548000 lines.
# Time taken to process 500 lines: 0.001618945598602295 minutes
# Processed 548500 lines.
# Time taken to process 500 lines: 0.0011535048484802245 minutes
# Processed 549000 lines.
# Time taken to process 500 lines: 0.0014287233352661133 minutes
# Processed 549500 lines.
# Time taken to process 500 lines: 0.0013289411862691244 minutes
# Processed 550000 lines.
# Time taken to process 500 lines: 0.0021396795908610027 minutes
# Processed 550500 lines.
# Time taken to process 500 lines: 0.001663486162821452 minutes
# Processed 551000 lines.
# Time taken to process 500 lines: 0.0015026648839314778 minutes
# Processed 551500 lines.
# Time taken to process 500 lines: 0.001311798890431722 minutes
# Processed 552000 lines.
# Time taken to process 500 lines: 0.001477360725402832 minutes
# Processed 552500 lines.
# Time taken to process 500 lines: 0.0012763619422912597 minutes
# Processed 553000 lines.
# Time taken to process 500 lines: 0.0016068259874979654 minutes
# Processed 553500 lines.
# Time taken to process 500 lines: 0.001153719425201416 minutes
# Processed 554000 lines.
# Time taken to process 500 lines: 0.001341700553894043 minutes
# Processed 554500 lines.
# Time taken to process 500 lines: 0.0013226151466369628 minutes
# Processed 555000 lines.
# Time taken to process 500 lines: 0.0013052821159362793 minutes
# Processed 555500 lines.
# Time taken to process 500 lines: 0.0012354691823323568 minutes
# Processed 556000 lines.
# Time taken to process 500 lines: 0.0012692968050638834 minutes
# Processed 556500 lines.
# Time taken to process 500 lines: 0.0014326333999633788 minutes
# Processed 557000 lines.
# Time taken to process 500 lines: 0.001611618200937907 minutes
# Processed 557500 lines.
# Time taken to process 500 lines: 0.001027679443359375 minutes
# Processed 558000 lines.
# Time taken to process 500 lines: 0.0008689522743225098 minutes
# Processed 558500 lines.
# Time taken to process 500 lines: 0.0009467800458272299 minutes
# Processed 559000 lines.
# Time taken to process 500 lines: 0.0008866747220357259 minutes
# Processed 559500 lines.
# Time taken to process 500 lines: 0.0008016268412272136 minutes
# Processed 560000 lines.
# Time taken to process 500 lines: 0.0032301425933837892 minutes
# Processed 560500 lines.
# Time taken to process 500 lines: 0.0009067336718241374 minutes
# Processed 561000 lines.
# Time taken to process 500 lines: 0.0009594162305196127 minutes
# Processed 561500 lines.
# Time taken to process 500 lines: 0.0009505271911621094 minutes
# Processed 562000 lines.
# Time taken to process 500 lines: 0.001314067840576172 minutes
# Processed 562500 lines.
# Time taken to process 500 lines: 0.0008765896161397298 minutes
# Processed 563000 lines.
# Time taken to process 500 lines: 0.0011875351270039876 minutes
# Processed 563500 lines.
# Time taken to process 500 lines: 0.0008610089619954427 minutes
# Processed 564000 lines.
# Time taken to process 500 lines: 0.0009685238202412923 minutes
# Processed 564500 lines.
# Time taken to process 500 lines: 0.0014617164929707845 minutes
# Processed 565000 lines.
# Time taken to process 500 lines: 0.001987918217976888 minutes
# Processed 565500 lines.
# Time taken to process 500 lines: 0.0022772709528605145 minutes
# Processed 566000 lines.
# Time taken to process 500 lines: 0.0028648535410563153 minutes
# Processed 566500 lines.
# Time taken to process 500 lines: 0.0011498570442199708 minutes
# Processed 567000 lines.
# Time taken to process 500 lines: 0.0012682477633158367 minutes
# Processed 567500 lines.
# Time taken to process 500 lines: 0.001203334331512451 minutes
# Processed 568000 lines.
# Time taken to process 500 lines: 0.00185165802637736 minutes
# Processed 568500 lines.
# Time taken to process 500 lines: 0.0018588821093241373 minutes
# Processed 569000 lines.
# Time taken to process 500 lines: 0.0019789735476175943 minutes
# Processed 569500 lines.
# Time taken to process 500 lines: 0.0016762495040893554 minutes
# Processed 570000 lines.
# Time taken to process 500 lines: 0.0021135449409484864 minutes
# Processed 570500 lines.
# Time taken to process 500 lines: 0.0021576444307963055 minutes
# Processed 571000 lines.
# Time taken to process 500 lines: 0.002210219701131185 minutes
# Processed 571500 lines.
# Time taken to process 500 lines: 0.002295839786529541 minutes

# %%
df = all_bills.copy()
df['date_created'] = pd.to_datetime(df['date_created'])

# Extract the column as a list (if needed)
date_list = df['date_created'].tolist()

# Find min and max dates
min_date = min(date_list)
max_date = max(date_list)

print("Minimum date:", min_date)
print("Maximum date:", max_date)
# Out:
# Minimum date: 2010-07-09 16:16:19
# Maximum date: 2015-05-02 02:02:19

# %%
def get_names(st,text,years, name_list):
    ''' Call Legiscan API
    Conduct string matching of bill title with all results from legiscan API. Kepe only if 90% match ore more'''

    save = 0

    st = st

    if text is not None:
        ti_unproc = text
        ### clean up bill title format. topic - title - metadata. only want title
        parts = ti_unproc.split(' - ')
        if len(parts) > 1: 
            ti = parts[1].strip()  
        else:
            ti = ti_unproc  

        year_str = str(years)
        year = int(year_str[:4])
        sponsors = []
        
        bill_search = legis.search(state = st, query= ti, year= year, page=1)
        counter = 0
        for i in range(len(bill_search['results'])):
            if counter <= len(name_list):
                if bill_search['results'][i]['title'] is not None:

                    ## conducting text match  
                    list1 = bill_search['results'][i]['title'].split()  
                    list2 = ti.split()  
                    matches = sum(1 for x, y in zip(list1, list2) if x == y)
                    if len(list1) > 0:  
                        percentage_match = (matches / len(list2)) 
                    else:
                        percentage_match = 0
                    if percentage_match > 0.9:
                        bill_detail = legis.get_bill(bill_id= bill_search['results'][i]['bill_id'])
                        all_people = bill_detail['sponsors']
                        if len(all_people) >=1:
                            people_id_list = [] 
                            for j in range(len(all_people)):
                                people_id = all_people[j]['people_id']
                                name = legis.get_sponsor(people_id)
                                sponsors.append(name['name'])
                            
                            
            else: 
                break
    else: 
        sponsors = []
        
    print(sponsors)
    print('____________________________________________')
    return sponsors

# %%
df_new = df.copy()

## Extract sponsors from dictionary object in column
df_new['name_list'] = df_new['sponsers'].apply(lambda sponsers: [x['name'].lower() for x in sponsers if x['type'] == 'primary'])

# %%
def split_dataframe(df, chunk_size):
    chunks = [df[i:i + chunk_size] for i in range(0, df.shape[0], chunk_size)]
    return chunks

# Split df_new into chunks of 100 rows each``
chunk_size = 100
df_chunks = split_dataframe(df_new, chunk_size)

# %%
j = 0
chunk_results = []  # This will hold the results for all chunks
error_dict = {}

for chunk in df_chunks:
    print(j)
    print('____________________________________________')
    result = []  # Reset result list for each chunk

    for i in range(len(chunk)):
        row_data = chunk.iloc[i]  # Get current row
        st = row_data['state']
        text = row_data['bill_title']
        years = row_data['date_introduced']
        name_list = row_data['name_list']

        # Debug prints
        
        print(i)
        print(st)
        print(text)
        print(years)
        print(name_list)

        try:
            ff = get_names(st, text, years, name_list) 
            result.append(ff)  
        except Exception as e:  
            print(f'Error processing row {i} in current chunk, setting results to None.')
            ## store what chunk and what row error ocurred. set row result to empty list
            error_dict[j] = i

            result = [None] * len(chunk)  
            break  
    chunk_results.append(result)  # Append the collective or None results of this chunk to chunk_results
    j += 1
# Out:
# 0
# ____________________________________________
# 0
# nh
# relative to hearings in the department of safety.
# 2013-01-03 11:50:16
# ['jim b rausch']
# []
# ____________________________________________
# 1
# nh
# establishing a commission on housing policy and regulation.
# 2013-01-31 11:03:40
# ['bob odell']
# []
# ____________________________________________
# 2
# nh
# repealing New Hampshire's atomic energy policy.
# 2013-01-03 09:25:01
# ['robert a backus']
# []
# ____________________________________________
# 3
# nh
# relative to the authority of the department of state.
# 2013-01-03 03:22:25
# ['lynne m ober']
# []
# ____________________________________________
# 4
# nh
# relative to child passenger restraint requirements.
# 2013-01-03 11:30:41
# ['sally h kelly']
# []
# ____________________________________________
# 5
# nh
# relative to membership of village districts in regional planning commissions.
# 2013-01-03 01:25:34
# ['james e coffey']
# []
# ____________________________________________
# 6
# nh
# relative to the disposition of dedicated funds.
# 2015-01-08 09:09:15
# ['chuck w morse']
# []
# ____________________________________________
# 7
# nh
# extending the New Hampshire health protection program.
# 2015-01-29 02:17:25
# ['david pierce']
# []
# ____________________________________________
# 8
# nh
# making a capital appropriation for a facility in Milford for a circuit court and a division of motor vehicles office.
# 2015-01-08 02:58:23
# ['gary l. daniels']
# ['Gary Daniels', 'Peter Leishman', 'Frank Edelblut', 'Kevin Avard', 'Jack Flanagan']
# ____________________________________________
# 9
# nh
# relative to workers' compensation for domestic employees.
# 2015-01-08 08:43:49
# ['donald l. lebrun']
# []
# ____________________________________________
# 10
# nh
# enabling the department of environmental services and the town of New Ipswich to negotiate an agreement regarding the encroachment of the town cemetery on state land.
# 2015-01-08 09:58:02
# ['james e. coffey']
# ['James Coffey', 'James Parison']
# ____________________________________________
# 11
# nh
# relative to the statewide improvement and assessment program.
# 2015-01-08 03:33:23
# ['rick m. ladd']
# []
# ____________________________________________
# 12
# nh
# prohibiting an employer from using credit history in employment decisions.
# 2015-01-08 10:01:20
# ['robert r. cushing']
# []
# ____________________________________________
# 13
# nh
# relative to proof of identity by voters.
# 2013-12-11 03:49:27
# ['david pierce']
# []
# ____________________________________________
# 14
# nh
# establishing a commission to study fiscal disparities between public school districts.
# 2013-12-16 03:47:13
# ['gary b richardson']
# []
# ____________________________________________
# 15
# nh
# exempting proprietorships from taxation under the business profits tax.
# 2013-12-16 03:11:43
# ['daniel c. itse']
# []
# ____________________________________________
# 16
# nh
# repealing New Hampshire's atomic energy policy.
# 2013-01-03 09:25:01
# ['robert a. backus']
# []
# ____________________________________________
# 17
# nh
# relative to the authority of the department of state.
# 2013-01-03 03:22:25
# ['lynne m. ober']
# []
# ____________________________________________
# 18
# nh
# increasing the limit on single wagers for games of chance conducted by charitable organizations.
# 2011-01-19 03:12:43
# ['john t gallus']
# ['John Gallus', "Lou D'Allesandro", 'Frank Sapareto', 'Yvonne Thomas', 'Edmond Gionet', 'Herbert Richardson']
# ____________________________________________
# 19
# nh
# establishing a restitution fund for victims of financial fraud and continually appropriating a special fund.
# 2011-02-03 03:12:43
# ["lou d'allesandro"]
# ["Lou D'Allesandro", 'Donna Schlachman', 'Kenneth Gidge']
# ____________________________________________
# 20
# nh
# relative to the number of years for calculating average final compensation for retirement system benefits.
# 2011-01-21 02:40:03
# ['kenneth   hawkins']
# ['Jeb Bradley', 'Neal Kurk', 'Ken Hawkins', 'John Reagan', 'Raymond White']
# ____________________________________________
# 21
# nh
# relative to the definition of political communication.
# 2011-01-11 12:45:19
# ['david bates']
# []
# ____________________________________________
# 22
# nh
# increasing the net operating loss carryover under the business profits tax.
# 2011-01-20 11:45:33
# ['carl w seidel']
# ['Carl Seidel', 'John Cebrowski', 'Pamela Tucker', 'William Smith', 'Jim Luther', 'Timothy Twombly', 'Bill Ohm']
# ____________________________________________
# 23
# nh
# establishing a commission to encourage broadband development and making an appropriation therefor.
# 2011-01-21 11:10:19
# ['laurence m rappaport']
# ['John Gallus', 'Beatriz Pastor-Bodmer', 'Charles Townsend', 'Laurence Rappaport', 'Naida Kaen', 'William Remick']
# ____________________________________________
# 24
# nh
# increasing the limit on single wagers for games of chance conducted by charitable organizations.
# 2011-01-19 03:12:43
# []
# ['John Gallus', "Lou D'Allesandro", 'Frank Sapareto', 'Yvonne Thomas', 'Edmond Gionet', 'Herbert Richardson']
# ____________________________________________
# 25
# nh
# establishing a restitution fund for victims of financial fraud and continually appropriating a special fund.
# 2011-02-03 03:12:43
# ["lou d'allesandro"]
# ["Lou D'Allesandro", 'Donna Schlachman', 'Kenneth Gidge']
# ____________________________________________
# 26
# nh
# repealing the self-funding of the department of labor.
# 2011-12-16 11:08:31
# []
# []
# ____________________________________________
# 27
# nh
# relative to the applicability of foreign law in cases before New Hampshire tribunals.
# 2011-11-22 12:46:08
# ['regina m birdsell']
# []
# ____________________________________________
# 28
# nh
# relative to the definition of spent material.
# 2011-11-28 09:41:47
# []
# []
# ____________________________________________
# 29
# nh
# relative to the number of years for calculating average final compensation for retirement system benefits.
# 2011-01-21 02:40:03
# []
# ['Jeb Bradley', 'Neal Kurk', 'Ken Hawkins', 'John Reagan', 'Raymond White']
# ____________________________________________
# 30
# nh
# relative to the definition of political communication.
# 2011-01-11 12:45:19
# []
# []
# ____________________________________________
# 31
# nh
# relative to the net operating loss carryover under the business profits tax.
# 2011-01-20 11:45:33
# []
# []
# ____________________________________________
# 32
# wi
# development of a system of short-term sanctions for individuals who violate conditions of extended supervision, parole, probation, or a deferred prosecution agreement and granting rule-making authority.
# 2014-02-03 00:00:00
# ['harsdorf', 'darling', 'l. taylor', 'cowles', 'gudex', 'olsen', 'carpenter', 'schultz']
# ['John Nygren', 'Joan Ballweg', 'Garey Bies', 'Mary Felzkowski', 'Michael Endsley', 'Joel Kleefisch', 'Dan Knodl', 'Dean Knudson', 'Dale Kooyenga', 'Scott Krug', 'Tom Larson', 'Daniel LeMahieu', 'Howard Marklein', 'David Murphy', 'Alvin Ott', 'Kevin Petersen', 'Warren Petryk', 'Rob Swearingen', 'Travis Tranel', 'Jill Billings', 'Evan Goyke', 'Gary Hebl', 'Robb Kahl', 'Sandra Pasch', 'Jon Richards', 'Janis Ringhand', 'Jocasta Zamarripa', 'Sheila Harsdorf', 'Alberta Darling', 'Lena Taylor', 'Robert Cowles', 'Richard Gudex', 'Luther Olsen', 'Timothy Carpenter', 'Dale Schultz', 'Glenn Grothman', 'Sheila Harsdorf', 'Alberta Darling', 'Lena Taylor', 'Robert Cowles', 'Richard Gudex', 'Luther Olsen', 'Timothy Carpenter', 'Dale Schultz', 'John Nygren', 'Joan Ballweg', 'Mary Felzkowski', 'Michael Endsley', 'Joel Kleefisch', 'Dan Knodl', 'Dean Knudson', 'Dale Kooyenga', 'Scott Krug', 'Tom Larson', 'Daniel LeMahieu', 'Howard Marklein', 'David Murphy', 'Alvin Ott', 'Kevin Petersen', 'Warren Petryk', 'Rob Swearingen', 'Travis Tranel', 'Jill Billings', 'Evan Goyke', 'Gary Hebl', 'Robb Kahl', 'Sandra Pasch', 'Jon Richards', 'Janis Ringhand', 'Jocasta Zamarripa']
# ____________________________________________
# 33
# wi
# an income and franchise tax credit for workplace wellness programs, granting rule-making authority, and requiring the exercise of rule-making authority.
# 2013-03-13 00:00:00
# ['moulton', 'l. taylor', 'lazich', 'gudex', 'harsdorf', 'leibham', 'shilling', 'lassa']
# ['Terry Moulton', 'Lena Taylor', 'Mary Lazich', 'Richard Gudex', 'Sheila Harsdorf', 'Joe Leibham', 'Jennifer Shilling', 'Julie Lassa', 'John Murtha', 'Travis Tranel', 'Tom Larson', 'Mandy Wright', 'Garey Bies', 'Mark Honadel', 'Kathleen Bernier', 'Dean Kaufert', 'Alvin Ott', 'Steve Doyle', 'Janis Ringhand', 'Debra Kolste', 'Kevin Petersen', 'Michael Endsley', 'John Spiros', 'Daniel LeMahieu', 'Robb Kahl', 'Warren Petryk', 'Ed Brooks', 'Jeff Stone', 'Tod Ohnstad', 'Lee Nerison', 'John Murtha', 'Travis Tranel', 'John Spiros', 'Daniel LeMahieu', 'Robb Kahl', 'Warren Petryk', 'Ed Brooks', 'Jeff Stone', 'Kathleen Bernier', 'Tom Larson', 'Mandy Wright', 'Garey Bies', 'Mark Honadel', 'Steve Doyle', 'Debra Kolste', 'Tod Ohnstad', 'Dean Kaufert', 'Alvin Ott', 'Janis Ringhand', 'Kevin Petersen', 'Michael Endsley', 'Lee Nerison', 'Terry Moulton', 'Mary Lazich', 'Richard Gudex', 'Sheila Harsdorf', 'Lena Taylor', 'Jennifer Shilling', 'Joe Leibham', 'Julie Lassa']
# ____________________________________________
# 34
# wi
# creating a veterans-themed lottery game, changing the primary source of funding for the veterans and surviving spouses property tax credit, and making appropriations.
# 2013-03-27 00:00:00
# ['petrowski', 'carpenter', 'lassa', 'schultz']
# ['Jerry Petrowski', 'Timothy Carpenter', 'Julie Lassa', 'Dale Schultz', 'Warren Petryk', 'Thomas Weatherston', 'Joan Ballweg', 'Kathleen Bernier', 'Ed Brooks', 'Mary Felzkowski', 'Michael Endsley', 'Tom Larson', 'Jeffrey Mursau', 'Alvin Ott', 'Mary Williams', 'Warren Petryk', 'Thomas Weatherston', 'Joan Ballweg', 'Kathleen Bernier', 'Ed Brooks', 'Mary Felzkowski', 'Michael Endsley', 'Tom Larson', 'Jeffrey Mursau', 'Alvin Ott', 'Mary Williams', 'Jerry Petrowski', 'Timothy Carpenter', 'Julie Lassa', 'Dale Schultz']
# ____________________________________________
# 35
# wi
# exempting employers from keeping records of the hours of employment of an employee who is exempt from the overtime pay requirement and who is not compensated on an hourly rate basis.
# 2014-01-31 00:00:00
# ['born', 'ballweg', 'bies', 'brooks', 'jacque', 'jagler', 'kestell', 'knodl', 'kulp', 't. larson', 'lemahieu', 'marklein', 'murtha', 'thiesfeldt']
# []
# ____________________________________________
# 36
# wi
# establishing a competitive election criteria for redistricting the legislature (first consideration).
# 2013-04-15 00:00:00
# ['kessler']
# ['Frederick Kessler']
# ____________________________________________
# 37
# wi
# the life and public service of Michael Harried.
# 2013-02-07 00:00:00
# ['kahl']
# []
# ____________________________________________
# 38
# wi
# social and financial impact reports.
# 2013-06-06 00:00:00
# ['kapenga', 'sanfelippo', 'jacque', 'tittl', 'schraa', 'ripp', 'craig']
# []
# ____________________________________________
# 39
# wi
# commending the University of Wisconsin-Whitewater gymnastics team for winning a second consecutive national championship.
# 2013-04-30 00:00:00
# ['jorgensen', 'kolste', 'ringhand', 'berceau', 'danou', 'hintz', 'hutton', 'kahl', 'kerkman', 'marklein', 'milroy', 'murphy', 'nass', 'ripp', 'spiros', 'wachs', 'wright']
# ['Andrew Jorgensen', 'Debra Kolste', 'Janis Ringhand', 'Terese Berceau', 'Christopher Danou', 'Gordon Hintz', 'Rob Hutton', 'Robb Kahl', 'Samantha Kerkman', 'Howard Marklein', 'Nick Milroy', 'David Murphy', 'Steve Nass', 'Keith Ripp', 'John Spiros', 'Dana Wachs', 'Mandy Wright', 'Timothy Cullen', 'Neal Kedzie', 'Julie Lassa', 'Lena Taylor']
# ____________________________________________
# 40
# wi
# entering into an agreement among the states to elect the president of the United States by means of a national popular vote.
# 2010-02-22 00:00:00
# ['risser', 'wirch']
# ['Fred Clark', 'Josh Zepnick', 'Robert Turner', 'Alvin Ott', 'Barbara Toles', 'Dean Kaufert', 'Fred Risser', 'Kristen Dexter', 'Robert Wirch', 'Tamara Grigsby', 'Jason Fields', 'Mark Pocan', 'Annette Williams', 'Christine Sinicki', 'Kelda Roys', 'Spencer Black', 'Terese Berceau', 'Scott Newcomer', 'Fred Clark', 'Josh Zepnick', 'Alvin Ott', 'Barbara Toles', 'Dean Kaufert', 'Fred Risser', 'Kristen Dexter', 'Robert Wirch', 'Tamara Grigsby', 'Jason Fields', 'Mark Pocan', 'Annette Williams', 'Christine Sinicki', 'Kelda Roys', 'Spencer Black', 'Terese Berceau', 'Scott Newcomer']
# ____________________________________________
# 41
# wi
# the lifetime limit under the Health Insurance Risk-Sharing Plan.
# 2009-02-18 00:00:00
# ['vinehout', 'erpenbach', 'robson', 'lehman', 'carpenter', 'wirch', 'taylor', 'coggs', 'hansen', 'miller']
# []
# ____________________________________________
# 42
# wi
# allowing an individual income tax deduction for certain amounts contributed by a divorced or legally separated parent to his or her child's college savings account or college tuition and expenses program and limiting the deduction that may be claimed by a married person who files separately.
# 2009-03-11 00:00:00
# ['lassa', 'kreitlow', 'taylor', 'darling', 'holperin', 'lehman', 'erpenbach', 'plale', 'grothman', 'olsen', 'kedzie']
# ['Louis Molepske', 'Jon Erpenbach', 'Scott Suder', 'Dean Kaufert', 'Lena Taylor', 'Alberta Darling', 'Steve Kestell', 'David Cullen', 'Josh Zepnick', 'Neal Kedzie', 'Robin Vos', 'Glenn Grothman', 'Luther Olsen', 'Pat Kreitlow', 'Jim Holperin', 'Terese Berceau', 'Sondy Pope', 'Jon Richards', 'Kelda Roys', 'Jeff Smith', 'Jeffrey Plale', 'Jason Fields', 'Julie Lassa', 'John Lehman', 'Garey Bies', 'Steve Nass', 'Louis Molepske', 'Jon Erpenbach', 'Scott Suder', 'Lena Taylor', 'Alberta Darling', 'Steve Kestell', 'David Cullen', 'Josh Zepnick', 'Neal Kedzie', 'Robin Vos', 'Glenn Grothman', 'Luther Olsen', 'Pat Kreitlow', 'Terese Berceau', 'Sondy Pope', 'Kelda Roys', 'Jeffrey Plale', 'Jason Fields', 'Julie Lassa', 'John Lehman', 'Garey Bies', 'Jim Holperin', 'Steve Nass']
# ____________________________________________
# 43
# wi
# a sales and use tax exemption for extended-range electric vehicles; a property tax exemption for tangible personal property used to recharge electric vehicles; the motor vehicle emission inspection and maintenance program, extended-range electric vehicle grants; an income and franchise tax credit for research conducted in this state by a corporation; a property and sales and use tax exemption for certain machinery and tangible personal property used to conduct research; granting rule-making authority; and making appropriations.
# 2010-02-09 00:00:00
# ['stone', 'richards', 'vos', 'pasch', 'honadel', 'fields', 'gottlieb', 'roys', 'huebsch', 'turner', 'davis', 'gunderson', 'montgomery', 'roth', 'strachota', 'zipperer', 'townsend', 'bies', 'steinbrink', 'knodl']
# ['Sandra Pasch', 'Patricia Strachota', 'Alberta Darling', 'Roger Roth', 'John Steinbrink', 'Dale Schultz', 'Jeff Stone', 'Phil Montgomery', 'Mark Gottlieb', 'Robin Vos', 'Michael Huebsch', 'Brett Davis', 'Robert Turner', 'Jon Richards', 'Kelda Roys', 'Jeffrey Plale', 'Jason Fields', 'Garey Bies', 'Dan Knodl', 'John Townsend', 'Scott Gunderson', 'Mark Honadel', 'Rich Zipperer', 'Sandra Pasch', 'Brett Davis', 'Michael Huebsch', 'Patricia Strachota', 'Alberta Darling', 'Roger Roth', 'John Steinbrink', 'Dale Schultz', 'Jeff Stone', 'Phil Montgomery', 'Mark Gottlieb', 'Robin Vos', 'Robert Turner', 'Mark Honadel', 'Jon Richards', 'Kelda Roys', 'Jeffrey Plale', 'Jason Fields', 'Garey Bies', 'Dan Knodl', 'Alan Lasee', 'Jim Sullivan', 'Samantha Kerkman', 'John Townsend', 'Scott Gunderson', 'Rich Zipperer']
# ____________________________________________
# 44
# wi
# declaring May as Amyotrophic Lateral Sclerosis Awareness Month.
# 2009-03-04 00:00:00
# ['strachota', 'benedict', 'spanbauer', 'm. williams', 'berceau', 'a. ott', 'dexter', 'bies', 'brooks', 'pasch', 'kaufert', 'lothian', 'hintz']
# []
# ____________________________________________
# 45
# wi
# the life and public service of Jerome J. Kleczka.
# 2009-02-03 00:00:00
# ['sinicki', 'richards', 'zepnick']
# []
# ____________________________________________
# 46
# wi
# determining eligibility of certain persons for Medical Assistance without consideration of a spouse's income or assets.
# 2009-04-30 00:00:00
# ['roth', 'smith', 'bies', 'brooks', 'gunderson', 'kaufert', 'lothian', 'a. ott', 'petersen', 'spanbauer', 'townsend', 'm. williams']
# ['Jeff Smith', 'Dale Schultz', 'Roger Roth', 'Mary Williams', 'Ed Brooks', 'Lena Taylor', 'Alvin Ott', 'Dean Kaufert', 'Scott Gunderson', 'John Townsend', 'Luther Olsen', 'Richard Spanbauer', 'Thomas Lothian', 'Garey Bies', 'Julie Lassa', 'Kevin Petersen']
# ____________________________________________
# 47
# wi
# commemorating the 20th anniversary of the Lower Wisconsin State Riverway.
# 2009-03-13 00:00:00
# ['black', 'garthwaite', 'hilgenberg', 'nerison', 'clark']
# []
# ____________________________________________
# 48
# wi
# Relating to: instruments filed or recorded with, and fees charged by, the register of deeds. (FE)
# 2015-03-10 00:00:00
# ['olsen', 'nass', 'bewley', 'darling', 'gudex', 'harsdorf', 'vinehout', 'wanggaard', 'wirch']
# []
# ____________________________________________
# 49
# wi
# Relating to: regulation of transportation network companies, providing an exemption from emergency rule procedures, granting rule-making authority, and providing a penalty. (FE)
# 2015-03-31 00:00:00
# ['farrow', 'lassa', 'lasee', 'gudex', 'marklein', 'nass', 'vukmir', 'wanggaard']
# []
# ____________________________________________
# 50
# wi
# Relating to: remembrance of April 24, 2015, as the 100th Anniversary of the Armenian Genocide.
# 2015-04-08 00:00:00
# ['weatherston', 'barca', 'bernier', 'brandtjen', 'goyke', 'jacque', 'kerkman', 'kitchens', 'mason', 'murtha', 'ohnstad', 'petryk', 'riemer', 'ripp', 'rodriguez', 'schraa', 'shankland', 'skowronski', 'spreitzer', 'c. taylor', 'tittl', 'zepnick']
# []
# ____________________________________________
# 51
# wi
# Relating to: deleting from the constitution the office of state treasurer (first consideration).
# 2015-01-29 00:00:00
# ['schraa', 'august', 'neylon', 'kuglitsch', 'czaja', 'craig', 'rohrkaste', 'born', 'kremer', 'sanfelippo', 'allen', 'knudson', 'petersen', 'krug', 'r. brooks', 'tauchen', 'horlacher', 'tittl', 'gannon', 'kleefisch', 'weatherston', 'steffen', 'genrich']
# []
# ____________________________________________
# 52
# wi
# Relating to: commemorating the economic impacts of sportsmen and sportswomen in Wisconsin.
# 2015-04-22 00:00:00
# ['kleefisch', 'milroy', 'a. ott']
# []
# ____________________________________________
# 53
# wi
# fees for dental services.
# 2012-03-06 00:00:00
# ['wanggaard', 'galloway', 'holperin', 'lasee', 'vinehout', 'moulton', 'lazich', 'hansen', 'schultz', 'erpenbach', 'king', 'shilling']
# []
# ____________________________________________
# 54
# wi
# the authority of attorneys to issue subpoenas.
# 2011-04-21 00:00:00
# ['taylor']
# []
# ____________________________________________
# 55
# wi
# absence without leave from a legislative session and providing a penalty.
# 2011-05-24 00:00:00
# ['lasee', 'vukmir']
# ['Frank Lasee', 'Leah Vukmir', 'Tyler August', 'Donald Pridemore', 'Steve Kestell', 'Steve Nass', 'Jeremy Thiesfeldt', 'Tyler August', 'Donald Pridemore', 'Steve Kestell', 'Steve Nass', 'Jeremy Thiesfeldt', 'Frank Lasee', 'Leah Vukmir']
# ____________________________________________
# 56
# wi
# the sale, consumption, or possession of high-concentration alcohol beverages and providing penalties.
# 2012-03-15 00:00:00
# ['krusick']
# ['Peggy Krusick']
# ____________________________________________
# 57
# wi
# proclaiming May 13, 14, and 15, 2011, Syttende Mai Weekend.
# 2011-04-05 00:00:00
# ['hebl', 'nerison', 'milroy', 'hulsey', 'knudson', 'bewley', 'pope-roberts', 'spanbauer', 'bernard schaber', 'berceau', 'brooks', 'steineke', 'bernier']
# []
# ____________________________________________
# 58
# wi
# commending Reince Priebus on his election as chairman of the Republican National Committee.
# 2011-01-25 00:00:00
# ['vos', 'kerkman', 'j. fitzgerald', 'august', 'ballweg', 'bernier', 'bies', 'brooks', 'e. coggs', 'endsley', 'farrow', 'honadel', 'jacque', 'kapenga', 'kaufert', 'kestell', 'kleefisch', 'klenke', 'knilans', 'knodl', 'knudson', 'kooyenga', 'kramer', 'krug', 'kuglitsch', 't. larson', 'lemahieu', 'litjens', 'loudenbeck', 'marklein', 'meyer', 'mursau', 'murtha', 'nass', 'nerison', 'nygren', 'a. ott', 'j. ott', 'petersen', 'petrowski', 'petryk', 'pridemore', 'ripp', 'rivard', 'severson', 'spanbauer', 'steineke', 'stone', 'strachota', 'suder', 'tauchen', 'thiesfeldt', 'tiffany', 'tranel', 'van roy', 'williams', 'weininger', 'wynn']
# ['Robin Vos', 'Samantha Kerkman', 'Jeff Fitzgerald', 'Tyler August', 'Joan Ballweg', 'Kathleen Bernier', 'Garey Bies', 'Ed Brooks', 'Elizabeth Coggs', 'Michael Endsley', 'Paul Farrow', 'Mark Honadel', 'Andre Jacque', 'Chris Kapenga', 'Dean Kaufert', 'Steve Kestell', 'Joel Kleefisch', 'John Klenke', 'Joe Knilans', 'Dan Knodl', 'Dean Knudson', 'Dale Kooyenga', 'William Kramer', 'Scott Krug', 'Mike Kuglitsch', 'Tom Larson', 'Daniel LeMahieu', 'Michelle Litjens', 'Amy Loudenbeck', 'Howard Marklein', 'Dan Meyer', 'Jeffrey Mursau', 'John Murtha', 'Steve Nass', 'Lee Nerison', 'John Nygren', 'Alvin Ott', 'Jim Ott', 'Kevin Petersen', 'Jerry Petrowski', 'Warren Petryk', 'Donald Pridemore', 'Keith Ripp', 'Roger Rivard', 'Erik Severson', 'Richard Spanbauer', 'Jim Steineke', 'Jeff Stone', 'Patricia Strachota', 'Scott Suder', 'Gary Tauchen', 'Jeremy Thiesfeldt', 'Thomas Tiffany', 'Travis Tranel', 'Karl Van Roy', 'Mary Williams', 'Chad Weininger', 'Evan Wynn', 'Robert Wirch', 'Robert Cowles', 'Alberta Darling', 'Michael Ellis', 'Dan Kapanke', 'Neal Kedzie', 'Frank Lasee', 'Mary Lazich', 'Joe Leibham', 'Luther Olsen', 'Leah Vukmir', 'Dale Schultz']
# ____________________________________________
# 59
# wi
# the sales and use tax exemption for electricity and natural gas.
# 2011-08-30 00:00:00
# ['kleefisch', 'jacque', 'kaufert', 'petrowski', 'mursau']
# ['Joel Kleefisch', 'Andre Jacque', 'Dean Kaufert', 'Jerry Petrowski', 'Jeffrey Mursau', 'Van Wanggaard', 'Dale Schultz']
# ____________________________________________
# 60
# wi
# the right of the people to contract privately for health care services and health care coverage, and prohibiting requiring a person to obtain or maintain health insurance coverage or to participate in any health care system or plan (first consideration).
# 2011-04-12 00:00:00
# ['vos', 'steineke', 'kestell', 'august', 'meyer', 'strachota', 'nygren', 'severson', 'petryk', 'krug', 'ziegelbauer', 'petersen', 'bies', 'spanbauer', 'lemahieu', 'kleefisch', 'endsley', 'honadel', 'mursau']
# ['Robin Vos', 'Jim Steineke', 'Steve Kestell', 'Tyler August', 'Dan Meyer', 'Patricia Strachota', 'John Nygren', 'Erik Severson', 'Warren Petryk', 'Scott Krug', 'Bob Ziegelbauer', 'Kevin Petersen', 'Garey Bies', 'Richard Spanbauer', 'Daniel LeMahieu', 'Joel Kleefisch', 'Michael Endsley', 'Mark Honadel', 'Jeffrey Mursau', 'Joe Leibham', 'Frank Lasee', 'Randy Hopper', 'Pamela Galloway', 'Mary Lazich', 'Terry Moulton', 'Alberta Darling', 'Joe Leibham', 'Frank Lasee', 'Randy Hopper', 'Pamela Galloway', 'Mary Lazich', 'Terry Moulton', 'Alberta Darling', 'Robin Vos', 'Jim Steineke', 'Steve Kestell', 'Tyler August', 'Dan Meyer', 'Patricia Strachota', 'John Nygren', 'Erik Severson', 'Warren Petryk', 'Scott Krug', 'Bob Ziegelbauer', 'Kevin Petersen', 'Garey Bies', 'Richard Spanbauer', 'Daniel LeMahieu', 'Joel Kleefisch', 'Michael Endsley', 'Mark Honadel', 'Jeffrey Mursau']
# ____________________________________________
# 61
# md
# Caroline County - Board of Education - Selection of Members - Straw Ballot
# 2008-03-03 00:00:00
# ['pipkin']
# []
# ____________________________________________
# 62
# md
# Health Care Facility Visitation and Medical Decisions - Domestic Partners
# 2008-02-01 00:00:00
# []
# []
# ____________________________________________
# 63
# md
# Family Law - Child Abuse and Neglect - Definition of Abuse - Clarification
# 2008-01-18 00:00:00
# []
# []
# ____________________________________________
# 64
# md
# Wicomico County - Alcoholic Beverages Act of 2008
# 2008-01-18 00:00:00
# ['colburn']
# []
# ____________________________________________
# 65
# md
# Environment - Clean Air Permit Fees
# 2008-01-31 00:00:00
# []
# []
# ____________________________________________
# 66
# md
# Real Estate Salespersons - Qualifications for Licensure - Education
# Requirements
# 2008-01-18 00:00:00
# []
# []
# ____________________________________________
# 67
# md
# Prince George's County - Alcoholic Beverages - Waterfront Entertainment Retail
# Complex and Wine Festival
# 2008-02-11 00:00:00
# []
# []
# ____________________________________________
# 68
# md
# Agriculture - Wild Pollinators Program
# 2008-01-31 00:00:00
# ['glassman']
# []
# ____________________________________________
# 69
# md
# Nurse Practitioners - Authority to Certify
# 2008-02-18 00:00:00
# ['dyson']
# []
# ____________________________________________
# 70
# md
# Competitive Sealed Proposals - Disclosure of Information - Minority Business
# Enterprise Participation
# 2008-03-03 00:00:00
# []
# []
# ____________________________________________
# 71
# md
# Criminal Law - Use of Firearm in the Commission of a Crime of Violence or a
# Felony
# 2008-02-15 00:00:00
# []
# []
# ____________________________________________
# 72
# md
# Task Force on Health Care Access and Reimbursement - Extension
# 2008-01-23 00:00:00
# ['pendergrass']
# []
# ____________________________________________
# 73
# md
# Identity Fraud - Prohibitions, Evidence, and Penalties
# 2008-02-07 00:00:00
# []
# []
# ____________________________________________
# 74
# md
# Credit Regulation - Mortgage Lending and Other Extensions of Credit
# 2008-01-25 00:00:00
# []
# []
# ____________________________________________
# 75
# md
# Homeowner's Property Tax Credit - Cost-of-Living Adjustment
# 2008-02-08 00:00:00
# ['olszewski']
# []
# ____________________________________________
# 76
# md
# Unemployment Insurance - State Collection of the Federal Unemployment Insurance
# Tax
# 2008-01-28 00:00:00
# []
# []
# ____________________________________________
# 77
# md
# Creation of a State Debt - Baltimore City - Garrett-Jacobs Mansion
# 2008-01-22 00:00:00
# []
# []
# ____________________________________________
# 78
# md
# Vehicle Laws - Fleeing or Eluding Police - Liability of Vehicle Owners
# 2008-02-08 00:00:00
# ['donoghue']
# []
# ____________________________________________
# 79
# md
# Bay Restoration Fund - Disbursement of Funds
# 2008-02-04 00:00:00
# []
# []
# ____________________________________________
# 80
# md
# Creation of a State Debt - Somerset County - Bending Water Park
# 2008-02-07 00:00:00
# []
# []
# ____________________________________________
# 81
# md
# Civil Actions - Child Sexual Abuse - Statute of Limitations and Limitation of
# Damages
# 2008-02-06 00:00:00
# []
# []
# ____________________________________________
# 82
# md
# Maryland Veterans Behavioral Health
# 2008-01-25 00:00:00
# []
# []
# ____________________________________________
# 83
# md
# Task Force on Classroom Indoor Air Quality Standards
# 2007-07-16 00:00:00
# ['rice']
# []
# ____________________________________________
# 84
# md
# Business Regulation - Mold Remediation Services - Licensing
# 2008-02-08 00:00:00
# ['mchale']
# []
# ____________________________________________
# 85
# md
# Public Safety - Emergency Medical Services Board - Membership
# 2008-01-31 00:00:00
# []
# []
# ____________________________________________
# 86
# md
# Garrett County - Gaming Events Regulation - Repeal
# 2008-01-31 00:00:00
# ['beitzel']
# []
# ____________________________________________
# 87
# md
# Criminal Law - Offensive Physical Contact
# 2008-02-06 00:00:00
# []
# []
# ____________________________________________
# 88
# md
# Criminal Procedure - Offender Registry - Retroactivity
# 2008-02-01 00:00:00
# []
# []
# ____________________________________________
# 89
# md
# State Personnel - Executive Pay Plans - Reporting Requirements
# 2008-01-30 00:00:00
# ['g. clagett']
# []
# ____________________________________________
# 90
# md
# Joint Committee on Base Realignment and Closure - Additional Members
# 2008-01-18 00:00:00
# ['rudolph']
# []
# ____________________________________________
# 91
# md
# State Board of Morticians - Family Security Trust Fund and Pre-Need Contracts
# 2008-02-07 00:00:00
# []
# []
# ____________________________________________
# 92
# md
# Creation of a State Debt - Capital Area Food Bank
# 2008-02-11 00:00:00
# []
# []
# ____________________________________________
# 93
# md
# Prince George's County - Board of License Commissioners - Compensation of
# Board's Attorney
# PG 330-08
# 2008-02-07 00:00:00
# ["prince george's county delegation"]
# []
# ____________________________________________
# 94
# md
# Juvenile Law - Custodial Interrogation of Minor on School Premises - Recording
# Restrictions
# 2008-02-06 00:00:00
# ['conaway']
# []
# ____________________________________________
# 95
# md
# Creation of a State Debt - Baltimore City - Alpha Phi Alpha Fraternity
# Corporate Headquarters
# 2007-03-02 00:00:00
# ['pugh']
# []
# ____________________________________________
# 96
# md
# Public Utility Companies - Generating Stations - Wind
# 2007-02-02 00:00:00
# []
# []
# ____________________________________________
# 97
# md
# Maryland Health Care Access Act of 2007
# 2007-01-25 00:00:00
# []
# []
# ____________________________________________
# 98
# md
# Public Safety - Eyewitness Identification - Written Policies
# 2007-01-25 00:00:00
# []
# []
# ____________________________________________
# 99
# md
# Property Tax - Agricultural Use Assessment - Migrant Labor Camps
# 2007-02-02 00:00:00
# ['colburn']
# []
# ____________________________________________
# 1
# ____________________________________________
# 0
# md
# Education - Student Discipline - Review of Local Policies and Procedures
# 2007-01-24 00:00:00
# []
# []
# ____________________________________________
# 1
# md
# Hospitals and Nursing Facilities - Health Care-Associated Infections Prevention
# and Control Program
# 2007-02-19 00:00:00
# ['gladden']
# []
# ____________________________________________
# 2
# md
# Income Tax - Subtraction Modification - Military Retirement Income for
# Commissioned Officers
# 2007-02-02 00:00:00
# []
# []
# ____________________________________________
# 3
# md
# Anne Arundel County - Alcoholic Beverages - Board of License Commissioners -
# Inspectors
# 2007-02-21 00:00:00
# ['astle']
# []
# ____________________________________________
# 4
# md
# Maryland Funding Accountability and Transparency Act of 2007
# 2007-03-05 00:00:00
# []
# []
# ____________________________________________
# 5
# md
# Creation of a State Debt - Wicomico County - Wicomico Youth and Civic Center
# 2007-01-31 00:00:00
# []
# []
# ____________________________________________
# 6
# md
# Creation of a State Debt - Washington County - C & O Canal National Historical
# Park
# 2007-02-15 00:00:00
# ['washington county delegation']
# []
# ____________________________________________
# 7
# md
# Environment - Landfills - Termination Date
# 2007-02-02 00:00:00
# ["queen anne's county delegation"]
# []
# ____________________________________________
# 8
# md
# Public Service Commission - For-Hire Driver's License - Review of Driving
# Record of Applicant
# 2007-02-21 00:00:00
# []
# []
# ____________________________________________
# 9
# md
# Maryland Agricultural Commission - Biofuel Industry Member
# 2007-02-05 00:00:00
# []
# []
# ____________________________________________
# 10
# md
# Creation of a State Debt - Frederick County - Agriculture and Education Complex
# 2007-01-26 00:00:00
# ['frederick county delegation']
# []
# ____________________________________________
# 11
# md
# Health Insurance - Uniform Credentialing Form
# 2007-02-20 00:00:00
# ['pendergrass']
# []
# ____________________________________________
# 12
# md
# Pharmacy Benefits Managers Regulation Act
# 2007-02-08 00:00:00
# []
# []
# ____________________________________________
# 13
# md
# Biotechnology Investment Tax Credits
# 2007-02-09 00:00:00
# ['feldman']
# []
# ____________________________________________
# 14
# md
# Energy Companies - Net Energy Metering
# 2007-02-09 00:00:00
# []
# []
# ____________________________________________
# 15
# md
# Medical Malpractice Liability Insurance - Garrett County Memorial Hospital -
# Subsidy for Family Practitioners Who Also Perform Obstetrical Services
# 2007-02-02 00:00:00
# []
# []
# ____________________________________________
# 16
# md
# Creation of a State Debt - Baltimore City - Maryland Science Center
# 2007-01-12 00:00:00
# []
# []
# ____________________________________________
# 17
# md
# Higher Education - Foster Care Recipients - Waiver of Tuition and Fees
# 2007-02-26 00:00:00
# []
# []
# ____________________________________________
# 18
# md
# Creation of a State Debt - Anne Arundel County - Hope House
# 2007-02-07 00:00:00
# []
# []
# ____________________________________________
# 19
# md
# State Employee and Retiree Health and Welfare Benefits Program - Eligibility
# for Enrollment and Participation
# 2007-02-08 00:00:00
# []
# []
# ____________________________________________
# 20
# md
# Criminal Law - Identity Fraud Victims - Judicial Determinations of Innocence
# and Victim Database
# 2007-02-09 00:00:00
# []
# []
# ____________________________________________
# 21
# md
# Vehicle Excise Tax - Rate
# 2007-02-09 00:00:00
# []
# []
# ____________________________________________
# 22
# md
# Ground Rents - Property Owned by Baltimore City - Reimbursement for Expenses -
# Notices
# 2007-02-06 00:00:00
# []
# []
# ____________________________________________
# 23
# md
# Law Enforcement Officers' Pension System - Membership - Martin State Airport
# Law Enforcement Officers
# 2007-01-25 00:00:00
# []
# []
# ____________________________________________
# 24
# md
# Court Records - Divorce - Limiting Access
# 2007-02-13 00:00:00
# ['kipke']
# []
# ____________________________________________
# 25
# md
# Department of Juvenile Services - Victor Cullen Center
# 2007-03-07 00:00:00
# []
# []
# ____________________________________________
# 26
# md
# Electricity - Net Energy Metering - Renewable Energy Portfolio Standard - Solar
# Energy
# 2007-02-09 00:00:00
# []
# []
# ____________________________________________
# 27
# md
# Health Insurance - Low-Income Health Insurance Premium Support Fund
# 2007-02-09 00:00:00
# []
# []
# ____________________________________________
# 28
# md
# Crimes - Threat of Mass Violence
# 2013-02-18 00:00:00
# ['muse']
# []
# ____________________________________________
# 29
# md
# Vehicle Laws - Unregistered Emergency Vehicles - Operating on Highways
# 2013-02-01 00:00:00
# ['brinkley']
# []
# ____________________________________________
# 30
# md
# Dorchester County - Alcoholic Beverages - Micro-Breweries
# 2013-01-17 00:00:00
# ['colburn']
# ['Ben Barnes', 'Jeff Waldstreicher', "Prince George's County Delegation", 'Allegany County Delegation', 'George Edwards', "Prince George's County Delegation", 'Brian McHale', 'Peter Hammen', 'Luke Clippinger']
# ____________________________________________
# 31
# md
# Baltimore City - Fees and Penalties for Unpaid Water and Sewer Usage Charges for Residential Customers
# 2013-01-17 00:00:00
# ['conway']
# []
# ____________________________________________
# 32
# md
# Recycling - Apartment Buildings and Condominiums - Ocean City
# 2013-03-04 00:00:00
# ['mathias and astle']
# []
# ____________________________________________
# 33
# md
# Residential Child Care Programs - Memorandum of Understanding
# 2013-01-30 00:00:00
# ['gladden']
# []
# ____________________________________________
# 34
# md
# Cecil-Harford Highway Impact Revenue Account
# 2013-01-16 00:00:00
# ['glassman']
# ['Barry Glassman', 'Nancy Jacobs', 'J.B. Jennings']
# ____________________________________________
# 35
# md
# Health Occupations Boards - Disciplinary Procedures - Prohibition on Stays
# 2013-02-06 00:00:00
# ['young']
# []
# ____________________________________________
# 36
# md
# Civil Actions - Examination in Aid of Enforcement - Procedure After Arrest for Failure to Appear
# 2013-01-28 00:00:00
# ['frosh']
# []
# ____________________________________________
# 37
# md
# Nancy Grasmick Teacher Award and Walter Sondheim Jr. Public Service Summer Internship Scholarship - Qualifications
# 2013-02-11 00:00:00
# ['ferguson']
# []
# ____________________________________________
# 38
# md
# Teaching Techniques - Students with Special Needs and Limited English Proficiency
# 2013-02-18 00:00:00
# ['montgomery']
# []
# ____________________________________________
# 39
# md
# Education - State Funding - Operating and Capital Funds
# 2013-02-25 00:00:00
# ['luedtke']
# []
# ____________________________________________
# 40
# md
# Maryland Loan Assistance Repayment Program for Physicians - Participation in a Consumer Operated and Oriented Plan (CO-OP) Network
# 2013-01-23 00:00:00
# ['cardin']
# []
# ____________________________________________
# 41
# md
# Procurement - Disclosure Requirements and Penalties
# 2013-02-08 00:00:00
# ['bohanan']
# []
# ____________________________________________
# 42
# md
# Tax Increases - Majority Vote Required
# 2013-01-25 00:00:00
# ['hough']
# []
# ____________________________________________
# 43
# md
# Public Safety - Firearms - Firearms Sales Prohibition
# 2013-02-08 00:00:00
# ['clippinger']
# ['Luiz Simmons', 'Samuel Rosenberg', 'Herbert McMillan', 'Samuel Rosenberg', 'Luiz Simmons', 'Donald Dwyer', 'Glen Glass', 'Michael Hough', 'Richard Impallaria', 'Kevin Kelly', 'Nicholaus Kipke', 'Susan McComas', 'Michael McDermott', 'Patrick McDonough', 'Neil Parrott', 'Michael Smigiel', 'Nancy Stocksdale', 'Jamin Raskin', 'Joan Conway', 'Ulysses Currie', 'William Ferguson', 'Jennie Forehand', 'Brian Frosh', 'Robert Garagiola', 'Verna Jones-Rodwell', 'Nancy King', 'Richard Madaleno', 'Roger Manno', 'Nathaniel McFadden', 'Karen Montgomery', 'Douglas Peters', 'Paul Pinsky', 'Victor Ramirez', 'James Robey', 'Jim Rosapepe', 'Ronald Young', 'Robert Zirkin', 'Ana Gutierrez', 'James Proctor', 'Curtis Anderson', 'Charles Barkley', 'Aisha Braveboy', 'Jon Cardin', 'Alfred Carr', 'Bonnie Cullison', 'Brian Feldman', 'Barbara Frush', 'James Gilchrist', 'Cheryl Glenn', 'Keith Haynes', 'Anne Healey', 'Carolyn Howard', 'Tom Hucker', 'Anne Kaiser', 'Ariana Kelly', 'Susan Lee', 'Eric Luedtke', 'Aruna Miller', 'Keiffer Mitchell', 'Shirley Nathan-Pulliam', 'Joseline Pena-Melnyk', 'Barbara Robinson', 'Shane Robinson', 'Veronica Turner', 'Mary Washington', 'Luiz Simmons']
# ____________________________________________
# 44
# md
# Workers' Compensation - Occupational Disease Presumption - Duty Belt Worn by Law Enforcement
# 2013-01-28 00:00:00
# ['deboy']
# []
# ____________________________________________
# 45
# md
# Baltimore City - School Facilities - Funding
# 2013-01-21 00:00:00
# ['anderson (by request - baltimore city administration)']
# []
# ____________________________________________
# 46
# md
# Vehicle Laws - Motor Scooters and Mopeds - Special Dealer Decals
# 2013-02-08 00:00:00
# ['conway and cane']
# []
# ____________________________________________
# 47
# md
# University System of Maryland - Institution Management - Admissions Requirements
# 2013-02-05 00:00:00
# ['parrott']
# []
# ____________________________________________
# 48
# md
# Creation of a State Debt - Montgomery County - Bohrer Park Miniature Golf Course
# 2013-02-08 00:00:00
# ['barve']
# ['Montgomery County Delegation', 'Montgomery County Delegation', 'Montgomery County Delegation', 'Montgomery County Delegation', 'Montgomery County Delegation', 'Montgomery County Delegation', 'Montgomery County Delegation', 'Montgomery County Delegation', 'Montgomery County Delegation', 'Montgomery County Delegation', 'Heather Mizeur', 'Montgomery County Delegation', 'Montgomery County Delegation']
# ____________________________________________
# 49
# md
# Estates and Trusts - Modified Administration and Inheritance Tax
# 2013-02-07 00:00:00
# ['waldstreicher']
# []
# ____________________________________________
# 50
# md
# Recordation and Transfer Taxes - Transfer of Property Between Related Entities - Exemption
# 2013-01-25 00:00:00
# ['barve']
# []
# ____________________________________________
# 51
# md
# Secondhand Precious Metal Object Dealers - Locations for Transaction of Business
# 2012-09-24 00:00:00
# ['bromwell']
# []
# ____________________________________________
# 52
# md
# Prince George's County - Education - Consolidated and Coordinated Procurement PG 405-13
# 2013-02-08 00:00:00
# ["prince george's county delegation"]
# ['Catherine Pugh', 'Joanne Benson', 'Joan Conway', 'Ulysses Currie', 'William Ferguson', 'Jennie Forehand', 'Barry Glassman', 'Richard Madaleno', 'Roger Manno', 'Nathaniel McFadden', 'Douglas Peters', 'Jamin Raskin', 'Delores Kelley', 'Joanne Benson', 'Joan Conway', 'Ulysses Currie', 'William Ferguson', 'Verna Jones-Rodwell', 'Nancy King', 'Catherine Pugh', 'Edward Reilly', 'Ronald Young', 'Karen Montgomery', 'Joanne Benson', 'Aisha Braveboy', 'Alfred Carr', 'Eric Luedtke', 'Jolene Ivey', 'Anne Kaiser', 'Leroy Myers', 'Alonzo Washington']
# ____________________________________________
# 53
# md
# Vehicle Laws - Misdemeanor Violations - Unsupervised Probation
# 2013-01-30 00:00:00
# ['anderson']
# []
# ____________________________________________
# 54
# md
# Criminal Law - Use of Handgun in Crime of Violence or Felony - Statute of Limitations
# 2013-01-31 00:00:00
# ['clippinger and valderrama']
# []
# ____________________________________________
# 55
# md
# Real Property - Property Used for Methamphetamine Production - Disclosure and Quarantine
# 2013-02-07 00:00:00
# ['m. washington']
# []
# ____________________________________________
# 56
# md
# State Highway Administration - Privatization of Rest Areas and Welcome Centers on State Highways
# 2013-02-06 00:00:00
# ['fisher']
# []
# ____________________________________________
# 57
# md
# Personal and Business Documents - Evidence
# 2013-01-28 00:00:00
# ['niemann']
# []
# ____________________________________________
# 58
# md
# Criminal Procedure - Successive Federal and State Prosecutions - Bar
# 2013-01-17 00:00:00
# ['anderson']
# []
# ____________________________________________
# 59
# md
# Public Utilities - Consumer Relations - Tenant Payment of Landlord Utility Bills
# 2013-02-08 00:00:00
# ['barnes']
# []
# ____________________________________________
# 60
# md
# Public Utilities - Geothermal Heating and Cooling On-Bill Financing - Pilot Program
# 2013-02-18 00:00:00
# ['hucker']
# []
# ____________________________________________
# 61
# md
# Education - Public School Holidays - Easter Monday
# 2013-02-08 00:00:00
# ['hucker and luedtke']
# []
# ____________________________________________
# 62
# md
# Counties and Municipalities - Required Legislation or Regulations - Adoption by Reference
# 2013-02-08 00:00:00
# ['eckardt']
# []
# ____________________________________________
# 63
# md
# Correctional Services - Parole Fund
# 2006-10-29 00:00:00
# []
# []
# ____________________________________________
# 64
# md
# Law Enforcement Officers' Bill of Rights - Alterations
# 2015-02-06 00:00:00
# ['gladden']
# []
# ____________________________________________
# 65
# md
# Creation of a State Debt - Frederick County - Helen Smith Studio
# 2015-01-29 00:00:00
# ['hough and young']
# ['Michael Hough', 'Ronald Young', 'Frederick County Delegation', 'Frederick County Delegation', 'Ronald Young', 'Michael Hough', 'Ronald Young', 'Michael Hough', 'Ronald Young', 'Michael Hough', 'Frederick County Delegation', 'Frederick County Delegation', 'Ronald Young', 'Michael Hough', 'Frederick County Delegation', 'Kelly Schulz', 'Ronald Young', 'Michael Hough', 'Frederick County Delegation', 'Frederick County Delegation', 'Ronald Young', 'Michael Hough', 'Frederick County Delegation', 'Ronald Young', 'Michael Hough', 'Michael Hough', 'Ronald Young', 'Frederick County Delegation']
# ____________________________________________
# 66
# md
# Consultation, Diagnosis, and Treatment of Mental and Emotional Disorders - Consent by Minors
# 2015-01-29 00:00:00
# ['nathan-pulliam']
# []
# ____________________________________________
# 67
# md
# Employees' Pension System - Dorchester County Sanitary Commission - Eligible Governmental Unit
# 2015-02-06 00:00:00
# ['eckardt']
# []
# ____________________________________________
# 68
# md
# Speed Monitoring Systems - Local Designees - Approval
# 2015-01-28 00:00:00
# ['brochin']
# []
# ____________________________________________
# 69
# md
# Real Property - Actions to Quiet Title
# 2015-02-23 00:00:00
# ['waugh']
# []
# ____________________________________________
# 70
# md
# Estates and Trusts - Maryland Trust Act - Incapacity
# 2015-02-06 00:00:00
# ['lee']
# ['Christian Miele', 'Susan Krebs', 'Joseline Pena-Melnyk', 'Sid Saab', 'Peter Hammen', 'Angela Angel', 'Erek Barron', 'Eric Bromwell', 'Bonnie Cullison', 'Antonio Hayes', 'Ariana Kelly', 'Patrick McDonough', 'Herbert McMillan', 'Matt Morgan', 'Dan Morhaim', 'Nathaniel Oaks', 'Shane Pendergrass', 'Kirill Reznik', 'Sheree Sample-Hughes', 'Chris West', 'Karen Lewis Young', 'Susan Lee', 'Susan Lee', 'Christian Miele', 'Joseline Pena-Melnyk', 'Sid Saab']
# ____________________________________________
# 71
# md
# General Provisions - Commemorative Days - Thurgood Marshall Day
# 2015-03-02 00:00:00
# ['conway']
# []
# ____________________________________________
# 72
# md
# Creation of a State Debt - Frederick County - Culler Lake Stormwater Management Project
# 2015-02-04 00:00:00
# ['krimm and k. young']
# ['Michael Hough', 'Ronald Young', 'Frederick County Delegation', 'Frederick County Delegation', 'Ronald Young', 'Michael Hough', 'Ronald Young', 'Michael Hough', 'Ronald Young', 'Michael Hough', 'Frederick County Delegation', 'Frederick County Delegation', 'Ronald Young', 'Michael Hough', 'Frederick County Delegation', 'Kelly Schulz', 'Ronald Young', 'Michael Hough', 'Frederick County Delegation', 'Frederick County Delegation', 'Ronald Young', 'Michael Hough', 'Frederick County Delegation', 'Ronald Young', 'Michael Hough', 'Michael Hough', 'Ronald Young', 'Frederick County Delegation']
# ____________________________________________
# 73
# md
# Video Lottery Facilities - Operation and Employee Licenses - Crimes or Acts of Moral Turpitude or Gambling
# 2015-02-18 00:00:00
# ['chair']
# []
# ____________________________________________
# 74
# md
# Crimes - Law Enforcement Officer - Misconduct In Office
# 2015-02-05 00:00:00
# ['anderson (by request - baltimore city administration) and glenn']
# []
# ____________________________________________
# 75
# md
# General Provisions - Open Meetings Act - Required Training
# 2015-03-05 00:00:00
# ['w. miller']
# ['Susan Krebs', 'Trent Kittleman', 'Gail Bates', 'Susan Krebs', 'Steven Arentz', 'Trent Kittleman', 'Susan McComas', 'Warren Miller', 'Matt Morgan', 'Sid Saab']
# ____________________________________________
# 76
# md
# Consumer Protection - Required Disclosure of Social Security Number - Prohibition
# 2015-02-09 00:00:00
# ['glass and metzgar']
# []
# ____________________________________________
# 77
# md
# Vehicle Laws - Maximum Speed Limits on Highways
# 2015-01-30 00:00:00
# ['beitzel']
# []
# ____________________________________________
# 78
# md
# Sprinkler System Requirements - Tents - Exemption
# 2015-02-23 00:00:00
# ['beitzel']
# []
# ____________________________________________
# 79
# md
# Anne Arundel County - Board of Education - Selection of Members
# 2015-02-13 00:00:00
# ['saab']
# []
# ____________________________________________
# 80
# md
# Real Property - Condominiums and Homeowners Associations - Disclosures to Purchasers on Resale of Unit or Lot - Limitation on Fees
# 2015-02-13 00:00:00
# ['mcmillan']
# []
# ____________________________________________
# 81
# md
# Maryland Medical Assistance Program - Former Foster Care Adolescents - Dental Care
# 2015-02-13 00:00:00
# ['pena-melnyk']
# []
# ____________________________________________
# 82
# md
# Real Property - Vacant and Abandoned Residential Property
# 2015-02-06 00:00:00
# ['walker']
# []
# ____________________________________________
# 83
# md
# Maryland Transportation Authority - Chesapeake Bay Bridge - Toll Collection
# 2014-11-14 00:00:00
# ['mcconkey']
# []
# ____________________________________________
# 84
# md
# State Board of Environmental Health Specialists - Revisions
# 2015-02-11 00:00:00
# ['pendergrass']
# []
# ____________________________________________
# 85
# md
# Family Law - Protecting the Resources of Children in State Custody
# 2015-02-12 00:00:00
# ['valentino-smith']
# []
# ____________________________________________
# 86
# md
# Motor Vehicles - Checkpoints - Prohibition on Targeting Motorcycles
# 2015-02-13 00:00:00
# ['kramer']
# []
# ____________________________________________
# 87
# md
# Criminal Law - Cyberstalking - Penalties
# 2015-02-12 00:00:00
# ['jalisi']
# []
# ____________________________________________
# 88
# md
# Environment - Exploration and Production Waste and Waste From Hydraulic Fracturing
# 2015-02-09 00:00:00
# ['s. robinson']
# []
# ____________________________________________
# 89
# md
# Community Colleges - Tuition Waiver for Disabled Individuals - Requirements
# 2015-01-28 00:00:00
# ['reznik and luedtke']
# []
# ____________________________________________
# 90
# md
# Public Health - Restaurants - Meals for Children
# 2015-02-13 00:00:00
# ['glenn']
# []
# ____________________________________________
# 91
# md
# Maryland-National Capital Park and Planning Commission - Certified County-Based Business Participation Program MC/PG 113-15
# 2015-02-13 00:00:00
# ["montgomery county delegation and prince george's county delegation"]
# []
# ____________________________________________
# 92
# md
# Election Law - Voter Registration and Absentee Voting - Proof of Citizenship
# 2015-02-13 00:00:00
# ['parrott']
# []
# ____________________________________________
# 93
# md
# State Department of Education - Assessment Report for Broadband Capabilities in Public Schools
# ...
# ____________________________________________
# 14
# pa
# An Act amending the act of April 6, 1951 (P.L.69, No.20), known as The Landlord and Tenant Act of 1951, further providing for hearing, judgment, writ of possession and payment of rent by tenant.
# 2013-04-09 00:00:00
# ['r. miller']
# []
# ____________________________________________
# 15
# pa
# An Act amending the act of February 14, 1986 (P.L.2, No.2), known as the Acupuncture Licensure Act, further providing for medical diagnosis; and providing for liability insurance.
# 2013-01-23 00:00:00
# ['readshaw']
# []
# ____________________________________________
# 16
# pa
# An Act amending Title 75 (Vehicles) of the Pennsylvania Consolidated Statutes, further providing for special plates for Pearl Harbor survivors, for special plates for veterans of Korean War, for special plates for recipients of Korean Defense Service Medal, for special plates for veterans of Persian Gulf War, for special plates for recipients of Expeditionary Forces Medal, for special plates for World War II veterans, for special plates for veterans of Vietnam Conflict, for special motorcycle plates for veterans, for Operation Iraqi Freedom veterans plate, for Operation Enduring Freedom veterans plate, for special plates for veterans and for Gold Star Family plate.
# 2013-03-13 00:00:00
# ['christiana']
# []
# ____________________________________________
# 17
# pa
# An Act designating a portion of State Route 2038 in Horsham Township, Montgomery County, as the 2LT James P. Kelly Memorial Highway.
# 2013-04-03 00:00:00
# ['murt']
# []
# ____________________________________________
# 18
# pa
# An Act amending the act of March 10, 1949 (P.L.30, No.14), known as the Public School Code of 1949, in State Board of Education, further providing for membership.
# 2013-05-15 00:00:00
# ['tallman']
# []
# ____________________________________________
# 19
# pa
# An Act amending the act of March 10, 1949 (P.L.30, No.14), known as the Public School Code of 1949, in district superintendents and assistant district superintendents, providing for limitation on severance packages.
# 2013-02-06 00:00:00
# ['lawrence']
# []
# ____________________________________________
# 20
# pa
# An Act providing for procedures in police lineups and for powers and duties of the Attorney General.
# 2013-03-14 00:00:00
# ['matzie']
# []
# ____________________________________________
# 21
# pa
# An Act amending Title 75 (Vehicles) of the Pennsylvania Consolidated Statutes, providing for Share the Road plate.
# 2013-05-16 00:00:00
# ['maloney']
# []
# ____________________________________________
# 22
# pa
# An Act providing for restroom access for certain customers of retail establishments and for a penalty.
# 2013-04-30 00:00:00
# ['kortz']
# []
# ____________________________________________
# 23
# pa
# An Act amending Title 75 (Vehicles) of the Pennsylvania Consolidated Statutes, providing for special farmland preservation registration plates and for the use of a portion of the fee for the plate.
# 2013-03-11 00:00:00
# ['denlinger']
# []
# ____________________________________________
# 24
# pa
# An Act amending the act of March 10, 1949 (P.L.30, No.14), known as the Public School Code of 1949, repealing provisions relating to disclosure of interscholastic athletic opportunities.
# 2013-06-03 00:00:00
# ['knowles']
# []
# ____________________________________________
# 25
# pa
# An Act amending Titles 42 (Judiciary and Judicial Procedure)and 75 (Vehicles) of the Pennsylvania Consolidated Statutes, in forfeitures, further providing for controlled substance forfeiture; providing for vehicle forfeiture when driving under the influence; further providing for procedure with respect to seized property subject to liens and rights of lienholders; and, in driving after imbibing alcohol or utilizing drugs, further providing for grading and for penalties; and making editorial changes.
# 2013-01-22 00:00:00
# ['grove']
# []
# ____________________________________________
# 26
# pa
# An Act amending Titles 18 (Crimes and Offenses) and 42 (Judiciary and Judicial Procedure) of the Pennsylvania Consolidated Statutes, providing for animal hoarding.
# 2013-03-11 00:00:00
# ['caltagirone']
# []
# ____________________________________________
# 27
# pa
# An Act amending Titles 53 (Municipalities Generally) and 66 (Public Utilities) of the Pennsylvania Consolidated Statutes, providing for municipal aggregation of electric generation supply.
# 2013-01-30 00:00:00
# ['readshaw']
# []
# ____________________________________________
# 28
# pa
# An Act amending Title 58 (Oil and Gas) of the Pennsylvania Consolidated Statutes, in development, further providing for use of safety devices.
# 2014-09-16 00:00:00
# ['mirabito']
# []
# ____________________________________________
# 29
# pa
# An Act amending Title 12 (Commerce and Trade) of the Pennsylvania Consolidated Statutes, providing for an angel investment tax credit.
# 2015-02-12 00:00:00
# ['fontana']
# []
# ____________________________________________
# 30
# pa
# An Act amending Title 18 (Crimes and Offenses) of the Pennsylvania Consolidated Statutes, in firearms and other dangerous articles, further providing for persons not to possess, use, manufacture, control, sell or transfer firearms.
# 2015-01-23 00:00:00
# ['hughes']
# []
# ____________________________________________
# 31
# pa
# An Act providing for requirements for hospitals and health care facilities that provide services to sexual assault victims, for provision of information and services relating to emergency contraception and for powers and duties of the Department of Health.
# 2015-02-25 00:00:00
# ['leach']
# []
# ____________________________________________
# 32
# pa
# An Act amending the act of July 8, 1978 (P.L.752, No.140), known as the Public Employee Pension Forfeiture Act, further providing for definitions.
# 2015-01-15 00:00:00
# ['boscola']
# []
# ____________________________________________
# 33
# pa
# An Act amending Title 65 (Public Officers) of the Pennsylvania Consolidated Statutes, in ethics standards and financial disclosure, further providing for restricted activities.
# 2015-02-04 00:00:00
# ['lawrence']
# []
# ____________________________________________
# 34
# pa
# An Act designating a portion of State Route 2029 and 2049, also known as Bath Road, in Bristol Township, Bucks County, as the Sergeant George Stuckey Memorial Road.
# 2015-04-06 00:00:00
# ['davis']
# []
# ____________________________________________
# 35
# pa
# An Act amending the act of March 10, 1949 (P.L.30, No.14), known as the Public School Code of 1949, in school health services, further providing for definitions and providing for notice of peanut or tree nut allergies.
# 2015-02-23 00:00:00
# ['cruz']
# []
# ____________________________________________
# 36
# pa
# An Act amending Title 30 (Fish) of the Pennsylvania Consolidated Statutes, in enforcement, authorizing waterways conservation officers to enforce trespass laws.
# 2015-04-20 00:00:00
# ['murt']
# []
# ____________________________________________
# 37
# pa
# An Act amending Title 53 (Municipalities Generally) of the Pennsylvania Consolidated Statutes, in consolidated county assessment, further providing for subjects of local taxation.
# 2015-04-06 00:00:00
# ['ross']
# []
# ____________________________________________
# 38
# pa
# An Act providing for the powers and duties of the Department of Aging and area agencies on aging and for annual review of care plans; requiring criminal background checks and communicable disease screenings of certain providers; prohibiting certain provider financial interests; and providing for consumer telephone access and for procedures for noncompliance.
# 2015-01-23 00:00:00
# ['gingrich']
# []
# ____________________________________________
# 39
# pa
# An Act establishing the School District Millage Rate Reduction Fund and the School District Homestead and Farmstead Relief Fund; providing for additional taxation; and repealing provisions of the Taxpayer Relief Act.
# 2015-04-10 00:00:00
# ['saylor']
# []
# ____________________________________________
# 40
# pa
# An Act amending Titles 34 (Game) and 75 (Vehicles) of the Pennsylvania Consolidated Statutes, providing for the removal of deer carcasses.
# 2015-02-10 00:00:00
# ['topper']
# []
# ____________________________________________
# 41
# pa
# An Act establishing the Capital Case Representation Resource Center of Pennsylvania for capital offense litigation; and providing for its duties and responsibilities.
# 2009-02-19 00:00:00
# ['greenleaf']
# []
# ____________________________________________
# 42
# pa
# An Act amending Title 42 (Judiciary and Judicial Procedure) of the Pennsylvania Consolidated Statutes, further providing for death action.
# 2009-02-20 00:00:00
# ['browne']
# []
# ____________________________________________
# 43
# pa
# An Act amending Title 51 (Military Affairs) of the Pennsylvania Consolidated Statutes, providing for use of armory fitness facilities.
# 2009-03-02 00:00:00
# ['kasunic']
# []
# ____________________________________________
# 44
# pa
# An Act amending the act of March 4, 1971 (P.L.6, No.2), known as the Tax Reform Code of 1971, in sales and use tax, further providing for definitions and for exclusions.
# 2009-02-02 00:00:00
# ['brubaker']
# []
# ____________________________________________
# 45
# pa
# An Act establishing standards for strip searches and body cavity searches; providing for conduct of strip searches and body cavity searches, for reports, for civil and criminal immunity and for duties of the Secretary of Corrections and the Attorney General.
# 2009-03-31 00:00:00
# ['bishop']
# []
# ____________________________________________
# 46
# pa
# An Act amending Title 51 (Military Affairs) of the Pennsylvania Consolidated Statutes, providing for a preference for certain disabled veterans.
# 2010-03-10 00:00:00
# ['brennan']
# []
# ____________________________________________
# 47
# pa
# An Act amending the act of June 26, 2001 (P.L.755, No.77), known as the Tobacco Settlement Act, in health investment insurance, further providing for the adult basic coverage insurance program.
# 2009-02-05 00:00:00
# ['mustio']
# []
# ____________________________________________
# 48
# pa
# An Act amending Title 18 (Crimes and Offenses) of the Pennsylvania Consolidated Statutes, in nuisances, further providing for the offense of posting advertisements on another's property.
# 2009-03-13 00:00:00
# ['cruz']
# []
# ____________________________________________
# 49
# pa
# An Act amending the act of May 25, 1945 (P.L.1050, No.394), known as the Local Tax Collection Law, requiring tax collectors to receive tax payments from escrow agents or escrow accounts; further providing for penalties; and providing for application of requirements.
# 2009-03-25 00:00:00
# ['phillips']
# []
# ____________________________________________
# 50
# pa
# An Act amending the act of May 17, 1921 (P.L.682, No.284), known as The Insurance Company Law of 1921, providing for certain disclosure to property or casualty insurance policyholders.
# 2009-05-04 00:00:00
# ['deluca']
# []
# ____________________________________________
# 51
# pa
# An Act amending Title 18 (Crimes and Offenses) of the Pennsylvania Consolidated Statutes, in authorized disposition of offenders, further providing for sentence for murder and murder of an unborn child; and, in crimes against unborn child, further providing for the offenses of murder of unborn child and voluntary manslaughter of unborn child.
# 2009-02-19 00:00:00
# ['cruz']
# []
# ____________________________________________
# 52
# pa
# An Act amending Title 75 (Vehicles) of the Pennsylvania Consolidated Statutes, further providing for definitions, for penalties for driving after imbibing alcohol or utilizing drugs, for ignition interlock, for accelerated rehabilitative disposition and for illegally operating a motor vehicle not equipped with ignition interlock; and making an editorial change.
# 2009-03-19 00:00:00
# ['clymer']
# []
# ____________________________________________
# 53
# pa
# An Act amending the act of May 17, 1921 (P.L.682, No.284), known as The Insurance Company Law of 1921, further providing for definitions, for acting for or aiding nonadmitted insurers, for requirements for eligible surplus lines insurers, for other nonadmitted insurers, for surplus lines licensee's duty to notify insured, for declarations, for surplus lines advisory organizations, for evidence of insurance, for licensing of surplus lines licensee, for surplus lines licensee's acceptance of business from brokers, for records of surplus lines licensees, for monthly reports, for surplus lines tax, for tax on independently procured insurance, for suspension, revocation or nonrenewal of surplus lines licensee's license and for penalties; and providing for compliance.
# 2009-05-04 00:00:00
# ['boyle']
# []
# ____________________________________________
# 54
# pa
# An Act prohibiting the Department of Environmental Protection and the Environmental Quality Board from promulgating rules and regulations under certain acts.
# 2010-03-09 00:00:00
# ['causer']
# []
# ____________________________________________
# 55
# pa
# An Act establishing the Agricultural Capital Investment Tax Credit Program for the modernization or expansion of agricultural operations in this Commonwealth; establishing a sponsorship program; authorizing the transferability of tax credits; and imposing powers and duties on the Department of Agriculture.
# 2009-04-20 00:00:00
# ['denlinger']
# []
# ____________________________________________
# 56
# pa
# An Act amending Title 75 (Vehicles) of the Pennsylvania Consolidated Statutes, further prohibiting use of hearing impairment devices.
# 2009-03-12 00:00:00
# ['reichley']
# []
# ____________________________________________
# 57
# pa
# An Act amending the act of May 23, 1945 (P.L.926, No.369), referred to as the Public Eating and Drinking Place Law, further providing for definitions; and providing for applicability.
# 2009-05-07 00:00:00
# ['kula']
# []
# ____________________________________________
# 58
# pa
# An Act amending the act of March 10, 1949 (P.L.30, No.14), known as the Public School Code of 1949, further providing for collective bargaining and employee contract reporting by school districts.
# 2009-02-02 00:00:00
# ['barrar']
# []
# ____________________________________________
# 59
# pa
# An Act amending the act of June 13, 1967 (P.L.31, No.21), known as the Public Welfare Code, providing, in public assistance, for screening for illegal drug use.
# 2009-03-11 00:00:00
# ['everett']
# []
# ____________________________________________
# 60
# pa
# An Act amending Title 23 (Domestic Relations) of the Pennsylvania Consolidated Statutes, in child protective services, further providing for definitions; and providing for quality improvement of county agencies.
# 2009-02-13 00:00:00
# ['petri']
# []
# ____________________________________________
# 61
# pa
# A Joint Resolution proposing an amendment to the Constitution of the Commonwealth of Pennsylvania, further providing for exemptions and special provisions.
# 2010-04-30 00:00:00
# ['levdansky']
# Error processing row 61 in current chunk, setting results to None.
# 21
# ____________________________________________
# 0
# ia
# A bill for an act modifying provisions relating to solar energy system income tax credits and including effective date and applicability provisions. (Formerly SSB 1175.)
# 2013-04-02 00:00:00
# ['ways & means']
# Error processing row 0 in current chunk, setting results to None.
# 22
# ____________________________________________
# 0
# ms
# Termite control contracts; require to contain damage repair obligation or language excluding such obligation.
# 2008-01-31 00:00:00
# ['lane']
# Error processing row 0 in current chunk, setting results to None.
# 23
# ____________________________________________
# 0
# ms
# Assessments; may be imposed for Class I violation of game and fish statutes.
# 2015-01-19 00:00:00
# ['bounds']
# Error processing row 0 in current chunk, setting results to None.
# 24
# ____________________________________________
# 0
# ms
# Execution or attachment; revise property exempt from seizure under.
# 2010-01-11 00:00:00
# ['evans']
# Error processing row 0 in current chunk, setting results to None.
# 25
# ____________________________________________
# 0
# ms
# Interstate Compact for Juveniles; authorize Governor to execute.
# 2009-01-15 00:00:00
# ['hines']
# Error processing row 0 in current chunk, setting results to None.

# %%
## chunks where API gave some unexplaiable error, Usually related to what is being queries for row. Not clea what is issue with the query, did not find any tangible pattern

error_chunks = [key for key in error_dict.keys()]
error_rect = {}



## rules for how to slice problematic rows out of chunks. Have to keep in mind API call limit. Optimized for that
for key in error_chunks:
    a = error_dict[key]
    if (a <10):
        error_rect[key] = [slice(a+5,101)]
    elif (a<80):
        error_rect[key] = [slice(None, a-2), slice(a+2, 101)]
    elif (a>=80):
        error_rect[key] = [slice(None, a-1)]

chunk_results_errors = [] 
j = 0 
for chunk_index, chunk in enumerate(df_chunks):
    if chunk_index in error_chunks:
        print(j)
        print('____________________________________________')
        result = [None] * len(chunk)  

## try those chunks again, but subste out the problematic rows from that chunk. Problematic row information stored in dictionary during first iteration of API calls
        
        if chunk_index in error_rect:
            for row_slice in error_rect[chunk_index]:
                for i in range(*row_slice.indices(len(chunk))):  
                    row_data = chunk.iloc[i]
                    st = row_data['state']
                    text = row_data['bill_title']
                    years = row_data['date_introduced']
                    name_list = row_data['name_list']

                    # Debug prints
                    print(i)
                    print(st)
                    print(text)
                    print(years)
                    print(name_list)

                    try:
                        ff = get_names(st, text, years, name_list)
                        result[i] = ff  
                    except Exception as e:
                        print(f'Error processing row {i} in current chunk, setting results to None.')
                        result[i] = None  

        chunk_results_errors.append(result)
        j +=1
# Out:
# 0
# ____________________________________________
# 0
# sd
# repeal certain provisions regarding the South Dakota Risk Pool.
# 2015-01-13 00:00:00
# ['health and human services']
# Error processing row 0 in current chunk, setting results to None.
# 1
# sd
# adopt the South Dakota Nonprofit Corporation Act.
# 2015-01-23 00:00:00
# ['stevens', 'gibson', 'gosch', 'johns', 'rusch', 'tieszen']
# Error processing row 1 in current chunk, setting results to None.
# 2
# sd
# repeal the South Dakota Energy Infrastructure Authority.
# 2015-01-13 00:00:00
# ['commerce and energy']
# Error processing row 2 in current chunk, setting results to None.
# 3
# sd
# revise certain provisions regarding zero based budgets, budgeting procedures, and the coordination of federally aided programs.
# 2015-01-13 00:00:00
# ['appropriations']
# Error processing row 3 in current chunk, setting results to None.
# 4
# sd
# revise certain provisions regarding the payment of salary and compensation to legislators.
# 2015-01-28 00:00:00
# ['gosch', 'bartling', 'gibson', 'haggar (don)', 'hawley', 'langer', 'mickelson', 'westra', 'wink', 'rave', 'brown', 'frerichs', 'heineman (phyllis)', 'lederman']
# Error processing row 4 in current chunk, setting results to None.
# 5
# sd
# Proposing and submitting to the electors at the next general election an amendment to Article XIV of the Constitution of the State of South Dakota, relating to the authority of the Board of Regents.
# 2015-01-28 00:00:00
# ['mickelson', 'anderson', 'bartling', 'beal', 'bolin', 'brunner', 'conzet', 'disanto', 'dryden', 'duvall', 'haggar (don)', 'heinemann (leslie)', 'hunhoff (jean)', 'hunt', 'jensen (alex)', 'klumb', 'langer', 'otten (herman)', 'partridge', 'rozum', 'schoenbeck', 'sly', 'solum', 'stalzer', 'stevens', 'westra', 'willadsen', 'wink', 'zikmund', 'rave', 'brown', 'haverly', 'heineman (phyllis)', 'holien', 'lederman', 'omdahl', 'otten (ernie)', 'peters', 'rampelberg', 'soholt', 'sutton', 'vehle']
# Error processing row 5 in current chunk, setting results to None.
# 6
# sd
# make an appropriation to reimburse certain family physicians, dentists, physician assistants, and nurse practitioners who have complied with the requirements of the recruitment assistance program and to declare an emergency.
# 2015-01-13 00:00:00
# ['appropriations']
# Error processing row 6 in current chunk, setting results to None.
# 7
# sd
# revise certain provisions relating to pseudoephedrine, ephedrine, or phenylpropanolamine sales.
# 2014-01-14 00:00:00
# ['judiciary']
# Error processing row 7 in current chunk, setting results to None.
# 8
# sd
# make an appropriation to reimburse certain family physicians who have complied with the requirements of the recruitment assistance program and to declare an emergency.
# 2014-01-14 00:00:00
# ['appropriations']
# Error processing row 8 in current chunk, setting results to None.
# 9
# sd
# revise certain provisions regarding the closure of county and township roads due to high water.
# 2014-01-31 00:00:00
# ['holien', 'otten (herman)']
# Error processing row 9 in current chunk, setting results to None.
# 10
# sd
# revise certain provisions regarding the regulation of certain open containers of alcoholic beverages.
# 2014-01-15 00:00:00
# ['transportation']
# Error processing row 10 in current chunk, setting results to None.
# 11
# sd
# revise the composition of the governing body of a health maintenance organization.
# 2014-01-31 00:00:00
# ['maher', 'brown', 'frerichs', 'holien', 'lederman', 'rave', 'munsterman', 'conzet', 'heinemann (leslie)', 'kirschman', 'ring', 'stalzer', 'westra']
# Error processing row 11 in current chunk, setting results to None.
# 12
# sd
# limit the sources of funds that may be used in the support of election activities administered by the state and its political subdivisions.
# 2014-01-14 00:00:00
# ['local government']
# Error processing row 12 in current chunk, setting results to None.
# 13
# sd
# revise certain provisions concerning actions prohibited near polling places.
# 2014-01-21 00:00:00
# ['feinstein', 'bartling', 'gibson', 'gosch', 'hunhoff (bernie)', 'johns', 'lust', 'stevens', 'jones (chuck)', 'frerichs', 'kirkeby', 'lederman', 'maher', 'novstrup (al)', 'rave', 'rhoden', 'tieszen']
# Error processing row 13 in current chunk, setting results to None.
# 14
# sd
# authorize the Department of Public Safety to build a highway patrol office and motorcycle training facility in Rapid City, to make an appropriation therefor, and to declare an emergency.
# 2014-01-14 00:00:00
# ['appropriations']
# Error processing row 14 in current chunk, setting results to None.
# 15
# sd
# provide for alternative documentation of financial responsibility for vehicles.
# 2014-01-28 00:00:00
# ['haggar (don)', 'anderson', 'greenfield', 'haggar (jenna)', 'heinemann (leslie)', 'hickey', 'kopp', 'olson (betty)', 'parsley', 'rounds', 'russell', 'schaefer', 'verchio', 'werner', 'westra', 'jones (chuck)', 'holien', 'jensen', 'kirkeby', 'maher', 'peters', 'tidemann', 'white']
# Error processing row 15 in current chunk, setting results to None.
# 16
# sd
# provide that no entity that places children for adoption or performs abortions may be registered as a pregnancy help center.
# 2014-01-30 00:00:00
# ['ecklund', 'campbell', 'craig', 'greenfield', 'haggar (don)', 'haggar (jenna)', 'heinemann (leslie)', 'hickey', 'hunhoff (bernie)', 'kaiser', 'kopp', 'latterell', 'olson (betty)', 'schaefer', 'stalzer', 'steele', 'novstrup (al)', 'begalka', 'heineman (phyllis)', 'hunhoff (jean)', 'jensen', 'kirkeby', 'lederman', 'maher', 'omdahl', 'rampelberg', 'rhoden']
# Error processing row 16 in current chunk, setting results to None.
# 17
# sd
# create an equitable process to handle water right applications submitted for aquifers determined to be fully appropriated by the Water Management Board.
# 2014-01-14 00:00:00
# ['agriculture and natural resources']
# Error processing row 17 in current chunk, setting results to None.
# 18
# sd
# revise the eligibility requirements for the South Dakota opportunity scholarship to include certain students who reside in bordering states.
# 2014-01-22 00:00:00
# ['tyler', 'hawks', 'parsley', 'rasmussen', 'ring', 'schoenfish', 'soli', 'verchio', 'lucas', 'jones (tom)']
# Error processing row 18 in current chunk, setting results to None.
# 19
# sd
# revise certain provisions regarding the open enrollment application review process of siblings of open enrolled students.
# 2014-01-14 00:00:00
# ['education']
# Error processing row 19 in current chunk, setting results to None.
# 20
# sd
# revise certain provisions regarding licenses issued by the State Plumbing Commission and the fees that may be set by the commission.
# 2014-01-14 00:00:00
# ['commerce and energy']
# Error processing row 20 in current chunk, setting results to None.
# 21
# sd
# accommodate legislation on medical services.
# 2014-01-29 00:00:00
# ['cronin', 'rave']
# Error processing row 21 in current chunk, setting results to None.
# 22
# sd
# Proposing and submitting to the electors at the next general election an amendment to Article III, section 6 of the Constitution of the State of South Dakota, to revise term limits for legislators.
# 2014-01-29 00:00:00
# ['nelson', 'campbell', 'craig', 'kaiser', 'kopp', 'may', 'schoenfish', 'verchio', 'van gerpen', 'begalka', 'kirkeby']
# Error processing row 22 in current chunk, setting results to None.
# 23
# sd
# revise certain provisions regarding military speciality plates.
# 2014-01-14 00:00:00
# ['transportation']
# Error processing row 23 in current chunk, setting results to None.
# 24
# sd
# increase the filing fee for a rate case filed by a gas or electric public utility.
# 2011-01-11 00:00:00
# ['commerce']
# Error processing row 24 in current chunk, setting results to None.
# 25
# sd
# revise certain provisions regarding the expungement of arrest records.
# 2011-01-11 00:00:00
# ['judiciary']
# Error processing row 25 in current chunk, setting results to None.
# 26
# sd
# require certain notice requirements for retailers that do not have nexus in South Dakota which are selling tangible personal property, services, or products transferred electronically for use in South Dakota.
# 2011-01-26 00:00:00
# ['peters', 'hansen (tom)', 'cronin', 'dennert']
# Error processing row 26 in current chunk, setting results to None.
# 27
# sd
# revise certain provisions regarding what organizations qualify for an exemption from sales tax as a relief agency or a religious educational institution.
# 2011-01-11 00:00:00
# ['taxation']
# Error processing row 27 in current chunk, setting results to None.
# 28
# sd
# expand the application of nexus for the purpose of collecting sales and use taxes owed to the state.
# 2011-01-26 00:00:00
# ['peters', 'hansen (tom)', 'cronin', 'dennert']
# Error processing row 28 in current chunk, setting results to None.
# 29
# sd
# revise certain provisions regarding the 24/7 sobriety program, to authorize the collection of certain fees, and to authorize the use of ignition interlock devices.
# 2011-01-11 00:00:00
# ['judiciary']
# Error processing row 29 in current chunk, setting results to None.
# 30
# sd
# revise the allowable time periods for use of nonresident small game hunting licenses.
# 2011-01-24 00:00:00
# ['juhnke', 'brunner', 'cronin', 'dennert', 'olson (betty)', 'schaefer', 'bradford', 'garnos', 'maher']
# Error processing row 30 in current chunk, setting results to None.
# 31
# sd
# revise certain provisions concerning certain fees for the electronic transmission of court records.
# 2011-01-18 00:00:00
# ['judiciary']
# Error processing row 31 in current chunk, setting results to None.
# 32
# sd
# require persons applying or receiving certain aid or assistance from the state to submit to drug and substances tests.
# 2011-01-24 00:00:00
# ['kirkeby', 'brunner', 'deelstra', 'feickert', 'hansen (jon)', 'hoffman', 'jones', 'moser', 'nelson (stace)', 'olson (betty)', 'russell', 'solum', 'verchio', 'lederman', 'krebs', 'maher']
# Error processing row 32 in current chunk, setting results to None.
# 33
# sd
# revise and repeal certain outdated provisions regarding land surveying.
# 2011-01-26 00:00:00
# ['willadsen', 'conzet', 'fargen', 'gosch', 'haggar', 'hansen (jon)', 'hickey', 'hubbel', 'lust', 'moser', 'nelson (stace)', 'novstrup (david)', 'sly', 'steele', 'street', 'wick', 'cutler', 'buhl', 'peters', 'schlekeway', 'sutton']
# Error processing row 33 in current chunk, setting results to None.
# 34
# sd
# place certain substances on the controlled substances schedule and to declare an emergency.
# 2011-01-11 00:00:00
# ['health and human services']
# Error processing row 34 in current chunk, setting results to None.
# 35
# sd
# allow municipalities, counties, and school districts to post certain information on the internet in addition to or in lieu of certain publication requirements.
# 2011-01-24 00:00:00
# ['wick', 'brunner', 'dryden', 'hoffman', 'hunt', 'jensen', 'lucas', 'moser', 'turbiville', 'verchio', 'gray', 'haverly', 'johnston', 'peters']
# Error processing row 35 in current chunk, setting results to None.
# 36
# sd
# provide for the registration and regulation of appraisal management companies.
# 2011-01-11 00:00:00
# ['commerce']
# Error processing row 36 in current chunk, setting results to None.
# 37
# sd
# revise the composition of the State Brand Board and to provide for its election by district.
# 2011-01-19 00:00:00
# ['olson (betty)', 'brunner', 'hoffman', 'kirkeby', 'nelson (stace)', 'russell', 'schrempp', 'steele', 'maher', 'bradford', 'lederman', 'sutton']
# Error processing row 37 in current chunk, setting results to None.
# 38
# sd
# provide for the identification of the law applicable to certain claims for damages.
# 2011-01-25 00:00:00
# ['hunt', 'boomgarden', 'gibson', 'nelson (stace)', 'rausch', 'turbiville', 'rave', 'hunhoff (jean)', 'schlekeway', 'tieszen', 'vehle']
# Error processing row 38 in current chunk, setting results to None.
# 39
# sd
# Proposing and submitting to the electors at the next general election an amendment to Article III, section 6 of the Constitution of the State of South Dakota, relating to four-year legislative terms and term limits.
# 2011-01-24 00:00:00
# ['feinstein', 'hansen (tom)']
# Error processing row 39 in current chunk, setting results to None.
# 40
# sd
# revise certain provisions concerning how motor vehicle license fees are distributed in the unorganized territories of a county.
# 2011-01-21 00:00:00
# ['venner', 'cronin', 'feickert', 'kirkeby', 'street', 'hunhoff (jean)', 'bradford', 'fryslie', 'lederman', 'maher']
# Error processing row 40 in current chunk, setting results to None.
# 41
# sd
# establish standards for teaching, to require teacher evaluations, and to provide for the development of a model evaluation instrument.
# 2010-01-12 00:00:00
# ['education']
# Error processing row 41 in current chunk, setting results to None.
# 42
# sd
# update certain provisions regarding the reimbursable expense exemption from the sales and service tax allowed licensed accountants.
# 2010-01-12 00:00:00
# ['taxation']
# Error processing row 42 in current chunk, setting results to None.
# 43
# sd
# revise, under certain circumstances, the vote required to allow a public body to issue bonds.
# 2010-01-28 00:00:00
# ['ahlers', 'brown', 'schlekeway', 'olson (ryan)', 'rave']
# Error processing row 43 in current chunk, setting results to None.
# 44
# sd
# provide for the continuation of the minimum monthly fee charged for care at the Human Services Center.
# 2010-01-12 00:00:00
# ['health and human services']
# Error processing row 44 in current chunk, setting results to None.
# 45
# sd
# establish a legislative policy to biannually review the highway needs and make appropriate adjustments.
# 2010-01-28 00:00:00
# ['vehle', 'ahlers', 'brown', 'fryslie', 'maher', 'krebs', 'juhnke', 'street']
# Error processing row 45 in current chunk, setting results to None.
# 46
# sd
# revise certain provisions relating to delinquent tax accounts.
# 2010-01-12 00:00:00
# ['taxation']
# Error processing row 46 in current chunk, setting results to None.
# 47
# sd
# allow copies of juvenile files to be provided to certain named parties or by court order rather than limiting use to inspection of the file only.
# 2010-01-19 00:00:00
# ['judiciary']
# Error processing row 47 in current chunk, setting results to None.
# 48
# sd
# clarify certain provisions relating to orders issued for examinations of certain insurers.
# 2010-01-12 00:00:00
# ['commerce']
# Error processing row 48 in current chunk, setting results to None.
# 49
# sd
# revise certain provisions and assessments related to the South Dakota Oilseeds Council.
# 2010-01-25 00:00:00
# ['vanneman', 'brunner', 'cronin', 'dennert', 'fargen', 'feickert', 'greenfield', 'hoffman', 'hunt', 'jensen', 'juhnke', 'kopp', 'krebs', 'noem', 'olson (betty)', 'pitts', 'putnam', 'rausch', 'schlekeway', 'sorenson', 'street', 'turbiville', 'verchio', 'hansen (tom)', 'bartling', 'bradford', 'fryslie', 'garnos', 'knudson', 'merchant', 'peterson', 'rhoden']
# Error processing row 49 in current chunk, setting results to None.
# 50
# sd
# provide for the issuance of an on-sale license and malt beverage license for the county fairgrounds and to authorize counties to issue an additional on-sale license.
# 2010-01-28 00:00:00
# ['conzet', 'cronin', 'gosch', 'greenfield', 'kirkeby', 'lust', 'novstrup (david)', 'olson (ryan)', 'rausch', 'sly', 'verchio', 'adelstein', 'tieszen']
# Error processing row 50 in current chunk, setting results to None.
# 51
# sd
# repeal the imposition of the five dollar surcharge on mentored youth big game hunting licenses.
# 2010-01-12 00:00:00
# ['agriculture and natural resources']
# Error processing row 51 in current chunk, setting results to None.
# 52
# sd
# revise certain provisions regarding court records inspection and copying.
# 2010-01-19 00:00:00
# ['judiciary']
# Error processing row 52 in current chunk, setting results to None.
# 53
# sd
# permit and regulate the blending of natural gasoline and ethyl alcohol and to provide for an ethanol broker license.
# 2010-01-12 00:00:00
# ['transportation']
# Error processing row 53 in current chunk, setting results to None.
# 54
# sd
# revise certain provisions for the procurement of goods and services for governmental agencies.
# 2010-01-12 00:00:00
# ['state affairs']
# Error processing row 54 in current chunk, setting results to None.
# 55
# sd
# limit certain requirements associated with animal identification systems.
# 2010-01-27 00:00:00
# ['russell', 'brunner', 'elliott', 'feickert', 'frerichs', 'kirkeby', 'wink', 'maher', 'bradford', 'peterson']
# Error processing row 55 in current chunk, setting results to None.
# 56
# sd
# Proposing and submitting to the electors at the next general election an amendment to Article XII of the Constitution of the State of South Dakota, relating to the limitation of expenditures for the State of South Dakota.
# 2010-02-02 00:00:00
# ['hunhoff (bernie)', 'elliott', 'heidepriem', 'abdallah', 'bradford', 'maher', 'merchant']
# Error processing row 56 in current chunk, setting results to None.
# 57
# sd
# provide certain tax refunds for new or expanded wind energy facilities.
# 2010-01-12 00:00:00
# ['appropriations']
# Error processing row 57 in current chunk, setting results to None.
# 58
# sd
# require certain applicants for licensure as a health professional or a licensee who is the subject of a disciplinary investigation to submit to a state and federal criminal background check.
# 2012-01-10 00:00:00
# ['health and human services']
# Error processing row 58 in current chunk, setting results to None.
# 59
# sd
# revise certain provisions relating to the South Dakota Retirement System, the South Dakota deferred compensation plan, and the South Dakota special pay retirement program.
# 2012-01-10 00:00:00
# ['retirement laws']
# Error processing row 59 in current chunk, setting results to None.
# 60
# sd
# provide for an affirmative defense of compulsion for the crime of prostitution.
# 2012-01-24 00:00:00
# ['cutler', 'krebs', 'peters', 'moser', 'blake', 'elliott', 'gibson', 'gosch', 'hickey', 'kirkeby', 'lucas', 'magstadt', 'rozum', 'sigdestad', 'street']
# Error processing row 60 in current chunk, setting results to None.
# 61
# sd
# expand the definition of victim for the purposes of certain written victim impact statements.
# 2012-01-10 00:00:00
# ['judiciary']
# Error processing row 61 in current chunk, setting results to None.
# 62
# sd
# limit compensatory damages in civil actions related to death or injury.
# 2012-01-24 00:00:00
# ['peters', 'gray', 'olson (russell)', 'novstrup (david)', 'cronin', 'hawley', 'moser', 'rausch', 'tulson', 'verchio']
# Error processing row 62 in current chunk, setting results to None.
# 63
# sd
# revise the exemptions for insurance agent examinations.
# 2012-01-10 00:00:00
# ['commerce and energy']
# Error processing row 63 in current chunk, setting results to None.
# 64
# sd
# exempt certain counties from restrictions relating to the taking of muskrat.
# 2012-01-20 00:00:00
# ['dennert', 'cronin', 'feickert', 'hoffman', 'kirschman', 'kloucek', 'olson (betty)', 'schaefer', 'wink', 'cutler', 'brown', 'frerichs']
# Error processing row 64 in current chunk, setting results to None.
# 65
# sd
# increase the penalty for leaving the brand inspection area without necessary inspection and authorization.
# 2012-01-10 00:00:00
# ['agriculture and natural resources']
# Error processing row 65 in current chunk, setting results to None.
# 66
# sd
# revise certain provisions regarding the filing of claims against public improvement contracts.
# 2012-01-23 00:00:00
# ['solum', 'gibson', 'kirkeby', 'moser', 'turbiville', 'lederman', 'hansen (tom)', 'hundstad', 'maher']
# Error processing row 66 in current chunk, setting results to None.
# 67
# sd
# remit certain sales and use taxes collected at county-owned fairgrounds to counties.
# 2012-01-23 00:00:00
# ['kirkeby', 'dryden', 'feickert', 'munsterman', 'venner', 'rampelberg', 'haverly', 'juhnke', 'maher', 'schlekeway']
# Error processing row 67 in current chunk, setting results to None.
# 68
# sd
# provide for exceptions from certain misdemeanor offenses relating to possession of handguns.
# 2012-01-10 00:00:00
# ['kopp', 'jensen', 'nelson (stace)', 'olson (betty)', 'russell', 'venner', 'begalka']
# Error processing row 68 in current chunk, setting results to None.
# 69
# sd
# allow certain structures or facilities previously used as an elevator to be classified as agricultural property.
# 2012-01-20 00:00:00
# ['dennert', 'cronin', 'hoffman', 'schaefer', 'sigdestad', 'hundstad', 'begalka', 'putnam', 'rhoden']
# Error processing row 69 in current chunk, setting results to None.
# 70
# sd
# clarify certain requirements relating to insurance examinations.
# 2012-01-10 00:00:00
# ['commerce and energy']
# Error processing row 70 in current chunk, setting results to None.
# 71
# sd
# revise certain provisions regarding child custody during a soldier's deployment.
# 2012-01-10 00:00:00
# ['judiciary']
# Error processing row 71 in current chunk, setting results to None.
# 72
# sd
# revise certain provisions relating to the nonrenewal of a teacher's contract.
# 2012-01-23 00:00:00
# ['olson (betty)', 'hansen (jon)', 'jensen', 'kirkeby', 'venner', 'brown', 'begalka', 'lederman', 'maher', 'peters']
# Error processing row 72 in current chunk, setting results to None.
# 73
# sd
# Proposing and submitting to the electors at the next general election an amendment to Article VI of the Constitution of the State of South Dakota, relating to the right of individuals to secure medical services of their choosing.
# 2012-01-19 00:00:00
# ['kirschman', 'blake', 'brunner', 'dennert', 'elliott', 'fargen', 'feickert', 'gibson', 'hickey', 'hunhoff (bernie)', 'jensen', 'kloucek', 'kopp', 'rausch', 'sigdestad', 'street', 'verchio', 'wick', 'sutton', 'bradford', 'frerichs', 'hundstad']
# Error processing row 73 in current chunk, setting results to None.
# 74
# sd
# permit a probationer who is a registered sex offender to reside in an assigned halfway house or supervised living center within a community safety zone.
# 2012-01-19 00:00:00
# ['judiciary']
# Error processing row 74 in current chunk, setting results to None.
# 75
# la
# PUBLIC SFTY/CORRECT DEPT:  Provides relative to contraband in penal institutions.  (gov sig)
# 2013-03-25 00:00:00
# ['francis c. thompson']
# Error processing row 75 in current chunk, setting results to None.
# 76
# la
# TOURISM:  Provides for legislation relative to the allocation of funds from the Vermilion Parish Tourist Commission. (gov sig)
# 2013-04-17 00:00:00
# ['jonathan perry']
# Error processing row 76 in current chunk, setting results to None.
# 77
# la
# PROPERTY INSURANCE:  Requires homeowners' insurance providers who use a named-storm or wind and hail deductible to offer the policyholder a discount on the annual premium. (8/1/13)
# 2013-03-28 00:00:00
# ['dan w. morrish']
# Error processing row 77 in current chunk, setting results to None.
# 78
# la
# CLERKS OF COURT:  Provides for the payment of group insurance premiums of certain retirees of the clerk of court's office in East Baton Rouge Parish.  (8/1/13) (EN +$33,000 LF EX See Note)
# 2013-03-21 00:00:00
# ['yvonne dorsey-colomb']
# Error processing row 78 in current chunk, setting results to None.
# 79
# la
# PORTS/HARBORS/TERMINALS:  Expands the jurisdiction of the Louisiana International Deep Water Gulf Transfer Terminal Authority. (8/1/13)
# 2013-03-26 00:00:00
# ['a.g. crowe']
# Error processing row 79 in current chunk, setting results to None.
# 80
# la
# BUILDING CODES:  Provides relative to the state uniform construction code
# 2013-03-29 00:00:00
# ['hunter greene']
# Error processing row 80 in current chunk, setting results to None.
# 81
# la
# CRIMINAL/BUREAU CRIML ID:  Authorizes certain nonprofit organizations to obtain criminal history record and identification files for applicants seeking to serve in certain programs
# 2013-03-22 00:00:00
# ['dalton honore']
# Error processing row 81 in current chunk, setting results to None.
# 82
# la
# REVENUE DEPARTMENT:  Establishes the Louisiana Tax Delinquency Amnesty Act of 2013 (EN INCREASE SD RV See Note)
# 2013-03-29 00:00:00
# ['joel robideaux']
# Error processing row 82 in current chunk, setting results to None.
# 83
# la
# RETIREMENT/LOCAL:  Provides relative to the computation of benefits in the Firefighters' Pension and Relief Fund in the city of New Orleans (EN DECREASE APV)
# 2013-02-22 00:00:00
# ['kevin pearson']
# Error processing row 83 in current chunk, setting results to None.
# 84
# la
# TAX/INCOME TAX:  Deletes requirement that a student be listed as a dependent for a taxpayer to receive the private school education income tax deduction
# 2013-04-08 00:00:00
# ['paul hollis']
# Error processing row 84 in current chunk, setting results to None.
# 1
# ____________________________________________
# 0
# la
# TAX/INCOME TAX:  Creates an individual income tax checkoff for The Extra Mile, Southeast La. and other regional The Extra Mile organizations
# 2015-04-03 00:00:00
# ['robert e. billiot']
# Error processing row 0 in current chunk, setting results to None.
# 1
# la
# TAX/SALES & USE:  Provides relative to the definition of dealer, hotel, and sales price for purposes of imposing the state sales and use tax
# 2015-04-22 00:00:00
# ['taylor f. barras']
# Error processing row 1 in current chunk, setting results to None.
# 2
# la
# CIVIL/PROCESS:  Provides for notice to certain state departments and agencies of suits involving violation of certain permits
# 2015-04-03 00:00:00
# ['clay schexnayder']
# Error processing row 2 in current chunk, setting results to None.
# 3
# la
# PROPERTY/PUBLIC:  Authorizes the transfer of certain state property in Calcasieu Parish
# 2015-03-25 00:00:00
# ['mike danahay']
# Error processing row 3 in current chunk, setting results to None.
# 4
# la
# DISTRICTS/FIRE PROTECT:  Provides relative to parcel fees levied by Fire Protection District 8-C in Lafourche Parish
# 2015-03-19 00:00:00
# ['jerome "dee" richard']
# Error processing row 4 in current chunk, setting results to None.
# 5
# la
# FISHING/FINFISH:  Provides relative to the method of determination of a stock assessment for black drum, sheepshead, and flounder
# 2015-04-01 00:00:00
# ['jerry "truck" gisclair']
# Error processing row 5 in current chunk, setting results to None.
# 6
# la
# PRESCRIPTION:  Provides relative to certain prescriptive periods applicable to the reinscription of mortgages
# 2015-04-03 00:00:00
# ['tom willmott']
# Error processing row 6 in current chunk, setting results to None.
# 7
# la
# TAX CREDITS:  Limits the amount of motion picture investor tax credit applications certified by the office each year (EG SEE FISC NOTE GF RV)
# 2015-04-01 00:00:00
# ['lance harris']
# Error processing row 7 in current chunk, setting results to None.
# 8
# la
# COURTS:  Increases authorized court costs for municipal ordinance violations in the mayor's court in the town of Anacoco. (8/1/14) (EN +$10,000 LF RV See Note)
# 2014-02-11 00:00:00
# ['john r. smith']
# Error processing row 8 in current chunk, setting results to None.
# 13
# la
# EMPLOYMENT:  Provides for a state minimum wage. (1/1/15) (OR INCREASE GF EX See Note)
# 2014-02-10 00:00:00
# ['yvonne dorsey-colomb']
# Error processing row 13 in current chunk, setting results to None.
# 14
# la
# HEALTH CARE:  Constitutional amendment to require the state to provide the opportunity to a legal resident, employed for the previous calendar year for at least one thousand hours, and whose income is below one hundred percent of the federal poverty level to participate in a state program that provides health insurance with essential benefits. (2/3-CA13s1(A))
# 2014-02-18 00:00:00
# ['ben nevers']
# Error processing row 14 in current chunk, setting results to None.
# 15
# la
# DISTRICTS/WATERWORKS:  Limits the powers granted to the governing authorities of waterworks districts located in the parishes of Beauregard and Calcasieu
# 2014-02-27 00:00:00
# ['brett geymann']
# Error processing row 15 in current chunk, setting results to None.
# 16
# la
# SCHOOLS/CHARTER:  Provides relative to assets or property acquired or used by charter schools under certain circumstances (OR SEE FISC NOTE LF EX)
# 2014-02-17 00:00:00
# ['kenny havard']
# Error processing row 16 in current chunk, setting results to None.
# 17
# la
# CIVIL SERVICE/FIRE & POL:  Provides that the position of police chief for the city of Covington is in the unclassified service
# 2014-02-26 00:00:00
# ['john m. schroder']
# Error processing row 17 in current chunk, setting results to None.
# 18
# la
# APPROPRIATIONS/JUDGMENT:  Appropriates funds for payment of judgment in the matter of "Brian Gerald v. State of Louisiana DOTD"
# 2014-01-23 00:00:00
# ['hunter greene']
# Error processing row 18 in current chunk, setting results to None.
# 19
# la
# CRIME:  Provides for intensive parole supervision for certain offenders sentenced as habitual offenders (EN DECREASE GF EX See Note)
# 2014-02-27 00:00:00
# ['patricia smith']
# Error processing row 19 in current chunk, setting results to None.
# 20
# la
# FUNDS/FUNDING:  Provides with regard to dedications of certain excess mineral revenues and deposits into the Budget Stabilization Fund (RE1 SEE FISC NOTE GF RV See Note)
# 2014-02-28 00:00:00
# ['karen gaudet st. germain']
# Error processing row 20 in current chunk, setting results to None.
# 21
# la
# MTR VEHICLE/LICEN PLATES:  Creates the "Louisiana Master Gardener" special prestige license plate
# 2014-02-28 00:00:00
# ['nancy landry']
# Error processing row 21 in current chunk, setting results to None.
# 22
# la
# CONTROLLED SUBSTANCES:  Restricts the sale of dextromethorphan (EN SEE FISC NOTE LF RV See Note)
# 2014-02-27 00:00:00
# ['cameron henry']
# Error processing row 22 in current chunk, setting results to None.
# 23
# la
# LAW ENFORCE/OFFICERS:  Provides with respect to supplemental pay for certain officers (EN INCREASE GF EX See Note)
# 2014-02-13 00:00:00
# ['sherman q. mack']
# Error processing row 23 in current chunk, setting results to None.
# 24
# la
# DISTRICTS/HOSPITAL SERVC:  Provides relative to hospital service districts in Jefferson Parish
# 2014-02-05 00:00:00
# ['patrick connick']
# Error processing row 24 in current chunk, setting results to None.
# 25
# la
# MTR VEHICLE/TRUCK REGS:  Provides with respect to overhang for trucks and trailers hauling heavy equipment
# 2014-02-24 00:00:00
# ['bob hensgens']
# Error processing row 25 in current chunk, setting results to None.
# 26
# la
# ALCOHOLIC BEVERAGE PERMT:  Provides relative to wine and malt beverage permits
# 2014-02-27 00:00:00
# ['jeffery "jeff" j. arnold']
# Error processing row 26 in current chunk, setting results to None.
# 27
# la
# TEACHERS/EVALUATION:  Provides relative to the evaluation of teachers and administrators (OR +$68,944 GF EX See Note)
# 2014-02-28 00:00:00
# ['robert johnson']
# Error processing row 27 in current chunk, setting results to None.
# 28
# la
# MOTOR VEHICLES:  Authorizes the research and testing of autonomous vehicles
# 2014-02-28 00:00:00
# ['walt leger, iii']
# Error processing row 28 in current chunk, setting results to None.
# 29
# la
# ADMINISTRATION DIVISION:  Requires the commissioner of administration to submit reports on amendments to the state action plan relative to funding for hurricane recovery programs
# 2014-04-01 00:00:00
# ['regina ashford barrow']
# Error processing row 29 in current chunk, setting results to None.
# 30
# la
# ELECTED OFFICIALS/STATEW:  Makes the office of state superintendent of education an elective rather than an appointed office (OR -$80,000 GF EX See Note)
# 2014-02-21 00:00:00
# ['brett geymann']
# Error processing row 30 in current chunk, setting results to None.
# 31
# la
# Provides that once the balance in the Millennium Trust reaches $1.38 billion, 100% of the annual Tobacco Settlement Proceeds shall be dedicated to the TOPS program.
# 2011-04-14 00:00:00
# ['john a. alario, jr.']
# Error processing row 31 in current chunk, setting results to None.
# 32
# la
# Authorizes post certified law enforcement officers to search defendants on probation.
# 2011-04-15 00:00:00
# ['jonathan w. perry']
# Error processing row 32 in current chunk, setting results to None.
# 33
# la
# Increases the number of working days prior to the opening of bids within which a potential supplier must submit a request for approval of a product other than that specified in the contract documents in public works projects of the New Orleans Sewerage and Water Board.
# 2011-04-14 00:00:00
# ['edwin r. murray']
# Error processing row 33 in current chunk, setting results to None.
# 34
# la
# Provides for the Louisiana Virtual School.
# 2011-04-13 00:00:00
# ['b. l. "buddy" shaw']
# Error processing row 34 in current chunk, setting results to None.
# 35
# la
# Provides for the recoupment of unit wells costs and risk charge.
# 2011-04-14 00:00:00
# ['b. l. "buddy" shaw']
# Error processing row 35 in current chunk, setting results to None.
# 36
# la
# Provides relative to textbooks and other instructional materials
# 2011-04-15 00:00:00
# ['frank a. hoffmann']
# Error processing row 36 in current chunk, setting results to None.
# 37
# la
# Clarifies relationship between co-owners relative to timber theft
# 2011-04-12 00:00:00
# ['dorothy sue hill']
# Error processing row 37 in current chunk, setting results to None.
# 38
# la
# Extends the La. Enterprise Zone Act to include transit-oriented multifamily developments
# 2011-04-15 00:00:00
# ['helena n. moreno']
# Error processing row 38 in current chunk, setting results to None.
# 39
# la
# Appropriates funds for payment of judgment against DOTD in the matter of "Eric Rachal v. the City of Alexandria and the State of Louisiana, et al"
# 2011-03-25 00:00:00
# ['lowell c. hazel']
# Error processing row 39 in current chunk, setting results to None.
# 40
# la
# Provides for funding for facility enhancement of the  Fire and Emergency Training Institute at Louisiana State University
# 2011-04-15 00:00:00
# ['mickey james guillory']
# Error processing row 40 in current chunk, setting results to None.
# 41
# la
# Provides for changes to the Firefighters' Pension and Relief Fund in the city of New Orleans
# 2011-04-12 00:00:00
# ['jeffery "jeff" j. arnold']
# Error processing row 41 in current chunk, setting results to None.
# 42
# la
# Appropriates funds for payment of judgment against the Department of Transportation and Development in the suit entitled "Jean Boudreaux and the victims of the Flood of April 6, 1983, on the Tangipahoa River v. State of Louisiana, et al"
# 2011-04-08 00:00:00
# ['stephen e. pugh']
# Error processing row 42 in current chunk, setting results to None.
# 43
# la
# Provides with respect to the employment of minors
# 2011-04-14 00:00:00
# ['erich e. ponti']
# Error processing row 43 in current chunk, setting results to None.
# 44
# la
# Provides for campaign contribution disclosures by appointees to certain boards and commissions prior to confirmation
# 2011-04-15 00:00:00
# ['regina ashford barrow']
# Error processing row 44 in current chunk, setting results to None.
# 45
# la
# Provides with respect to the La. Hearing Aid Licensing Act
# 2011-04-14 00:00:00
# ['jack montoucet']
# Error processing row 45 in current chunk, setting results to None.
# 46
# la
# Provides for changes in the qualifications needed to serve on the parole board.
# 2010-03-08 00:00:00
# ['d.a. "butch" gautreaux']
# Error processing row 46 in current chunk, setting results to None.
# 47
# la
# Provides relative to funding by state entities of certain non-flood protection assets.
# 2010-03-17 00:00:00
# ['edwin r. murray']
# Error processing row 47 in current chunk, setting results to None.
# 48
# la
# Requires applicants for certain permits to attend any public hearings on the proposed permit.
# 2010-03-18 00:00:00
# ['dan w. "blade" morrish']
# Error processing row 48 in current chunk, setting results to None.
# 49
# la
# Authorizes BESE to exempt a school board from certain laws, rules, and regulations pursuant to a request and proposal for increasing quality of instruction and academic achievement from the school board.
# 2010-04-13 00:00:00
# ['ann d. duplessis']
# Error processing row 49 in current chunk, setting results to None.
# 50
# la
# Provides for a five-year final average compensation period.
# 2010-03-15 00:00:00
# ['d.a. "butch" gautreaux']
# Error processing row 50 in current chunk, setting results to None.
# 51
# la
# Provides relative to the permission to move the remains of a deceased person.
# 2010-03-18 00:00:00
# ['julie quinn']
# Error processing row 51 in current chunk, setting results to None.
# 52
# la
# Provides relative to the delay for applying for a new trial in parish and city courts.
# 2010-03-08 00:00:00
# ['conrad appel']
# Error processing row 52 in current chunk, setting results to None.
# 53
# la
# Provides that the chairmen of the Senate and House Committees on transportation, highways and public works shall serve as chairman of the board of the Louisiana Transportation Authority on a two-year rotating basis.
# 2010-03-15 00:00:00
# ['william joseph mcpherson, jr.']
# Error processing row 53 in current chunk, setting results to None.
# 54
# la
# Authorizes certain special schools to share services and functions under certain conditions
# 2010-03-16 00:00:00
# ['patricia haynes smith']
# Error processing row 54 in current chunk, setting results to None.
# 55
# la
# Provides relative to the maximum state health insurance contribution for certain judicial retirees
# 2010-03-08 00:00:00
# ['joel c. robideaux']
# Error processing row 55 in current chunk, setting results to None.
# 56
# la
# Provides for changes to the Firefighters' Pension and Relief Fund in the city of New Orleans
# 2010-03-15 00:00:00
# ['jeffery "jeff" j. arnold']
# Error processing row 56 in current chunk, setting results to None.
# 57
# la
# Provides for term limits for certain statewide elected officials
# 2010-02-26 00:00:00
# ['simone b. champagne']
# Error processing row 57 in current chunk, setting results to None.
# 58
# la
# Provides relative to local ethics entities in certain parishes
# 2010-03-17 00:00:00
# ['cameron henry']
# Error processing row 58 in current chunk, setting results to None.
# 59
# la
# Authorizes the issuance of a restricted hunter education certificate for developmentally disabled hunters
# 2010-03-18 00:00:00
# ['karen gaudet st. germain']
# Error processing row 59 in current chunk, setting results to None.
# 60
# la
# Adds the crimes of human trafficking and trafficking of children for sexual purposes to the list of sex offenses and crimes of violence
# 2010-03-18 00:00:00
# ['neil c. abramson']
# Error processing row 60 in current chunk, setting results to None.
# 61
# la
# Amends the crime of simple arson
# 2010-03-15 00:00:00
# ['karen gaudet st. germain']
# Error processing row 61 in current chunk, setting results to None.
# 62
# la
# Allows a ticket to an athletic contest of an institution of higher education to be sold for more than face value in certain situations
# 2010-03-04 00:00:00
# ['clifton r. richardson']
# Error processing row 62 in current chunk, setting results to None.
# 63
# la
# Removes convictions for possession of controlled dangerous substances as prior offenses for purposes of the habitual offender law
# 2010-03-04 00:00:00
# ['walt leger, iii']
# Error processing row 63 in current chunk, setting results to None.
# 64
# la
# Provides relative to eligibility of certain home study students to participate in interscholastic athletics at secondary schools that are members of the LHSAA
# 2010-03-11 00:00:00
# ['cameron henry']
# Error processing row 64 in current chunk, setting results to None.
# 65
# la
# Merges the Fertilizer Commission and the La. Feed Commission
# 2010-03-15 00:00:00
# ['m.j. "mert" smiley, jr.']
# Error processing row 65 in current chunk, setting results to None.
# 66
# la
# Authorizes the secretary of the Dept. of Wildlife and Fisheries to develop certification standards for La. wild fish and seafood including wild-caught shrimp
# 2010-03-18 00:00:00
# ['joe harrison']
# Error processing row 66 in current chunk, setting results to None.
# 67
# la
# To increase emission inspection fees
# 2010-03-18 00:00:00
# ['michael l. jackson']
# Error processing row 67 in current chunk, setting results to None.
# 68
# la
# Provides relative to the distribution and sale of motor vehicles
# 2010-03-19 00:00:00
# ['jeffery "jeff" j. arnold']
# Error processing row 68 in current chunk, setting results to None.
# 69
# la
#  Provides relative to the sale of expropriated property
# 2010-03-10 00:00:00
# ['walt leger, iii']
# Error processing row 69 in current chunk, setting results to None.
# 70
# la
# Increases the employee contribution rate for certain members of state retirement systems.
# 2012-01-27 00:00:00
# ['elbert l. guillory']
# Error processing row 70 in current chunk, setting results to None.
# 71
# la
# Creates the crime of failure to report certain felonies.
# 2012-02-28 00:00:00
# ['daniel r. martiny']
# Error processing row 71 in current chunk, setting results to None.
# 72
# la
# Provides relative to allocation of monies from the St. Tammany Parish Fund.
# 2012-03-01 00:00:00
# ['jack donahue']
# Error processing row 72 in current chunk, setting results to None.
# 73
# la
# Provides for the appointment of the district public defender for the 4th Judicial District.
# 2012-04-03 00:00:00
# ['michael a. walsworth']
# Error processing row 73 in current chunk, setting results to None.
# 74
# la
# Prohibits discrimination in state employment based upon sexual identification.
# 2012-02-20 00:00:00
# ['edwin r. murray']
# Error processing row 74 in current chunk, setting results to None.
# 75
# la
# Requires National Human Trafficking Resource Center hotline information to be posted at certain establishments, truck stops, and rest stops.
# 2012-03-02 00:00:00
# ['sharon weston broome']
# Error processing row 75 in current chunk, setting results to None.
# 76
# la
# Provides relative to merger of the La. School Employees' Retirement System into the Teachers' Retirement System of La.
# 2012-01-27 00:00:00
# ['patrick page cortez']
# Error processing row 76 in current chunk, setting results to None.
# 77
# la
# Provides that a person who successfully completes the Motorcycle, Safety, Awareness, and Operator Training Program is not required to take a written knowledge test to obtain an "M" endorsement on his driver's license.
# 2012-02-16 00:00:00
# ['richard "rick" gallot, jr.']
# Error processing row 77 in current chunk, setting results to None.
# 78
# la
# Provides for the posting of the notice of a meeting of a public body on the official website of the public body
# 2012-03-01 00:00:00
# ['neil c. abramson']
# Error processing row 78 in current chunk, setting results to None.
# 79
# la
# Appropriates funds for payment of judgment against DOTD in the matter of "Carl Fruge and Darla Fruge v. State Farm Fire and Casualty Company, et al"
# 2012-02-23 00:00:00
# ['kenny r. cox']
# Error processing row 79 in current chunk, setting results to None.
# 80
# la
# Relative to revision of local government laws pursuant to HCR No. 218 of the 2009 R.S., repeals certain obsolete or ineffective provisions
# 2012-02-29 00:00:00
# ['roy a. burrell']
# Error processing row 80 in current chunk, setting results to None.
# 81
# la
# Provides relative to benefits in the Firefighters' Pension and Relief Fund in the city of New Orleans
# 2012-01-27 00:00:00
# ['walt leger, iii']
# Error processing row 81 in current chunk, setting results to None.
# 82
# la
# Provides relative to the eligibility for restrictive licenses
# 2012-03-01 00:00:00
# ['steve e. pylant']
# Error processing row 82 in current chunk, setting results to None.
# 83
# la
# Enacts the Jefferson Parish Seafood Disclosure Law
# 2012-03-02 00:00:00
# ['patrick connick']
# Error processing row 83 in current chunk, setting results to None.
# 84
# la
# Provides relative to health care provider charges for health records
# 2012-03-02 00:00:00
# ['hunter v. greene']
# Error processing row 84 in current chunk, setting results to None.
# 85
# la
# Provides with respect to ad valorem taxes for fire and police protection in Orleans Parish
# 2012-02-29 00:00:00
# ['walt leger, iii']
# Error processing row 85 in current chunk, setting results to None.
# 86
# la
# Provides with respect to the location of qualified truck stop facilities within prohibited distances from certain properties
# 2012-02-20 00:00:00
# ['joseph p. lopinto iii']
# Error processing row 86 in current chunk, setting results to None.
# 87
# la
# Repeals provisions relative to the production and marketing of livestock
# 2012-02-14 00:00:00
# ['simone b. champagne']
# Error processing row 87 in current chunk, setting results to None.
# 88
# la
# Removes certain restrictions relative to contracting and employment applicable to former members of the board of commissioners of the St. Tammany Parish Hospital Service District No. 1
# 2012-02-27 00:00:00
# ['scott m. simon']
# Error processing row 88 in current chunk, setting results to None.
# 89
# la
# Provides for prospective application of new medical treatment guidelines
# 2012-02-29 00:00:00
# ['edward c. "ted" james ii']
# Error processing row 89 in current chunk, setting results to None.
# 90
# la
# Repeals provisions that authorize local governmental subdivisions to create certain economic development districts
# 2012-03-02 00:00:00
# ['simone b. champagne']
# Error processing row 90 in current chunk, setting results to None.
# 91
# la
# Provides for the transfer of hospital inpatients who require specialized care to other hospitals
# 2012-03-02 00:00:00
# ['scott m. simon']
# Error processing row 91 in current chunk, setting results to None.
# 92
# la
# Appropriates funds for payment of judgment against the state in the matter of "Stephen and Lori Davis, et al v. DOTD" consolidated with "Christina Wiley, et al v. DOTD" consolidated with "Amanda Townsend, et al v. DOTD"
# 2012-02-27 00:00:00
# ['steve e. pylant']
# Error processing row 92 in current chunk, setting results to None.
# 93
# la
# Establishes Annual Second Amendment Weekend Holiday to exempt from state and local sales tax each year consumer purchases of firearms, ammunition, and hunting supplies from the first consecutive Friday through Sunday of September each year.
# 2009-04-06 00:00:00
# ['robert m. marionneaux, jr.']
# Error processing row 93 in current chunk, setting results to None.
# 94
# la
# Provides for enhancement of penalties for a parent who participates or allows a juvenile to engage in a felony criminal act.
# 2009-04-17 00:00:00
# ['willie l. mount']
# Error processing row 94 in current chunk, setting results to None.
# 95
# la
# Provides relative to motor vehicle fatalities.
# 2009-04-17 00:00:00
# ['william joseph mcpherson, jr.']
# Error processing row 95 in current chunk, setting results to None.
# 96
# la
# Constitutional amendment to repeal the provision prohibiting an otherwise eligible person from receiving the "special assessment level" because their income exceeds a certain amount.
# 2009-04-14 00:00:00
# ['julie quinn']
# Error processing row 96 in current chunk, setting results to None.
# 97
# la
# Constitutional amendment to delete the authority of taxing authorities to roll forward ad valorem tax millage rates after a reappraisal.
# 2009-04-06 00:00:00
# ['john a. alario, jr.']
# Error processing row 97 in current chunk, setting results to None.
# 98
# la
# Ends the "suspension" and makes retroactive from January 1, 1998, the sales tax exemption granted for on-premises, non-public sales of meals furnished to the staff and students of educational institutions; the staff and patients of hospitals and mental institutions; boarders of rooming houses; and occasional meals furnished in connection with or by educational, religious, or medical organizations.
# 2009-04-13 00:00:00
# ['michael j. "mike" michot']
# Error processing row 98 in current chunk, setting results to None.
# 99
# la
# Requires a homeowner's insurer to give notice to a mortgagee or other interested party under certain circumstances
# 2009-04-16 00:00:00
# ['christopher j. roy, jr.']
# Error processing row 99 in current chunk, setting results to None.
# 2
# ____________________________________________
# 0
# mi
# Controlled substances; schedules; certain synthetic substances; classify as schedule 1 controlled substances and prohibit sales and offer to sell certain products represented to have the effects of certain controlled substances. Amends secs. 7212, 7401, 7402, 7403 & 7404 of 1978 PA 368 (MCL 333.7212 et seq.) & adds sec. 7417.
# 2012-04-19 00:00:00
# ['david hildenbrand']
# Error processing row 0 in current chunk, setting results to None.
# 1
# mi
# Labor; fair employment practices; awarding state government contracts to businesses that employ undocumented workers; prohibit. Amends 1984 PA 431 (MCL 18.1101 - 18.1594) by adding sec. 264a.
# 2011-01-26 00:00:00
# ['glenn anderson']
# Error processing row 1 in current chunk, setting results to None.
# 2
# mi
# Property tax; assessments; sale price as presumptive true cash value when property is sold; establish. Amends sec. 27 of 1893 PA 206 (MCL 211.27).
# 2011-01-27 00:00:00
# ['tory rocca']
# Error processing row 2 in current chunk, setting results to None.
# 3
# mi
# Income tax; administration; corporate income tax deductions and withholdings provisions; clean up. Amends sec. 705 of 1967 PA 281 (MCL 206.705).
# 2011-09-15 00:00:00
# ['john proos']
# Error processing row 3 in current chunk, setting results to None.
# 4
# mi
# ...
# 2015-04-30 00:00:00
# ['ajello', 'diaz', 'almeida', 'mckiernan', 'regunberg']
# Error processing row 29 in current chunk, setting results to None.
# 30
# ri
# AN ACT RELATING TO TAXATION - LEVY AND ASSESSMENT OF LOCAL TAXES (Increases the maximum tax from eight percent (8%) to twelve percent (12%) of gross scheduled rental income to be eligible for low-income housing.)
# 2015-02-05 00:00:00
# ['phillips', 'morin', 'casey']
# Error processing row 30 in current chunk, setting results to None.
# 31
# ri
# AN ACT RELATING TO TAXATION - THE RHODE ISLAND COLLEGE INTERNSHIP TAX CREDIT ACT (would create the Rhode Island College Internship Tax Credit Act)
# 2014-02-12 00:00:00
# ['gallo', 'lynch']
# Error processing row 31 in current chunk, setting results to None.
# 32
# ri
# AN ACT RELATING TO MOTOR AND OTHER VEHICLES -- ABANDONED MOBILE AND MANUFACTURED HOME ACT (This act would provide a procedure for removal of abandoned mobile or manufactured homes under the jurisdiction of the district court.)
# 2014-03-04 00:00:00
# ['fogarty', 'cool rumsey', 'ottiano', 'dipalma']
# Error processing row 32 in current chunk, setting results to None.
# 33
# ri
# AN ACT RELATING TO FOOD AND DRUGS -- UNIFORMED CONTROLLED SUBSTANCE ACT (Authorizes the Traffic Tribunal to seal marijuana conviction records of less than 1 oz. Immediately, And Extends The Period a person can satisfy conditions of a marijuana possession enhanced civil penalty by calculating the penalty from conviction date.)
# 2014-02-27 00:00:00
# ['lynch', 'lombardi', 'archambault', 'lombardo']
# Error processing row 33 in current chunk, setting results to None.
# 34
# ri
# AN ACT RELATING TO COURTS AND CIVIL PROCEDURE - PROCEDURE IN PARTICULAR ACTIONS - JOINT AND SEVERAL LIABILITY (would limit liability of a tortfeasor for damages to several only and not joint if it is found that the defendant’s act or omission constituted no more than25% of the damages sustained by the plaintiff.)
# 2014-01-21 00:00:00
# ['cote']
# Error processing row 34 in current chunk, setting results to None.
# 35
# ri
# AN ACT RELATING TO SOLEMNIZATION OF MARRIAGES (would allow Thomas Welch to join Mary Newman and Michael McNeice in marriage on or about September 13, 2014, within the Town of Bristol, Rhode Island)
# 2014-01-09 00:00:00
# ['ruggiero', 'gallison']
# Error processing row 35 in current chunk, setting results to None.
# 36
# ri
# AN ACT RELATING TO LABOR AND LABOR RELATIONS - WORKERS' COMPENSATION - GENERAL PROVISIONS (Provides for various changes to the jurisdiction, procedure, and administration of the Rhode Island workers' compensation court.)
# 2014-06-05 00:00:00
# ['shekarchi', 'guthrie', 'slater', 'amore']
# Error processing row 36 in current chunk, setting results to None.
# 37
# ri
# AN ACT RELATING TO SOLEMNIZATION OF MARRIAGES (This act would allow Robert Lippmann to join Molly Murkett and Daniel Bruno in marriage on or about August 2, 2014, within the Town of Westerly, Rhode Island.)
# 2014-03-06 00:00:00
# ['azzinaro']
# Error processing row 37 in current chunk, setting results to None.
# 38
# ri
# AN ACT RELATING TO BUSINESSES AND PROFESSIONS - UNDERGROUND UTILITY CONTRACTORS (This act would establish qualifications/procedures to license underground utility contractors. It would also enlarge the contractor's registration and licensing board from fifteen (15) to seventeen (17) members to administer and to oversee the licensees.)
# 2014-02-26 00:00:00
# ['san bento', "o'brien", 'williams', 'costantino']
# Error processing row 38 in current chunk, setting results to None.
# 39
# ri
# AN ACT RELATING TO DECEPTIVE TRADE PRACTICES --MODEL FAIR CONSUMER CONTRACTS ACT (would repeal exemptions to the deceptive trade practices act. This act would create the "Model Fair Consumer Contracts Act" to protect consumers from exploitive contracts)
# 2014-02-13 00:00:00
# ['lima', 'o`neill', 'jacquard']
# Error processing row 39 in current chunk, setting results to None.
# 40
# ri
# AN ACT RELATING TO BUSINESS AND PROFESSIONS -- PHARMACIES (This act would set forth labeling requirements for a drug which is compounded at a licensed pharmacy when used in a healthcare facility or physician's office.)
# 2014-03-06 00:00:00
# ['marcello']
# Error processing row 40 in current chunk, setting results to None.
# 41
# ri
# AN ACT RELATING TO HIGHWAYS - MUNICIPAL ROAD AND BRIDGE REVOLVING FUND (would raise the maximum amount of financial assistance available from the road and bridge revolving fund from $20,000,000 to $50,000,000 and would also provide that any financial assistance be paid over a period of 10 years)
# 2014-01-30 00:00:00
# ['mclaughlin', 'hull', 'bennett']
# Error processing row 41 in current chunk, setting results to None.
# 42
# ri
# AN ACT RELATING TO TAXATION - SALES AND USE TAXES - LIABILITY AND COMPUTATION (would authorize the creation of a municipal economic development zone consisting of the entire city of Woonsocket & require that the director of the dept of revenue perform an annual review of all MED zones)
# 2014-02-06 00:00:00
# ['phillips', 'casey', 'abney', 'gallison', 'shekarchi']
# Error processing row 42 in current chunk, setting results to None.
# 43
# ri
# AN ACT RELATING TO HUMAN SERVICES - EQUAL RIGHTS OF BLIND AND DEAF PERSONS TO PUBLIC FACILITIES
# 2012-02-07 00:00:00
# ['walaska', 'bates', 'lynch', 'gallo']
# Error processing row 43 in current chunk, setting results to None.
# 44
# ri
# AN ACT RELATING TO INSURANCE -- MOTOR VEHICLE DAMAGE APPRAISERS
# 2012-03-01 00:00:00
# ['goodwin']
# Error processing row 44 in current chunk, setting results to None.
# 45
# ri
# AN ACT RELATING TO HEALTH AND SAFETY - STATE BUILDING CODE (would establish a restricted receipt account for the purpose of funding the purchase and operation of a web-accessible software system to be utilized by the state/municipalities for a uniform, statewide electronic plan review)
# 2012-02-28 00:00:00
# ['sosnowski', 'lynch', 'lombardo', 'perry', 'walaska']
# Error processing row 45 in current chunk, setting results to None.
# 46
# ri
# AN ACT RELATING TO HEATH AND SAFETY -- CORRECTIONAL HEALTHCARE ACT (would establish the correctional healthcare act in order to reduce the costs of correctional healthcare.)
# 2012-01-18 00:00:00
# ['walaska']
# Error processing row 46 in current chunk, setting results to None.
# 47
# ri
# AN ACT RELATING TO HEALTH AND SAFETY -- ENERGY (would facilitate the creation of a waste-to-energy facility located in the city of Woonsocket.)
# 2012-01-05 00:00:00
# ['brien', 'phillips', 'baldelli-hunt']
# Error processing row 47 in current chunk, setting results to None.
# 48
# ri
# AN ACT RELATING TO PUBLIC OFFICERS AND EMPLOYEES - LONGEVITY PAYMENTS (would eliminate longevity payments for any state employee, any employees of the Board of Governors of Higher Education, the BRE&SE, the RI Public Telec. Authority, & of quasi-public corp., not provided for in a collective bargaining agreement.)
# 2012-02-08 00:00:00
# ['dasilva', 'guthrie', 'flaherty', 'savage', 'messier']
# Error processing row 48 in current chunk, setting results to None.
# 49
# ri
# AN ACT RELATING TO STATE AFFAIRS AND GOVERNMENT - TOURISM AND DEVELOPMENT (would make changes in the percentage distribution of the proceeds of the hotel tax)
# 2012-03-06 00:00:00
# ['brien', 'reilly', 'phillips']
# Error processing row 49 in current chunk, setting results to None.
# 50
# ri
# AN ACT RELATING TO HEALTH AND SAFETY - PLACES OF ASSEMBLY (would exempt places of assembly meeting or exceeding current fire codes from the requirement of having a firefighter present.)
# 2012-02-15 00:00:00
# ['trillo', 'williams', 'brien', 'ferri', 'malik']
# Error processing row 50 in current chunk, setting results to None.
# 51
# ri
# AN ACT RELATING TO INSURANCE -- PORTABLE ELECTRONICS INSURANCE
# 2012-02-09 00:00:00
# ['kennedy', 'san bento', 'lally', 'coderre', 'naughton']
# Error processing row 51 in current chunk, setting results to None.
# 52
# ri
# AN ACT RELATING TO THE BOARD OF MEDICAL LICENSURE AND DISCIPLINE (would add a definition for medical records to the current statute)
# 2012-03-06 00:00:00
# ['bennett', 'hull', 'mcnamara', 'medina', 'gallison']
# Error processing row 52 in current chunk, setting results to None.
# 53
# ri
# AN ACT RELATING TO TOWNS AND CITIES - STATE AFFAIRS AND GOVERNMENT - LAW ENFORCEMENT OFFICERS - INJURED AND DECEASED FIREFIGHTERS AND POLICE (would amend the definition of police officer or law enforcement officer  to include campus police officers.)
# 2012-01-25 00:00:00
# ['san bento', 'dasilva', 'lally', 'hull', 'savage']
# Error processing row 53 in current chunk, setting results to None.
# 54
# ri
# AN ACT RELATING TO HIGHWAYS (would require the dept. of transportation to use complete street design principles to accommodate the mobility needs of all users and would require the dept. of transportation to publish a report showing how the agency has complied with the requirements)
# 2012-02-02 00:00:00
# ['martin']
# Error processing row 54 in current chunk, setting results to None.
# 55
# mo
# Requires health carriers to file their premium rates and accompanying information with the Department of Insurance for approval
# 2013-02-19 00:00:00
# ['levota']
# Error processing row 55 in current chunk, setting results to None.
# 56
# mo
# Allows circuit courts that reimburse the state for the salaries of family court commissioners to charge up to a twenty dollar surcharge for cases
# 2012-12-01 00:00:00
# ['dixon']
# Error processing row 56 in current chunk, setting results to None.
# 57
# mo
# Modifies the criteria for determining whether a child is a special needs child for the purposes of the special needs adoption tax credit
# 2012-12-01 00:00:00
# ['lamping']
# Error processing row 57 in current chunk, setting results to None.
# 58
# mo
# Changes the laws regarding insurance coverage under the Missouri Life and Health Insurance Guaranty Association Act
# 2012-12-17 00:00:00
# ['gatschenberger, chuck']
# Error processing row 58 in current chunk, setting results to None.
# 59
# mo
# Prohibits any state or local governmental entity; public building, park, or school; or public setting or place from banning or restricting the practice, mention, celebration, or discussion of any federal holiday
# 2013-01-23 00:00:00
# ['brattin, rick']
# Error processing row 59 in current chunk, setting results to None.
# 60
# mo
# Repeals the provisions regarding the prevailing hourly wage requirements and specifies that no person will be paid a prevailing wage with specified exceptions
# 2013-02-25 00:00:00
# ['fitzpatrick, scott']
# Error processing row 60 in current chunk, setting results to None.
# 61
# mo
# Requires the Department of Social Services to seek a federal waiver to mandate the use of photo identification for continued eligibility in the food stamp program
# 2013-01-23 00:00:00
# ['english, keith']
# Error processing row 61 in current chunk, setting results to None.
# 62
# mo
# Prohibits publishing of the names of lottery winners
# 2013-02-28 00:00:00
# ['walton gray, rochelle']
# Error processing row 62 in current chunk, setting results to None.
# 63
# mo
# Requires the transfer of excess fund balances to the state general revenue fund
# 2015-01-29 00:00:00
# ['schaefer']
# Error processing row 63 in current chunk, setting results to None.
# 64
# mo
# Prohibits employers from inquiring into or considering the criminal records of applicants before offering a conditional offer of employment
# 2014-12-01 00:00:00
# ['nasheed']
# Error processing row 64 in current chunk, setting results to None.
# 65
# mo
# Modifies provisions relating to elementary and secondary education
# 2014-12-01 00:00:00
# ['sifton']
# Error processing row 65 in current chunk, setting results to None.
# 66
# mo
# Requires new city council members to receive training and orientation
# 2014-12-01 00:00:00
# ['walton gray, rochelle']
# Error processing row 66 in current chunk, setting results to None.
# 67
# mo
# Defines "annual general operating revenue" for purposes of section 302.341
# 2014-12-19 00:00:00
# ['cornejo, robert']
# Error processing row 67 in current chunk, setting results to None.
# 68
# mo
# Modifies provisions related to committees of political parties
# 2015-01-26 00:00:00
# ['entlicher, sue']
# Error processing row 68 in current chunk, setting results to None.
# 69
# mo
# Specifies that public school students must not be subject to penalties or discipline for simulating a weapon while playing if it does not cause bodily harm, disrupt learning, or constitute a serious threat
# 2014-12-23 00:00:00
# ['kelley, mike']
# Error processing row 69 in current chunk, setting results to None.
# 70
# mo
# Extends the expiration date on various federal reimbursement allowances for three years
# 2015-01-29 00:00:00
# ['flanigan, tom']
# Error processing row 70 in current chunk, setting results to None.
# 71
# mo
# Authorizes a tax credit for donations to a state building and capital improvement fund and establishes a check-off for donations to the fund on income tax returns
# 2014-02-26 00:00:00
# ['messenger, jeffrey']
# Error processing row 71 in current chunk, setting results to None.
# 72
# mo
# Exempts industrial hemp from the list of controlled substances and specifies that it is legal for anyone who has not been convicted of a drug-related crime to cultivate hemp
# 2014-02-27 00:00:00
# ['colona, mike']
# Error processing row 72 in current chunk, setting results to None.
# 73
# mo
# Proposes a constitutional amendment regarding the Governor's authority to expend state funds
# 2014-01-21 00:00:00
# ['fitzpatrick, scott']
# Error processing row 73 in current chunk, setting results to None.
# 74
# mo
# Raises the minimum teacher salary for the 2015-2016 school year, subject to appropriation
# 2014-02-13 00:00:00
# ['cookson, steve']
# Error processing row 74 in current chunk, setting results to None.
# 75
# mo
# Allows certain county hospital trustees to offer health care services in adjoining counties
# 2014-01-27 00:00:00
# ['muntzel, dave']
# Error processing row 75 in current chunk, setting results to None.
# 76
# mo
# Changes the laws regarding the school funding formula by adding an additional weight for each gifted student to the calculation of the school district's weighted average daily attendance
# 2014-01-23 00:00:00
# ['sommer, chrissy']
# Error processing row 76 in current chunk, setting results to None.
# 77
# mo
# Prohibits the payment of professional membership dues of any school administrator or superintendent from the incidental fund or teachers fund of a school district and places limits on superintendent salaries
# 2014-02-19 00:00:00
# ['bahr, kurt']
# Error processing row 77 in current chunk, setting results to None.
# 78
# mo
# Requires candidates for election to the board of the Springfield School District in which more than one seat is open to declare their candidacy for a specific seat
# 2012-03-28 00:00:00
# ['leach, melissa']
# Error processing row 78 in current chunk, setting results to None.
# 79
# mo
# Changes the laws regarding the Joint Committee on Education's review of the Commissioner of Education's proposed expenditures on statewide areas of critical need for learning and development
# 2012-03-29 00:00:00
# ['aull, joe']
# Error processing row 79 in current chunk, setting results to None.
# 80
# mo
# Proposes a constitutional amendment which freezes the level of tax liability on residential property owned by a person who is 65 years of age or older
# 2012-01-23 00:00:00
# ['denison, charlie']
# Error processing row 80 in current chunk, setting results to None.
# 81
# mo
# Requires children in the St. Louis City School District and Kansas City School District to enroll in a school by age five
# 2012-02-28 00:00:00
# ['morgan, judy']
# Error processing row 81 in current chunk, setting results to None.
# 82
# mo
# Changes the laws regarding the Missouri individual income tax
# 2012-02-01 00:00:00
# ['oxford, jeanette mott']
# Error processing row 82 in current chunk, setting results to None.
# 83
# mo
# Establishes the Good Jobs First Act which provides development subsidies to certain corporations
# 2012-01-31 00:00:00
# ['oxford, jeanette mott']
# Error processing row 83 in current chunk, setting results to None.
# 84
# mo
# Changes the laws regarding solid waste management
# 2012-03-07 00:00:00
# ['ruzicka, don']
# Error processing row 84 in current chunk, setting results to None.

# %%
## append the chunks with no errors and errors 

k = 0
df_names = pd.DataFrame()
for j in range(0,len(df_chunks)):
    g['chunk'+str(j)] = df_chunks[j].copy()
    if j in error_chunks:
        g['chunk'+str(j)]['full_names'] = chunk_results_errors[k]
        k+=1
    else: 
        g['chunk'+str(j)]['full_names'] = chunk_results[j]

    df_names = pd.concat([df_names,g['chunk'+str(j)]])

# %%
## df_names.to_excel('./Data/withAPI.xlsx')

# %%
df_names.shape
# Out:
# (2585, 21)

# %%
### Start Manual Matching 

### first lets look at all bills with no legiscan match and have  only one sponsor  and have at least two names for sponsor
slice_full = df_names.copy()
slice_full = slice_full[(slice_full['full_names'].isna()) | (slice_full['full_names'].apply(lambda x: x == []))]
slice_full['len_list'] = slice_full['name_list'].apply(lambda x: len(x))
slice_full  = slice_full[slice_full.len_list == 1]
slice_full['len_name'] = slice_full['name_list'].apply(lambda x: len(x[0].split()))
slice_full = slice_full[slice_full.len_name >= 2]

# %%
def process_name(name_list):
    if not name_list:  # Check if the list is empty
        return ['', '']  # Return empty first and last names
    
    #get the full name for this slice 
    full_name = name_list[0] 

    #and split first last and possibly middle name
    names = full_name.split()
    
    # If there is a comma in the name
    if ',' in full_name:
        parts = full_name.replace(',', '').split()  # Remove comma and split
        if len(parts) >= 3:  # Last, First, Middle
            first_name = parts[1]  # Second element becomes the first name
            last_name = parts[2] + ' ' + parts[0]  # Combine third element and first element as last name. Now in first and last name format

        elif len(parts) == 2:  #last, first
            first_name = parts[1]  # Second element becomes the first name
            last_name = parts[0]  # First element becomes the last name
        else:  # Handling unexpected format gracefully
            first_name = parts[0]  # Use what we have
            last_name = ''
    else:
        # Handling names without comma
        if len(names) >= 2:  # More than two names without comma. then first name last name format
            first_name, last_name = names[0], names[-1]  # Take only first and last
        else:
            first_name, last_name = names[0], ''  # Only one name given

    return first_name, last_name
# Apply the function to each row in the DataFrame
## get two columns
slice_full[['first_name', 'last_name']] = slice_full['name_list'].apply(lambda x: process_name(x)).tolist()

# %%
slice_full.head(2)


## get ideological dataset
leg = pd.read_csv('C:/Users/ayush/Downloads/legislators.csv')
leg['first_name'] = leg['first_name'].str.lower()
leg['last_name'] = leg['last_name'].str.lower()

def remove_roman_numerals(s):
    ''' Remove roman numerals from names'''
    pattern = r'\b(i{1,3}|iv|vi{0,3}|ix)\b'
    return re.sub(pattern, '', s).strip()

leg['last_name'] = leg['last_name'].apply(remove_roman_numerals)

leg['house'] = leg['u_id'].dropna().apply(lambda x: str(x)[6])
leg['house'] = np.where((leg['house'] == 'L')&(leg['house'].notna()), 'lower',leg['house'])
leg['house'] = np.where((leg['house'] == 'U')&(leg['house'].notna()), 'upper',leg['house'])
leg = leg[['first_name','last_name','party','state','ideology','house']]
leg.head(2)


##merge on last name. 
look = pd.merge(slice_full, leg, on = ['last_name', 'state'], how = 'left')
# Out:
#            date_signed      date_introduced  \
# 0  2013-06-27 01:12:07  2013-01-03 11:50:16
# 1  2013-07-15 02:08:29  2013-01-31 11:03:40
#
#                                  bill_document_first         date_updated  \
# 0  \r\n\r\n\r\nSB 0013\r\n\r\n\r\n\r\n \r\n\r\n\r...  2013-08-13 01:57:16
# 1  \r\n\r\n\r\nSB 0185\r\n\r\n\r\n\r\n \r\n\r\n\r...  2013-08-29 00:38:17
#
#   short_title bill_type                                            actions  \
# 0        None    [bill]  [{'date': '2013-01-03 11:50:16', 'action': 'In...
# 1        None    [bill]  [{'date': '2013-01-31 11:03:40', 'action': 'In...
#
#   summary chamber state  ...  \
# 0    None   upper    nh  ...
# 1    None   upper    nh  ...
#
#                                           bill_title  \
# 0  relative to hearings in the department of safety.
# 1  establishing a commission on housing policy an...
#
#                                             sponsers bill_id  sunlight_id  \
# 0  [{'leg_id': 'NHL000021', 'type': 'primary', 'n...   SB 13  NHB00002073
# 1  [{'leg_id': 'NHL000019', 'type': 'primary', 'n...  SB 185  NHB00002765
#
#         name_list full_names len_list len_name first_name last_name
# 0  [jim b rausch]         []        1        3        jim    rausch
# 1     [bob odell]         []        1        2        bob     odell
#
# [2 rows x 25 columns]
#   first_name last_name party state  ideology  house
# 0         al     adams     D    ak     -1.02  lower
# 1        tom  anderson     R    ak      0.65  lower

# %%
## in the many to one merge we only select those cases where the first names dont match and assess them manually. 

look['check'] = np.where(look.first_name_x != look.first_name_y,1,0)
rectify_match = look[look.check == 1]

##save dataframe and edit manually 
# rectify_match.to_excel('./Data/assessed_match.xlsx')

#drop duplicates where there were correct matches 
correct_match = look[look.check == 0].drop_duplicates(subset = ['bill_document_first','first_name_x','last_name','first_name_y'], keep = 'first')

# call back edited dataframe
# manual_match = pd.read_excel('./Data/assessed_match.xlsx')

##Add back he matches into the original dataframe shape. Keep names I selected manually 
manual_match = manual_match[['state','session','bill_id','name_list', 'first_name_x', 'first_name_y', 'party', 'ideology', 'house']]
manual_match = pd.merge(manual_match,rectify_match[['state','session','bill_id','first_name_x','last_name']], on = ['state','session','bill_id','first_name_x'], how = 'left')
manual_match = manual_match[['first_name_x','first_name_y', 'last_name', 'party', 'ideology', 'house']]
rectify_match = pd.merge(rectify_match,manual_match, on = ['first_name_x','first_name_y','last_name'], how = 'left')
rectify_match = rectify_match[rectify_match.ideology_y.notna()]
rectify_match.shape
rectify_match = rectify_match.drop_duplicates(subset = ['bill_document_first','first_name_x','last_name','first_name_y'], keep = 'first')
rectify_match.shape
rectify_match = rectify_match[['date_signed', 'date_introduced', 'bill_document_first', 'date_updated',
       'short_title', 'bill_type', 'actions', 'summary', 'chamber', 'state',
       'session', 'action_dates', 'unique_id', 'bill_document_last',
       'date_created', 'bill_title', 'sponsers', 'bill_id', 'sunlight_id',
       'name_list', 'full_names', 'len_list', 'len_name', 'first_name_x',
       'last_name', 'first_name_y','party_y', 'ideology_y', 'house_y',
       'check']]
rectify_match.rename(columns = {'party_y':'party','ideology_y':'ideology','house_y':'house'}, inplace = True)

##matched full names 
full_name_matches = pd.concat([correct_match,rectify_match])
full_name_matches.shape
# Out:
# (206, 33)
# (101, 33)
# (302, 30)

# %%
## doing the same for bills where there is only first name 
slice_half = df_names.copy()
slice_half = slice_half[(slice_half['full_names'].isna()) | (slice_half['full_names'].apply(lambda x: x == []))]
slice_half['len_list'] = slice_half['name_list'].apply(lambda x: len(x))
slice_half = slice_half[slice_half.len_list == 1]
slice_half['len_name'] = slice_half['name_list'].apply(lambda x: len(x[0].split()))
slice_half = slice_half[slice_half.len_name < 2]

# %%
## only keep those rows which have unique matches. No way to know about those that have multiple matches
slice_half['last_name'] = slice_half.name_list.apply(lambda x: x[0])
look2 = pd.merge(slice_half, leg, on = ['last_name', 'state'], how = 'left')
look2.shape
keep_unique = pd.DataFrame(look2.last_name.value_counts().sort_values()).reset_index()
keep_unique_list = keep_unique[keep_unique.last_name == 1]['index'].tolist()
half_name_matches = look2[look2.last_name.isin(keep_unique_list)]
half_name_matches.shape
# Out:
# (1143, 28)
# (298, 28)

# %%
## LegiScan matches
df_names2 = df_names.copy()
df_names2.shape
df_names2 = df_names2[(df_names2['full_names'].notna()) & (df_names2['full_names'].apply(lambda x: x != []))]
df_names2.shape
df_names2['len_full'] = df_names2.full_names.apply(lambda x: len(x))
df_names2 = df_names2[df_names2.len_full != 0]
df_names2.shape
# Out:
# (2585, 21)
# (735, 21)
# (735, 22)

# %%
def find_matching_elements(list1, list2):
    ''' ;LegiScan results in more sponsors than in raw bills dataset. From legiscan results 
    Keep only those names whose last name matches with the legislator name in the raw bill. No cases where 
    bill has two legislator with same names'''
    unique_words_list1 = set()
    # Split elements of list1 into words and add to the set
    for element in list1:
        parts = element.lower().split()
        for part in parts:
            unique_words_list1.add(part.replace(',', '').replace('.', '') )
    
    # Initialize set for unique matching names from list2
    unique_names_list2 = set()
    # Check if any part of the names from list2 matches any word in list1
    for full_name in list2:
        name_parts = full_name.lower().split()
        for name_part in name_parts:
            if name_part in unique_words_list1:
                unique_names_list2.add(full_name)  # Add original name to preserve formatting
                break  # Stop searching through this name as we have found a match
    
    return list(unique_names_list2)  #

# %%
df_names2['overlapping_names'] = df_names2.apply(lambda row: find_matching_elements(row['name_list'], row['full_names']), axis=1)
df_names2['len_full'] = df_names2.overlapping_names.apply(lambda x: len(x))
df_names2 = df_names2[df_names2.len_full != 0]

# %%
df_names2.shape
# Out:
# (673, 23)

# %%
## calling legislators again. different processing than we called last time

leg = pd.read_csv('./Data/legislators.csv')
leg['last_name'] = leg['last_name'].str.lower()
leg.head(2)
# Out:
#   first_name last_name party state        u_id  ideology  senate2008  \
# 0         Al     adams     D    ak  AK1995L036     -1.02         NaN
# 1        Tom  anderson     R    ak  AK2003L035      0.65         NaN
#
#    senate2009  senate2010  senate2011  senate2012  senate2013  senate2014  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN         NaN         NaN
#
#    senate2015  house2008  house2009  house2010  house2011  id
# 0         NaN        NaN        NaN        NaN        NaN   1
# 1         NaN        NaN        NaN        NaN        NaN   1

# %%
def get_ideology_scores(row):
    ''' For legiscan matched names merging with ideology dataset here seenms to complicate things. 
    instead look for the full name in the overlapping names column by first and last name in ideology and append the ideology score in a list.
    Append becaus there could be multiple sponsors. Later we will find the mean of each list for for each row  '''
    state = row['state']
    names = row['overlapping_names']
    scores = []

    for full_name in names:
        # Split the full name into first and last name and convert to lowercase
        parts = full_name.lower().split()
        if len(parts) >= 2:  # Check if the name can be split into at least first and last name
            first_name, last_name = parts[0], parts[-1]  # first and last name are the first and last parts

            # Filter  for matching first and last names and the same state
            matched = leg[(leg['first_name'].str.lower() == first_name) &
                                     (leg['last_name'].str.lower() == last_name) &
                                     (leg['state'].str.lower() == state)]
            scores.extend(matched['ideology'].tolist())  # Add matched ideology scores to the list

    return scores

# Apply function to each row in df to create the new 'ideology_scores' column

def get_party(row):
    ''' Same idea as above. bu this time get the party instead of ideology scores for all sponsors in a list and store as binary'''
    state = row['state']
    names = row['overlapping_names']
    values = []

    for full_name in names:
        # Split the full name into first and last name and convert to lowercase
        parts = full_name.lower().split()
        if len(parts) >= 2:  # Check if the name can be split into at least first and last name
            first_name, last_name = parts[0], parts[-1]  # Assuming first and last name are the first and last parts
            # Filter df_politicians for matching first and last names and the same state
            matched = leg[(leg['first_name'].str.lower() == first_name) &
                                     (leg['last_name'].str.lower() == last_name) &
                                     (leg['state'].str.lower() == state)]
            if not matched.empty:
                values.append(1 if matched['party'].values[0] == 'R' else 0)  # Add matched ideology scores to the list

    return values


def calculate_mean(row):
    ''' mean of each ideology score list for each row'''
    return np.mean(row) if len(row) > 0 else np.nan  

# Function to count the number of elements in the list
def count_elements(row):
    ''' number of sponsors for each bill'''
    return len(row)

# Function to calculate the variance (nanvar) of the list
def calculate_nanvar(row):
    '''Find the variance of the party sponsors. 1 for republican 0 for democrats '''
    return np.nanvar(row) if len(row) > 0 else np.nan  # Return NaN if the list is empty

# Function to determine party based on the first element
def determine_party(row):
    '''Also good to have party affiliation by party name along with binary'''
    if len(row) > 0:  # Check if the list is not empty
        return 'Republican' if row[0] == 1 else 'Democrat'
    else:
        return np.nan

# %%
## apply all that. df_ide is legiscan matched bills
df_ide = df_names2.copy()
df_names2.columns
df_ide['ideology_scores'] = df_ide.apply(get_ideology_scores, axis=1)
df_ide['parties'] = df_ide.apply(get_party, axis=1)
# Out:
# Index(['date_signed', 'date_introduced', 'bill_document_first', 'date_updated',
#        'short_title', 'bill_type', 'actions', 'summary', 'chamber', 'state',
#        'session', 'action_dates', 'unique_id', 'bill_document_last',
#        'date_created', 'bill_title', 'sponsers', 'bill_id', 'sunlight_id',
#        'name_list', 'full_names', 'len_full', 'overlapping_names'],
#       dtype='object')

# %%
## matches we found where raw bill had only last name. harmonizing the columns for readability
half_name_matches = half_name_matches[['date_signed', 'date_introduced', 'bill_document_first', 'date_updated',
       'short_title', 'bill_type', 'actions', 'summary', 'chamber', 'state',
       'session', 'action_dates', 'unique_id', 'bill_document_last',
       'date_created', 'bill_title', 'sponsers', 'bill_id', 'sunlight_id',
       'name_list', 'party', 'ideology']]

## matches we found where raw bill had full name. harmonizing the columns for readability

full_name_matches = full_name_matches[['date_signed', 'date_introduced', 'bill_document_first', 'date_updated',
       'short_title', 'bill_type', 'actions', 'summary', 'chamber', 'state',
       'session', 'action_dates', 'unique_id', 'bill_document_last',
       'date_created', 'bill_title', 'sponsers', 'bill_id', 'sunlight_id',
       'name_list', 'party', 'ideology']]

## matches we found whith manual matching. harmonizing the columns for readability

matched_manual = pd.concat([half_name_matches,full_name_matches])
matched_manual['ideology_scores'] = matched_manual['ideology'].apply(lambda x: [x])
matched_manual['parties'] = matched_manual['party'].apply(lambda x: [1 if x == 'R' else 0])


matched_manual = matched_manual[['date_signed', 'date_introduced', 'bill_document_first', 'date_updated',
       'short_title', 'bill_type', 'actions', 'summary', 'chamber', 'state',
       'session', 'action_dates', 'unique_id', 'bill_document_last',
       'date_created', 'bill_title', 'sponsers', 'bill_id', 'sunlight_id',
       'name_list','ideology_scores', 'parties']]

###All three above have single sponsors, so no need to apply average ideology score function on them or party finder.

##matched found with legiscan API. with the newly added ideology scores 
df_ide = df_ide[['date_signed', 'date_introduced', 'bill_document_first', 'date_updated',
       'short_title', 'bill_type', 'actions', 'summary', 'chamber', 'state',
       'session', 'action_dates', 'unique_id', 'bill_document_last',
       'date_created', 'bill_title', 'sponsers', 'bill_id', 'sunlight_id',
       'name_list','ideology_scores', 'parties']]

##create full data

all_match = pd.concat([matched_manual,df_ide])

# %%
all_match.shape
# Out:
# (1155, 7)

# %%
## get number of sponsors
all_match['len_full'] = all_match.ideology_scores.apply(lambda x: len(x))
all_match = all_match[all_match.len_full != 0]

#get mean of ideology scores in list because they have multiple sponsors
all_match['ideology'] = all_match.ideology_scores.apply(calculate_mean)

#how many sponsors
all_match['len_sponsors'] = all_match.ideology_scores.apply(count_elements)

#party variance for multiple sonsor bills. 0 when there is only 1 sponsor of course
all_match['party_variance'] = all_match.parties.apply(calculate_nanvar)

#get party name back from binary 
all_match['party'] = all_match.parties.apply(determine_party)

# %%
# all_match.to_excel('C:/Users/ayush/Downloads/ideology.xlsx', index = False)

# %%
##get back sampled alignments
alignments  = pd.read_excel('./Data/sampled.xlsx')

# %%
alignments.head(2)
all_match = all_match[['state','bill_id', 'unique_id','ideology','party','party_variance','len_sponsors']]
all_match['bill_id'] = all_match.bill_id.str.replace(' ','')
all_match.head(2)
# Out:
#          left_id            right_id  score  adjusted_alignment_score  \
# 0  nh_2011_HB186      ma_189th_H2875   39.0                   23.9421
# 1  nh_2011_HB186  ny_2011-2012_S1300   16.0                   15.0288
#
#   left_bill_id left_bill_state right_bill_id right_bill_state
# 0        HB186              nh         H2875               ma
# 1        HB186              nh         S1300               ny
#   state bill_id                     unique_id  ideology       party  \
# 0    wi    AJR5  wi_2013 Regular Session_AJR5    -1.059    Democrat
# 5    md   SB419                 md_2008_SB419     0.282  Republican
#
#    party_variance  len_sponsors
# 0             0.0             1
# 5             0.0             1

# %%
all_match.shape
# Out:
# (1155, 7)

# %%
##first match bill ideology on left bills
alignment_ide = pd.merge(alignments,all_match, left_on = ['left_id'], right_on = ['unique_id'], how = 'left')

#drop all bills rows where left bill did not match. no point in keeping them since right bill is usefull only with left bill 
alignment_ide = alignment_ide[alignment_ide.bill_id.notna()]
alignment_ide.shape

#match on right bills
alignment_ide.rename(columns  ={'ideology':'ideology_left','party':'party_left','party_variance':'party_variance_left','len_sponsors':'len_sponsors_left'}, inplace = True)
alignment_ide = pd.merge(a,all_match, left_on = ['right_bill_id'], right_on = ['bill_id'], how = 'left')

#dropna again
alignment_ide = alignment_ide[alignment_ide.ideology.notna()]
alignment_ide.shape

#final columns we will use in analysis
alignment_ide.rename(columns  ={'ideology':'ideology_right','party':'party_right','party_variance':'party_variance_right','len_sponsors':'len_sponsors_right'}, inplace = True)
# Out:
# (674, 15)
# (126, 22)

# %%
##also add a column for squared distance between bill pair sponsors
alignment_ide['dist'] = (alignment_ide['ideology_left'] - alignment_ide['ideology_right'])**2

# %%
###save
alignment_ide.to_excel('./Data/joined_metadata.xlsx', index = False)
